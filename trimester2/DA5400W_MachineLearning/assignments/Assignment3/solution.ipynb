# %% [markdown]
# ## Solution 4

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

rng = np.random.default_rng(seed=42)
N = 200
x1_true = rng.normal(0, 1, size=N)
x2_true = rng.normal(0, 1, size=N)
y_true = 3 * x1_true - 2 * x2_true
e1 = rng.normal(0, 0.5, size=N)
e2 = rng.normal(0, 0.5, size=N) 
ey = rng.normal(0, 0.2, size=N)
x1 = x1_true + e1
x2 = x2_true + e2
y = y_true + ey

# %%
X = np.vstack([x1, x2]).T
X.shape
# Out:
# (200, 2)

# %%
linreg = LinearRegression().fit(X, y)
linreg.coef_, linreg.intercept_
# Out:
# (array([ 2.32678514, -1.76295545]), np.float64(0.015768849913575744))

# %%
# TODO Total Least Squares solution
