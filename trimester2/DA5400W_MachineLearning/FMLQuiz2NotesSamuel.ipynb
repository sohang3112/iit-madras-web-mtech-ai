# %% [markdown]
# ##DA5400W: Foundations of Machine Learning
# ## Nirav Bhatt- faculty of DSAI
# working at IITM as M Tech chair
# ###email: niravbhatt@smail.iitm.ac.in
# ##Dr. Jayadev
# ###email:ps.jayadev@gmail.com
# ##Dr. Tirthankar S Gupta
# ###email: ic17043@imail.iitm.ac.in
#
# ##TA
# ###Ayush: da24s019@smail.iitm.ac.in
# ###??: da25d900@smail.iitm.ac.in

# %% [markdown]
# ##Objective:
# To introduce the fundamentals of machine learning techniques and their applications in different problems
#
# ##Prerequisite:
# Basics of Linear Algebra, Optimization, Probability and Statistics
#
# ## Credits: 12
# Lectures: 2(90 minutes) Tutorials: 1 (90 minutes), Self-study: 300-400 minutes
#
# ## Lectures (G Slot)
# Mon: 4-5.30 (Reserved), Tue: 5.30-7, Wed: 5.30-7
#
# ##Grading Policy
# Quiz 1: 15 (online proctured)
# Quiz 2: 15 (online proctured)
# End Sem: 50  (centre based Computer based/handwritten)
# Assignments/ In-class quiz: 20 (Best 8/10)
# No step marking in any part of course

# %% [markdown]
# ## Syllabus
# ---
#
# ### Module 1: Unsupervised Learning
# - Estimation - Review of MLE, Bayesian estimation
# - Dimensionality Reduction
# - Clustering - K-Means, Hierarchical Clustering, Spectral Clustering
#
# ---
#
# ### Module 2: Supervised Learning
# - Functional Approximations and regression
# - Regression
# - Linear Regression, Ordinary Least Squares, PCR
# - Non-linear regression (basis functions)
# - Ridge Regression, LASSO
#
# ---
#
# ### Module 3: Binary Classification
# - K-Nearest Neighbors
# - Decision Trees, CART
# - Bias-Variance Dichotomy, Model Validation: Cross validation
# - Bayesian Decision Theory
# - Generative vs Discriminative Modeling for classification
#   - Generative
#     - Naive Bayes, Gaussian Discriminant Analysis
#     - Hidden Markov Model
#   - Discriminative
# - Logistic Regression
#
# ---
#
# ### Module 4: Advanced Methods for Classification
# - Support Vector Machines - Kernels
# - Ensemble Methods:
#   ■ Bagging - Random Forest
#   ■ Boosting - Adaboost/GBDT/XgBoost
#   ■ Artificial Neural Networks
#   ■ Multi-Class Classification - one vs all, one vs one
#
# ---
#
# ### Module 5: Sequential Decision Making
# - Online learning,
# - Bandit Problem,
# - Reinforcement Learning

# %% [markdown]
# ## Text Books:
# Bishop C. M. & Nasrabadi. N. M. (2006). Pattern Recognition and Machine Learning, New York: Springer.
#
# Hastie, T., Tibshirani, R., Friedman, J. H., & Friedman, J. H. (2009). The Elements of Statistical Learning: Data Mining, Inference, and Prediction, New York: Springer.
#
# ## References:
# 1. Duda, R. O. & Hart, P. E. (2006). Pattern Classification. John Wiley & Sons.
# 2. James, G., Witten, D., Hastie, T., & Tibshirani, R. (2013). An Introduction to Statistical Learning. New York: Springer.
# Notes and scientific papers
# 3. M. P. Deisenroth, A. A. Faisal, C. S. Ong. Mathematics for Machine Learning, Published by Cambridge University Press (2020).
#
#
# ## Additonal Material:
# 1. illustrated guide to machine learning-Statquest
# 2. Pattern Recognition and Machine Learning
# 3. Reference material by Ulriken
# 4. Book for Spectral density - Data Mining concepts and Techniques by Jiawei Han, Micheline Kambe
# 5. Multivariate Data analysis by Johnson
# 6. Elements of Statistical learning by Trevor

# %% [markdown]
# Useful Links:
# https://www.youtube.com/watch?v=zuS1WZQGhAs&list=PLZ2ps__7DhBammhVmBE9f5eezTj2kDfTN&index=1
# https://www.youtube.com/playlist?list=PLZ2ps__7DhBbA_e6_G3FI-BA1f7lCINUu
#
# https://www.youtube.com/@statquest/playlists
#
# https://youtube.com/playlist?list=PLblh5JKOoLUICTaGLRoHQDuF_7q2GfuJF&si=vw5AMoe5OsOxcFKW
#
# https://youtube.com/playlist?list=PLIg1dOXc_acbdJo-AE5RXpIM_rvwrerwR&si=qq-onfQFT24m-x3I
#
# https://youtube.com/playlist?list=PLZ2ps__7DhBbA_e6_G3FI-BA1f7lCINUu&si=UeC7vhob0PvT5rxQ
#
# https://openlearninglibrary.mit.edu/courses/course-v1:MITx+6.036+1T2019/course/

# %% [markdown]
# ##Mid-Sem Portion
# ###Regression - Part 1:
# ###11-Feb
# 1. Introduction
# 2. Types of Regression Problems
# 3. Linear Regression
# * True vs Observed vs Predicted
# 4. Simple and Multiple Linear Regression
# * Random Error (Eps)
# * Assumptions on Random Error
# ###17-Feb
# 5. Ordinary Least Square Solution
# * Finding the model from the Data
# * Least square approach
# * OLS = MLE
# * Interpretation of w^
# * Vector Spaces Associated with Data Matrix
# * Linear Algebrais Interpretation of OLS
# 6. Total Least Square Soltuion
# * Singular Value Decomposition (SVD)
# * Interpreting Singular Vectors and Values of Data Matrix
# * Sum of r Rank 1 Matrices
# * Low Rank Approximation
# * Frobenius Norm of a Matrix
# ###18-Feb
# * TLS Approach and Motivation
# * TLS Solution Steps
# 7. Weighted OLS and TLS
# * Reliability of Measurements
# * Weighted OLS and weights
# * Weighted TLS
# 8. Other Forms of Linear Regression
# * Polynomial Regression
# * Logarithmic Regression
# ###24-Feb
# 9. Multi-Variate Linear Regression
# * Two solution approach (MISO, MIMO)
# ###Regression - Part 2:
# 10. Gradient Descent
# * Limitations of Closed Form Solution
# * Loss function and Gradient Descent
# * Gradient Descent Approach
# * Learning Rate
# * Feature Scaling
# * Gradient Descent and Normal Equation
# 11. Supervised Learning Workflow
# * Translate to SL problem - Data Collection - Pre-processing
# ###25-Feb
# * Hypothesis Selection - Feature Engineering - Model Training
# * Model Validation - Model Selection & Testing - Model Deployment
# 12. Bias Vs Variance in Regression Models
# * Motivation
# * Bias in Predictions
# * Variance in Predictions
# * Prediction Error due to Bias and Variance
# * Relation: Error, Bias and Variance
# 13. Regularization
# * Motivation
# * Math Idea
# * Ridge Regression (L2 Regularization)
# * LASSO (L2 Regularization)
# ###03-Mar
# * LASSO using Coordinate Descent
# 14. Model Validation
# * Techniques
# * Hold-Out, K-fold, LOOCV
# * Metrics to Measure Prediction Error (MAE, RMSE)
# * Metrics to Measure Relative Error (MAPE)
# * Matrics to Evaluate Goodness of fit (R^2, Adj. R^2)
# 15. Feature Selection
# ###04-Mar
# * Recursive Feature Elimination
# * Sequential Feature Selection
# 16. Bayesian Linear Regression
# * Key Idea
# 17. Non-Linear Regression
# * Non-Linear Least square solution
# ###Classification
# 1. Classification
# * Feature Space perspective
# 2. Types of Classification Models
# * Soft vs Hard Predictions in Classification
# * Points to be Noted
# 3. k-Nearest Neighbour (kNN) Classifier
# ###10-Mar
# 4. Logistic Regression
# * Motivation
# * Logit link
# * Sigmoid function
# * Learning Parameters
# * Gradient Descent
# * Decision Boundary
# * Multiclass Logistic Regression
# * Softmax function
# * Cross Entropy Loss
# 5. Performance metrics for Classification
# * Errors in Classification and Confusion Matrix
# * Performance metrics - Accuracy, Precision, Recall
# * Performance metrics - F1 Score
# ###11-Mar
# * Performance metrics - Balanced Accuracy, Sensitivity, Specificity
# * Scores, Ranking and Thresholds
# * Performance metrics - ROC-AUC
# 6. Naive Bayes's Classifier
# * Motivation
# * Baye's Classifier and Decision Rule
# * Naive Bayes Assumption
# * Estimating the Probabolities (Training)
# * Bernoulli Naive Bayes
# * Multinomial Naive Bayes
# * Gaussian Naive Bayes
# ###17-Mar
# * Prediction Steps
# * Score Computation
# 7. Handling Data Imbalance in Classification and Issue
#
# ###Tutorials
# ###23-Feb
# * Linear Regression, OLS and TLS Recap - Prog
# * Sklearn Linear Regression - Prog
# * OLS from scratch - Prog
# * TLS from scratch - Prog
# * Logarithmic Regression from Scratch - Prog
# * Exponential Regression - Prog
# * Gradient Descent from Scratch - Prog
# * Questions on Linear Regression - Ass.1
# * OLS numerical question - Ass.2
# * OLS - Scaling problem
# ###16-Mar
# * Classification (kNN)
# * Classification (Logistic Regression)
# * Naive Bayes' Classifier
# * Classification Metrics
# * Regression - Linearizable Reg. Models
# * Regression - OLS Estimator/Derivation
# * Regression - OLS from Summary Stats
# ###18-Mar
# *

# %% [markdown]
# ##Week 11 Lecture 3 on 18th Mar 2026 - Pending

# %% [markdown]
# ##Week 11 Lecture 2 on 17th Mar 2026 - Pending

# %% [markdown]
# ##Week 11 Lecture 1 on 16th Mar 2026 - Pending

# %% [markdown]
# ##Week 10 Lecture 2 on 11th Mar 2026 - Pending

# %% [markdown]
# ##Week 10 Lecture 1 on 10th Mar 2026 - Pending

# %% [markdown]
# ##Week 9 Lecture 2 on 4th Mar 2026 - Pending

# %% [markdown]
# ##Week 9 Lecture 1 on 3rd Mar 2026

# %% [markdown]
# ### Detailed Notes:
# 04:00->09:00 Recap
# 09:00->28:00 LASSO Solution using Coordinate Descent
# * LASSO has no close form solution and not differentiable at 0
# * Idea: Optimize objective by holding others and optimize one parameter at a time
# * Alogrithm
# 1. Std. each feature
# 2. Initialize random values to parameters w
# 3. Repeat until convergence
# a) Each D predictors(inputs) compute partial residuals
# ri(-j)=yi-Sumk!=jxikwk for all j vars
# * gives what part of yis left unexplained w/o var j
# * This is the target wj must explain
# b) Compute OLS like contribution of feature j
# r-j=pjxj
# pj=x^tjr-j/(x^tjxj)=x^tjr-j (scaled features)
# * Explains potential value for wj when there is no L1 penalty
# c) Apply soft thresholding and update weights as follows:
# wj=pj-lam/||x||^2; pj>lam
# wj=0;|pj|<=lam
# wj=pj+lam/||x||^2; pj<-lam
# lam chosen using validation techniques, no gradient, no matrix inverse
# 1. What is lam? lam is the stength of reg., reg. rate
# 2. Why xj is left and regress in step 2?residual shows contirbution without xj and we regress for xj
# 3. reason behind dividing by L2 norm of x? to give an intuitive answer
# 4. r-j will be a vector?no, r-j is the residual across all samples
# 5. we will have feature no. of r?yes
# 6. pj will be any number?yes
# 7. In an NNN how will this be carried out?something different
#
# 28:00->32:30 Model Validation
# * Hyperparameters to be chosen by user
# * Alternatively this can also be found by Model validation strategy
# * Given data is split into training, validation and test set
# * Training and Validation go hand in hand
# 1. Is this synonomous to hyper parameter tuning?yes. it uses validation in the background
# 2. What is reg. rate?how strong the reg. that needs to be applied
#
# 32:30->39:00 Model Validation Techniques-Hold Out
# * Hold-out, K-fold, LOOCV
# * All techniques involve splitting data into training and validation and validation uses one of the metrics
# * Hold-out-> hold some data for validation Eg. 80:20, 70:30
# 1. There will be only 1 ietration?yes, the initial training depends on the method
# * Random sampling might result in sampling bias
# * The dist of training and validation might not represent population dist of original data
#
# 39:00->50:00 K-fold
# * If there are N they are divided into k folds of N/K
# * Each time one fold is left out of training as val set
# * Repest across all folds and average performance which reduce sampling bias
# 1. Does it suffer from data leadkage?no, selection of k is random but fized once k folds are choosen
# 2. if there are k different models, what is the final model? its the average peroformance across all models
# 3. In all folds are we using different hyper parameters?no, same set of hyperparameters are used
# 4. we take avreage or worst performance?there are different, mostyl average is popular
# 5. How do we take average of 10 models?we choose one metric and stick to it
# 6. How do we choose a model, if the architecture change in every iteration?we fix one and repeat for all folds
#
# 50:00->55:00 LOOCV
# * If no of samples are very low, we use LOOCV
# * Special case of k-fold wheer k=N
# * every sample is a fold and we leave one out and validated on the left out
# 1. will each of these k folds have unique elements? yes
# 2. can folds have unequal elements? not necessary, we add stray to any folsa
#
# 55:00->1:28:30 Metric for Reg. Model Evaluation
# * Mean absolute error MAE=1/NSum|yi-yi^|
# * Easy to understand and same units as dependednt variable
# * Treats all errors equally and does not apmplify large errors
# * RMSE=sqrt(1/NSum(yi-yi^)^2
# * Penalizes large errors, useful for detect outliers
# 1. How will it penalize?summed and then squared and root, that how it peanlizes
# * For smaller errors can be demplified due to squaring
# 2. same reason why we dont use rmse in log regression?no
# 3. smaller erros goes to 0 is beneficial? no if output is also small
# * Mean absolute percentage error
# MAPE=1/NSum(yi-yi^/yi)*100
# * Useful for understanding relative errors and easy to intrepret
# * can be very high if values are small
# * undefined when yi=0
# * scale independent and can be used to compare models
# 4. MAPE also not used for loss function?no
# 5. cross entropy is only used for class. and not reg.?yes
# R^2 - measure of fit
# R^2=1-RSS/TSS=1-Sum(yi=yi^)^2/Sum(yi-yi-)^2
# TSS-> represent total variation in dep. variable rel. to mean
# RSS-> represent unexplained variation by the model
# * R^2 should be high close to 1
# * -ve values represnt under fitting, prediction is worse
# 6. what does 0 value mean?untrained model, same as mean
# * to be used only with same dataset
# * can be misleading if the variance is low on dep variable
# * R^2 increase with variable even of they are not relevant
# * R^2 does not imply good predictions
# 7. How can i comment on model if few metrics are having good score?based on metric understanding we have to take a call
# 8. These 4 metrics will be used on validation set?yes
# Adjusted R^2=1-((1-R^2)(n-1))/(n-p-1) p->no of features
# * model overfitting if diff bt. R^2 and adj R^2 is large
# 9. how can we get formulas for studying if there are anotations?needed ones are included
# 10. Explain derivation of adj R^2?based on dof, if we add feaures denom is smaller and is adjusted
# Adj R^2 ensure R^2 does not increase with just increasing features
# 11. Adj R^2 and R^2 should be near to 1?yes
# 12. How is LASSO or OLS change R^2?if R^2 decrease less after LASSO then reg. is proper
#
# 1:28:30->1:33:00 Feature Selection Prelude
# * Objective: Select a subset of features that will minimize gen or val error
# S set of (1,2,.. D)
# Lval(S)=1/Nval*Sum(yi-yi^(s))^2
# * Search over all subsets are not possible
# * 2 approaches Recursive Feature Elimiation(start all and remove iter) and Sequential Feature Selection(build step by step)
# * Computationally exp but better than LASSO
# 1. Recursive is greedy approach?yes

# %% [markdown]
# ##Week 8 Lecture 3 on 25th Feb 2026

# %% [markdown]
# ### Detailed Notes:
# 1:30->03:30 Recap
# 1. Learning rate and scaling, can adaptive learning rate to compensate for scaling? to some extent, yes
#
# 03:30->27:30 Supervised Learning Workflow
# * Translate a business problem to SL problem
# * Data Collection and Understanding
# * Data Preprocessing
# * Hypothesis Selection
# * Feature Engineering
# * Model Training
# * Model Validation
# * Model Selection and Testing
# * Model Deployment and Maintanence
# In the course we will focus on Feature Engineering, Model Training, Model Validation
#
# 1. How doe we determin the linear or non linear model? using Model validation step by means of metrics
# 2. Hyperparamters are functions of model, if our initial guess is incorrect, will it not result in incorrect model? yes, this is optimized in Model validation step
# 3. There is not much we can do on distribution of data?Basic checks in the correct model needs to be used
# 4. We take a lot of data, doesn't the clt define that it is normal distribution? dist of means across many samples will converge to normal but original dist will not converge
# 5. How do we figure out there is drift in the prediction?During testring of model, we are aware of range of prediction, we look if there is drift from known predictions
#
# 27:30->56:30 Bias Variance Tradeoff
# * Motivation, concept overfitting adn underfitting
# * Bias=E[y^]-yt
# * How far avg. predictions is far from true value
# * Avg value of a complex model is low and for simple model is high
# 1. Bias is computed from coeff?on output, if intrested in predictions bias in prediction, if intrested in interpretation we should look at bias in coeff
# 2. In regression we already have interpreation, so we look at output?yes
# 3. Just by looking at bias we cannot say its overfitting but to look at varaince also?we looking at training error with validation error
# 4. Noise is for each data point? it is for each pt.
# 5. x and y in graph?abstract notation
# 6. are we suppsoed to be definitely know about distribution of input and output?not necessarily
# 7. Instead of E(y^) can we use y^ itself?we cannot calculate this, as we cannot know yt
# 8. For a given model we can tell bias?yes, high or low but never precise
# Variance in Predictions:
# * Variance measures change in model predictions when trained on different datasets
# var=E((y^-E[y^])^2)
# Simple model: High Bias, Low variance
# Complex model: Low Bias, High variance
# So bias vs variance trade-off is inevitable in ML
# 9. If x is 1,2,3,4 and in another data set it is not there how do we give these values for other dataset?it doesn't matter, the trained model can work on any value of x
# 10. How to choose Bias and Variance?By validation and regularization
# * Model Structure: Prediction error source, Linear vs non-linear, polynomial degreee, feature set
# * Parameters Estimation: sample variability, noise in observations, multi-colinearity
# * Increasing data set reduces variance but cannot remove model bias
# * MSE=Bias^2+Variance+Irreducible error
# * E[(y-y^)^2]=(E[y^]-yt)^2+E[(y^-E[y^])^2]+sige^2
# 11. Diff bt. expectations of predictions in single models and across multi-models?depedns on the model selection
#
# 56:30->1:11:00 Regularized Regression Models
# * Objectives: learn a model that explains training data and generalize unseen data, Bias and Variance should be balanced, minimize test error and not only training error
# * Idea: Choose a model that allows flexibility (high variance), Regularize to control flexibility, converts high varianve to balanced
# 1. Training error goes to zero, what to do if we slowly get to zero?Increase model complexity
# 2. What is the general thresholding considering traing and test error?there is no fixed threshold but depends on the objective and model
# * Regularised OLS objective:
# minw(y-X*w)^T(y-X*w)+lam*sig(w)
# * sig(w)-> reg penality-balanving against training loss, sig is large for complex and small for simple
# * lam>=0: Reg rate - controls the strength of reg.
# 3. lam will be upto us? usualy0-1 but cases >1 is also there
# 4. can we consider lam as an optimization problem?we cannot compute both lam and w, the objective becomes complex
# * lam can be fine tuned by model training
# 5. Validation errors, will we be using during loss minimization?after model training
# Impact of Reg: Parameters are pushed to 0, significant increase in variance with small increase in bias
# 6. Will we fit the model based on the loss function?yes
# 7. Instead of adding model complexity, we use Reg. to fine tune the model?yes
# In NN Reg. is used to prevent overfitting, in LR for feature selection
# 8. What is the way to select which feature is good, is it hit and trial?L2-Regularization
#
# 1:11:00->1:28:00 Ridge Regression
# * Ridge regression objective
# min w(y-X*w)^T(y-X*w)+lam||w||2^2
# wridge=(X*^TX*+lamI)^-1X*^Ty
# 1. lam is about reducing influence of weights?yes
# 2. Ridge regerssion this is the loss function?yes
# 3. two approachs, simple model and increasing parameters or max parametrs and apply reg, which approach is better?not known, it depends ont he application and dataset
# 4. Since choosing the approach is dependent on application, does this comes with experience?for small dataset, there are libraries that automates
# 5. Library that does that?Pycaret, Flaml, H2O
# * Penalizes square mag of coeffs
# * Shrinks all coeff smoothly with inc. in lam
# * Shrinks larger coeff more
# * Geometric View: OLS minimizez eror in unconstrained space, Ridge: Min constrained inside L2 circle
# 6. What is the red circle? Represents penality
# 7. how will we know its a circle? the equation rep. a circle
# 8. w^Tw-x< 0 subject to constraint in ridge regression?yes
# 9. How soln got changed to lam?Lagranage multiplier for making it constrained problem
# 10. Why do we consider equality constraint as an equal?its equality that determines intersection
# 11. If its <=c and its a minimization problem, it should be >=0?no
#
# 1:28:00->1:34:30 LASSO(L1 Regularization)
# * Least absolute shrinkage and selection Operator
# * LASSO Regression objective:
# min w(y-X*w)^T(y-X*w)+lam||w||1
# * Can drive some coeff to exactly 0, used for feature selection
# * Minmizes error in L1 square
# 1. What is teh diff bt. Ridge and LASSO? L norm, there is no closed form soln for L1
# 2. Ridge and LASSO converge to same soln.?no
# 3. We need to understand which one to use? we use both to see which performs better. L1-> to drive features to zero, L2->want all features but minimize contribution
# 4. To calculate variance, we need several datasets, how many is needed? usually 30 datasets

# %% [markdown]
# ##Week 8 Lecture 2 on 24th Feb 2026

# %% [markdown]
# ### Detailed Notes:
# 00:30->02:30 Recap
# 02:30->09:00 Lograthmic Regression
# * unit increase in x is w1x100% change in y
# * increase in 1% of x is w1/100 units in y
# 1. What is the advantage of the Log Reg?For convenience in interpretation
# 2. How does that converge for output for Normal and Log Reg?for unit change appx holds good for higher change the appx starts to diverge
# * OLS related assumptions are resonably satisfied
# * Log can only be used for positive values
# * shifiting can be done for 0 values
# * If range of x is small, there can be high correlation bt. x and lnx | x and x^2 so only one should be used
#
# 09:00->34:00 Multivariate Linear Regression
# YNxm=XNx(D+1)W(D+1)xm+ENxm
# * assumptions are mostly same as multiple LR
# * errors are independent across samples of output but error covariance is allowed
# * Each output error across is jointly normal
# Two Solution approach:
# * OLS Multivariate can be applied using MISO and MIMO
# MISO:
# * model is broken down into multiple models each having 1 dep variable
# * Each model is obtained like multiple linerar reg.
# w^=(X^TX)^-1X*^Tyi
# * Applied if dep variables  are independent of each other, error terms pertaining to each should not be correlated
# 1. is each model capturing diff features?no, features are same, outputs are different
# 2. are we training on all possible datasets?no, there is only one dataset
# 3. is output a vector of m dimesnion?yes
# 4. is it same in MISO?in MISO we can build independent models and MIMO we cannot build independet models
# 5. Even if ops are realted, the MISO can be still be applied, the coeff of model is wrong?it will be different, the relation bt. ops are not captured
# 6. o of the model, y is a vector? yes in MISO it is in one value, in MIMO it is a vector
# 7. MSE loss is sum of each vector across diff values of y?yes, its a matrix
# 8. additonal constraint of y1 only model will be when measurements are at different frequency level? yes, MISO is recommended
# 9. MIMO is used when correlation o finputs is high?no, when correlation of outputs are high, if its low we go with independent
# 10. SO means single independent output? independent of other outputs
#
# 34:00->40:00 Part 2 Regression
# Outline:
# * Gradient Descent approach to LR
# * Supervised Learning workflow
# * Bias Vs Variance in Reg. Model
# * Regularization in Reg. Model
# 1. In LR, where will OLS break?to be discussed
# Draw backs of OLS analytical:
# * Computation is high memory consuming
# * Cannot be used for data streaming in batches
# * Do we need to find inverse? no, OLS can be solved iteratively
# Loss Function and Gradient Descent:
# * Loss function: J(w)=1/2NSumi(yi-xi^Tw)^2
# * Properoties: quadratic and convex, global minima exist, ideal for gradient based optimization
#
# 40:00->1:14:00 Gradient Descent Approach
# * Start with init guess of w
# * Iteratively move in direct of steepest descent of cost function
# 1. Why is there + in the infal eqn? because gradient is -ve and we go in opposite direction of grad
# 2. Second term is computational intense beause of inverse, in GD does it exist?no
# 3. Diff bt. mini-batch and batch GD? for batch it is N but for mini batch it is B<< N
# 4. Switching from OLS/TLS to GD, GD will bring same issue?no and we can do batch wise execution, inverse computation doesnt come
# 5. can we convert data matrix to orthogonal matrix, for not computing inverse values?that is still computational if there are large samples
# 6. Will it help in improve accuracy?if data is good and assumptions are right, analytical is better
# 7. Drawbacs of GD? error and for low samples it is slow, sensitivy learning rate
# Learning Rate a:
# * GD only gives direction but not how far one shouls go
# * a controls step size
# * a should be balanced, typically 0.1
# 8. If Grad is high we need to choose a low, how is it related to step size? Step size is a*grad
# 9. For specific grads, we scale alpha to converge faster?for NN it is used, Eg: Adam, momentum, RMS prop where curvaturs of the function is considered
# 10. Is this only due to linearity, or is it dure to modelt complexity?yes it converges only due to linearity
# Feature Scaling:
# * features to be scaled in GD
# * wihtout scaling, features with large magnitude dominate Grad
# * without scaling: contours are more elliptical, learning rate  be lower for stabilty, GD would be slow to converge
# * with scaling: opposite of w/o scaling
# 11. do we do feature scaling in unsupervised approach?yes, otherwise clustering willbe dominated by one feature
#
# 1:14:00->1:33:00 GD and Normal Eqn.
# * GD converge to same as OLS if alpha is proper and enough iterations are run
# * At optimum grad is 0 and GD eqn becomes OLS
# Supervise Learning Workflow:
# * Translate a business problem to SL problem
# * Data Collection and Understanding
# * Data Preprocessing
# 1. Model will be able to predict upto certain extent?yes but accuracy will be low
# 2. Are we modeling regression formula? we used tools to seelct proper features that contribute to model

# %% [markdown]
# ##Week 8 Lecture 1 on 23rd Feb 2026 - Pending

# %% [markdown]
# ##Week 7 Lecture 2 on 18th Feb 2026

# %% [markdown]
# ### Detailed Notes:
# 04:00->05:30 Recap
# 05:30->29:00 TLS Approach
# * Error in both indep and dep variable is minimized while obtaining model
# * True model yt=w0+w1xt
# * Observed model y=w0+w1x+(w1epsx-epsy)
# 1. How eq, obtained? y->y+epsy and x->x+epsx and movnig to one side
# * Values of both dependent and independent values are to be estimated in this case
# * Mathematic Objective:
# min w||[X,Y]-[X^,Y^]||F st. y^ in Col space(X) y^=X^W^
# 2. Why TLS is ued instead of OLS?TLS used only if noise is there in both inputs and outputs
# 3. TLS is etiamting true model and OLS is eatimating the observed model?no, we are stimating model closed to true model
# 4. We generally take residuals as observed y- pred y?in TLS there is eror in xna dy there y,y^ and x,x^
# 5. In both we are trying to estimate true model?yes
# 6. How can x be called estimated if its an indep variable?x can have noise, estimate is somehowe denoising and giving better estimate
# 7. Can we say in TLS x is a random variable?yes
# 8. Earlier we knew y and y^, how will we get x^?to be discussed
# 9. when we min vertical dist from y, will there be huge shift in x^?no
# 10. is x=x^, we are going to OLS?yes
# 11. In OLS, we take var(y) and var(y^) and sq. of bias, v(y^)=0, in TLSvar(yobs) exist?yes
# 12. Baye LR and TLS diff is that w also have variation?yes
# 13. Estimated line aligns with the dist of data, will it point in the direction of the PC?yes
# * A numerical solution will be obtained via SVD
#
# 29:00->43:00 TLS Solution Steps
# * Step 1-> Scale data wrt all dep and indep variables to 0 mean and 1 var
# * Step 2-> Construct augmented data matrix combining X and y
# * Step 3-> Perform SVD on Aug matrix
# * Step 4-> Identify smallest sing values and corresponding right singular value
# * Step 5-> Partition sing. vectors into indep and dep values vx Dx1 vy 1z1
# * Step 6-> w^=1/vy[vx] Estiamte of reg. coeff
# 1. cant we use per distance to line and we try to find coeff?yes, for that GD based approach should be used
# 2. are we trying to capture max var?sing vectors are per, last vector is per to all other vectors
# * least variance captured by last sing matrix is the variance of noise
# Step 7->Get corrected values of data matrices X and y by taking low rank appx of augmented data matrix
# Data matrix has rank of D and the additional rank is due to noise
#
# 43:00->44:00 Summary
# * Right sing vectors are directions along which var equal to sing values is captured
# * Every matrix can be appx. by a lower rank r by taking r largest sing values and corresponding sing vectors
# * Low rank matrix appx is used for TLS soln.
# * TLS approach min errors in both dep and indep variables
# * TLS by taking SVD of aug data matrix
#
# 44:00->1:01:00 Weighted OLS and TLS
# * All measurements are not equally reliable
# * Arises due to data collection process, measurement instruments, exp or operational conditions
# * This leads to heteroscedascity
# * WOLS/WTLS Factors noise in variance
# * Weights for weighted OLS
# * Approach 1: Reliability based on weights, sources with higher reliability gets more weight
# * Approach 2: ITerative Re-weighting, initial weights using Std OLS, WOLS is performed and re-estimated, goes ietratively till w converge
# * In weighted TLS only step2,3 are modified, they multiple with sqrt(sigma matrix) and performe SVD
# * End rescale back
# 1. Var of error is contributed by both var of y and x?in  TLS yes
# 2. What is sigma 1/2? it is error covariance matrix not summation
# 3. Diff bt. TLS and WTLS? to address hetero scedascity in samples based on reliability
# 4. Regression we refer to Johnson textbook?yes
# 5. Chapter number form Johnson?they are not exactly found, portions are taken
#
# 1:01:00-> Other forms of LR
# * What is dep and indep variable relation is not linear
# * In this case the variable can be suitably transformed b4 applying LR
# * Eg: Polynomial trans, Log trans
# * When tot ry other form of LR? non-linear strut of model is known, residual seems to be skewed, some non-eandom pattern of residuals
# y=w0+w1x1+w2x1^2+w3x2+w4x2^2+w5x1x2
# * Overfitting can be an issue
# * DEgree of polynomial can be deicded using Cross validation
# 1. OLS is for linear, here it is nonlinear?we use OLS method to find the weights
# 2. How is the prediction if estimates are baised? we are satisfied with the errors and estimate
# 3. Can we show estimates will be biased in ply reg?repeat exp many times to prove, mathematical proof will become complex. Muach easier to show emprical
# 4. Bias and variance?higher degree can increase variance, tends to overfit
# 5. OLS and TLS, can we apply for other type of problems statement?we appx variable using polynomial reg needs to be used before we apply OLS and TLS
# 6. how to create eqns like this?based on degree we add all possible combinations, use CV and Regularization to see which terms to drop
# 7. In sklearn can we specify which order?by default cross terms are ignored, to be included via parameter
# 8. Library tries to fit?only trains, best fit to be analyzed
# * Log transformation can be in both dep and indep variables
# * Eg x and y are non linear but x and log(y) is linear
# * Scenairos to use: Skewed distribution(Lof ensure homscedacity), known exp relation, variance of erros is not constant, wide range(for compressing scales), percentage changes(small change in log y corresponds to relative change in y)
# 9. What about standardization? cannot account for varying increase, can be appplied after log transformation

# %% [markdown]
# ##Week 7 Lecture 1 on 17th Feb 2026

# %% [markdown]
# ###Detailed Notes:
# 01:00 -> 17:30 Ordinary Least Squares Solution
# * Model structure y^=w0+w1x1+..wnxn
# * Known: Mappped input and output
# * Objective: Estimate w that minimizes error in prediction
# * Assumptions: no multi-colinearity, number of samples in dataset> no. of regression coeffecient, X is observed without noise, estimated rgeression coeff will be diff from true Reg coeff
# 1. If we have more features than no. of data points, should we use PCA?yes, other methods also exists
# 2. Can we use pseudo inverse in normal equation?yes, but there are many other possible solution and no unique solution
#
# 17:30 -> 53:00 OLS Approach
# * Residual: diff bet. obs and pred value
# * SSR = (y-X*w)^T(y-X*w)
# * Least square estimate w^ argmin(w)SSR
# * Final Normal Equation w^=(X*^TX*)^-1X*^Ty
# 1. The real error id diff bt. true and observed?yes
# 2. The predicted model will also learn error?no, error is unexplained by the model
# * OLS=MLE y=X^Tw+eps, eps~Normal(0,sig^2T)-> yi~N(xi^Tw,sig^2)
# * w^ is best fit to given data
# * w^ is unbiased estimate of w
# * Its is best fit for assumptions of OLS, if assusmptions fail it is an unbiased estimator
# * Interpretation: changein dep for unit change in indep variable holding everything else constant
# 3. W^ is the weight, OLS is finding w and GD also finding w?yes OLS can also be found using GD
# 4. When we find dist of Y, then X also has a dist.?no, in OLS there is no uncertianity in X
# 5. We dont use Bayesian for LR?no, we use but not covered as part of syllabus, Bishop book mentions this
# 6. In Deep Learning, we will be using Bayesian?yes for Bayesian NN
# 7. Bayesian is also used when we are uncertain about weights?yes
# 8. Bayesian LR is diff from Ridge regression? its the same, there is equivalend bt Bay Reg and Ridge Reg
#
# 53:00->1:07:30 Linear Algebraic Interpretation of OLS
# 1. If Bay LR, the eatimate will be a MAP estimate? yes
# Variables as Dimensions:
# * Dimnesion: Each dimension or axis of a vector space is represented by a variable
# * Vector: Each vector in the space represents a sample across all variables
# Samples as Dimensions:
# * Dimension: Each dimension or axis of the vector space represents a sample
# * Vector: Each vector in the the space represents a variable with all its sample values
# * OLS Soln. is in matrix form: y^=X*w^
# * y^ lies in column space of X*
# * y^ is the projection of y onto the column space of X*
# * Intrepretation is well explain by Johnson
# * Residual vector(Observed-Predicted): r=y-X*w^
# * Residual Vector is perpendicular to columns space of X* (perp dist bt. and y^)
#
# 1:07:30->1:10:00 Summmary
# * Residuals capture error in prediction
# * Reg model is got by esimtating coeff which min residuals
# * analytical OLS is givenby normal eqn., gives soln in one shot
# * Reg coeff capture change in dep for unit change in indep variables keeping others constant
# * OLS predict is projeciton of vector of observed values on columns space of data matrix
# 1. Exp(W^)=w, why? If we average w^ based on large number of iterations it will converge to true values w, law of large numbers and CLT coming into picture
#
# 1:10:00->1:25:00 Total Least squares(TLS)
# * SVD: Xmxn=UmxmSmxnV^Tnxn
# * U->left singular vectors, V->right singular vectors, S-> singular values along main diagonal
# * Right Singular vectors: direction along which variance of data is sigma
# * Left singular vectors: projections of data ontp directions given by v
# 1. Shouldn't X be data centered matrix?yes, it is generally done
# * Right singular vector+largest singular value=direction of maximum variance in data
# * Same idea is used in TLS
# * A matrix of rank r can be written as a sum of r 1 rank matrix
# * X=[u1 u2..un]S[v1 v2 ..vn]^T
# * X=u1S1v1^T+urSrvr^T+..urSrvr^T
# * Low Rank Appx. -> A matrix of rank r can be appx as rank l mattrix l< r by taking largest l singular values and corresponding singular vectors
# Xl=u1s1v1+u2s2v2+...ulslvl
# * Frobenius Norm of Matrix
# ||X||F=sqrt(sumi sumj Xij^2)
# 2. For rank r matrix S is mxn why it is not mentioned as sigma n? for rank r there are r singular values

# %% [markdown]
# ##Week 6 Lecture 2 on 11th Feb 2026

# %% [markdown]
# ### Detailed Notes:
# 01:00 -> 7:00 Introduction on Linear Regression
# Outline:
# * Intro to Linear Regression
# * Types of Regression problems
# * Linear Regression
# * Simple and Multiple Linear Regression
# * OLS Solution for Linear Regression
# * TLS and WOLS/WTLS Solutions for Linear Regression
# * Other forms of Linear Regression
# * Multi-variate Linear Regression
#
# * Regression, finding relationshipps(model) are identified between set of dependent variables and set of independent variables
# * Depenedent variable should be continous numeric, if not it becomes a classification problem
# * Eg: Predict price of house given size,location,#bedrooms etc.
#
# * Types of LR
# * Relation - linear and non linear
# * Number of dep and indep variables - univariate, multivariate and multiple regression
# * Types of Soln. based on errors - TLS and OLS
#
# 07:00 -> 44:30 Linear Regression
# * Relation bt. Indep and Dep variables is linear
# * Function need not be linear
# * Function need not be linear in variables
# * y(x,w)=w0+w1x+eps
# * True(Ground truth), Observed(measured or observed) and Predicted(estimated by model) Values
# * Residual=True-Predicted
# * y(x,W)=w0+w1x1+w2x2+..+wnxn+eps
# * Genral y(x,W)=w0+w1phi(x)+..+wnphin(x)+eps
# 1. Is x in general equations scalar?it is a vector
# 2. In polynomial reg., is it an appx of Linear Reg.?no, poly reg is a combination of inputs
# 3. Dep and multipl Indep variables related linearly, is it due to linear function of observed values?yes
# 4. In actual case it may not be linear?maybe
# 5. If we know relation is linear, do we need to do regression?Yes, to find out m and c or parameters
# * Multivaariate:
# y1(x,W)=w01+w11x1+w21x2+...wDaxdD+eps1
# y2(x,W)=w02+w12x1+w22x2+...wDaxdD+eps2
# ym(x,W)=w0m+w1mx1+w2mx2+...wDmxD+epsm
#
# 44:30 -> Simple and dMultiple LR
# * Matrix form y=[1n X]w+eps => y=X*w+eps
# 1. The diff. between y and ypred is displayed? no, its the ground truth and data observations
# * Assumption of Erros -> E(eps)=0
# 2. There is no possibility to measure the noise? no
# 3. easy way to find E(eps)=0? by repeating observations
# 4. Residual average will be zero?yes, that assumption is made
# 5. we are expecting exp of residual =0 would imply exp of noise=0?yes ifresidual only contains noise
# * Variance of error should be same for all values of independent variables and errors across diff observations should not be correlated (Homoscedastic errors)
# * Errors should be Normally distributed
# * Indepedent variable and error should not be correlated
# 6. How can we talk of variance of errors being constant?we are repeating the experiment for the same inputs, the output is considered a random variable due to the random noise
# 7. Can we say which of the variable contributed how much to the error?no
# 8. If we calculate residuals and we calculate weighted terms of each variable, can we find the contribution?inputs dont contribute to the error, if input not contibuting to the model then it adds to the error
# 9. Is it related to multi colinearity?no
# * You should not have multi colinearity in OLS
# 10. If hidden feature is not part of the model, then the error is purely random?need not be
# 11. Any ref book?Bishop, Multivaritate data analysis with Johnson
# 12. Homoscedastiscity of errors, noise will be constants for every inputs?yes
# 13. What can we do if its not normally distributed?the solution will minimize the noise but it will be a biased estimate

# %% [markdown]
# ##Week 6 Lecture 1 on 11th Feb 2026 (Instead of 10th)

# %% [markdown]
# ### Detailed Notes
# ### 5:00 ->35:00 K-means problem
# * Plcaement of towers by Telecom companies
# * K=2 two towers, 6 houses in rural
# * Objective->  Minimize distance bt. each house and nearest tower
# * House cooridnates-> (2,2) (2,4) (5,8) (6,7) (9,2) (10,3)
# * a-> consider 2,2 and 5,8 as initial locations
# 1. Should we calculate Eudlidean distance? yes
# * Step 1: Make a table compute distance of H with T1 and T2, use min distance to allocate
# * Step 2: recompute centroid by computing coordinate average 22:00
# *Step 3: reallocate to clusters based on new centroid
# * Clustering is impacted by initial point
# 2. Canwe take any one data point as starting?maybe yes but not always
# 3. do we stop when the cluster centers dont change much?yes, sometime thresholds are used
# * b-> If new house is provided with coordinate (5,3) which tower should it be
# * find distance from new centroid and find T1,T2
# 4. shouldn't assignment of H7 lead to centroid recalculation?no after cluster is formed if input is small, but needed if too many data points are added
#
# ###35:00->59:00 DBSCAN
# * 11 data points given eps=0.6, minpts=4
# 1. In each point do we need to check or we stop when we reach min pts 4?yes, enough if we find minpts
# 2. do we need to have eps=0.6 or close by is fine?yes its fine
# 3. do we create a circle of points? including core point, min pts should be 4
# 4. Do we have to create matrix and compute distances?yes
# 5. it will take O(n^2)? yes its for understanding, there are libraries that do in one step
# 6. in exams will we be given similar no. of points?no, its for practice
# * Draw table, class points based on distance
# * Noise if no groups are formed
# * >4-> Core, 3-> border
# 7. 2 can be considered as noice?for safer side we consider 1
# 8. How P1 and P4 in same cluster, as in P4 there is no mention of P1?
# 9. P1 to P8 is reachable, P8 to P4 is reachable, does it mean P4 to P1 is reachable?no
# 10. one iteration is enough to classify whether pts are core or border or noice?yes
# 11. Based on min ponts cluster will differ?yes, choosing hyperparameter is important
# 12. min pts will always be a constraint that user has to pick?yes similarly chossing value of k in knee method
# * Form cluster with core points, first point P3 has P2,3,6,7
# here P6 is a core and has P2,3,5,6,7 intersection is P2,3,5,6,7
# * Look at the unaccounted core points P8 has P1,4,8,9,11 and P11 is a core points so 2nd cluster has P1,4,8,9,11,
# * Noise is P10
#
# ### 59:00->1:19:00 Hierarchical Clustering
# * Write points as a matrix and take diff bt. the points
# * Find min distance of upper traingular and merge
# 1. Should it be 42.5? no we have to combine and form clusters
# * a-> in single linkage we find min of combined clusters
# 2. how do we draw dendogram?to be shown
# 3. How are the levels of dendrogram written?on every iteration when we merge clusters

# %% [markdown]
# ##Week 5 Lecture 3 on 4th Feb 2026

# %% [markdown]
# ### Detailed Notes:
# ### 04:30->08:00 Recap
# 1. Timing for Quiz 1? To be informed by CODE team
# * Knee point, Add clustering, applying different metrics
# * Quality of Clsuters
#
# ### 08:00->12:00 Silhouette Score
# * a-> avg dist. bt. xi and other pts in Ci
# * b-> min of avg dist
# * S(xj)=b-a/max(a,b)
# * Lies bt. 1 and -1, -1-> to assign to neighbouring, 1-> same cluster
# * mean scores of all ponits tells clustering quality, close to 1 is good clustering
#
# ###12:00->16:30 Dunn Index
# * del->inter cluster dist.
# * d-> diameter of cluster
# * Dunn Index-> min(del)/max(d)
# * MEasure of compactness, prone to outliers
#
# ###16:30->20:30 Density Based Clustering
# * Clustering based on density
# * How should we cluster -
# * They can define cluster of arbitrary shape, handle noice well, only need density as criteria
# * Methods-DBCAN, OPTICS, DENCLUE, CLIQUE
#
# ###20:30->54:00 DBSCAN
# * Density based Spatial Clustering of applications with noise
# * Epse and mon pts, core points, denisty recahbale, connected, border point
# * Eps-neighbourhood of object
# * minpts-> specify density threshold
# * corepoint-> eps-neighbourhood contains atleast minpts including itself
# * density reachable->a-core object, b-object(core/non-core) b is reachable from a
# * density connected-> p1,p2 are density connnected concerning eps and minpts there is q such that ir is density reachbale to both p1 and p2
# * Convex set is not necesaru condition for density-clustering
# 1. In order to be denisty reachable should minpts number of pts lie within the intersection of 2 clusters?density reachable is defined for core object a if b is in the eps of a, there is no concept of intersection. We can define density reachable for the core point not any other point
# 2. How min pts concept relate to this?This needs to be defined for a neigbourhood
# 3. Why is it applicable only to core points and not any other points?it is defined for core point,Eg person belongs to a crowd is defined by the center of the crowd (syn to core point). Core point defines the density
# 4. if a is reachable from b, is it symmetric, ie b is also reachable from a?yes if b is a core point
# 5. If pts lies on the eps range of cluster is it directly density reachable?no, core pt->eps and min pts, it cant be assumed both way
# 6. eps and min pts are hyper parameters?yes
# 7. is the min pts same for all cluster?no
#
# ###54:00->1:00:00 DBSCAN Algo
# * Select arbitrary point
# * Retrieve all density reachable from p wrt eps and minpts
# * If p is core pt cluster is formed
# * If p is border pt, no points are sensity reachable, DBSCAN visits next point
# * Continue until all pts are processed
# * Sensitivity to parameters
#
# ###1:00:00->1:10:00 Spectral Clustering
# * Uses concept of Graphs(Laplacian) and similarity matrix
# * To be covered in greater detail in Data mining
# * Reference material by Ulriken
# 1. Book for Spectral density?Data Mining concepts and Techniques by Jiawei Han, Micheline Kambe
# * eps and min pts will define concept of density and not the cluster
#
# ### 1:10:00-> Outlier detection
# * to be removed before clustering
# * DBSCAN in a way excludes outliers and used for outlier detection
# * Density based methods are not affected by outliers
# * For others outliers may cause problem
# * Many of Clustering assumes noise is not present
# * Representative deduction to reduce computational efforts
#
# ### 1:13:00->1:38:00 Summary
# * Cluster analysis groups object on similarity
# * Measures of similarity can be computed for various types of data
# * Clustering methods can be categorized to algos
# * Quality of clustering can be evaluated in many ways
# * To start with Regression in the next class
# 1. What is rand index?not covered due to time constraint, students should go through and is coming for exam
# * Rand Index-> D (n pts),subsets D1(r points) D2(s points)
# * a-> same D, D1,D2, b->not same in D,D1,D2, c-> D=D1,!=D2, d->D1=D1,=D2
# * Rand index = a+b/(a+b+c+d)
# * n(n-1)/2->a+b+c+d
# * RI is 0 clusters are not well, 1 algo is well
# * Purity and Entropy is more prefered
# 2. D represent ground truth?someitmes yes
# 3. For unsupervised data, we dont have lablled data how can we determine best algo?Sill score, doesnt require labelled data. Uses clusters we got and distance from other clusters
# 4. Assignment 2 will be published in course page?yes by tonight
# 5. What is the portion for quiz 1? upto rand index

# %% [markdown]
# ##Week 5 Lecture 2 on 3rd Feb 2026

# %% [markdown]
# ### Detailed Notes:
# ### 04:30->24:00 Recap
# * Clustering K-means illustration and algorithm
# * Clustering problem and notation
# * Pseudo Code: Lyod's heuristic
# * Example runs (K=2,4)
# * Run2 (K=4)
# * K-means critique - only numeric data, does not scale large data set
# 1. What is medoids?another way of computing the center
# 2. is medoid widely used or L2 norm?typically Euclidean distances are used
# * Centroid, radius of cluster, diameter of cluster
#
# ### 24:00->48:00 Knee Method
# * point at which error will drastically reduce after which major reduction is not possible
# 1. right number of cluster is after or before the knee point?exactly at the knee point
# * pitfall - points in border between two means - Fuzzy, random asssignment
# * better alternative for distance - ellipsodial, distance that adapts to width and depth of cluster
# 2. L2 norm will not give exact circle but will give smt that is circular in nature?yes, however ellipsoidal spans better to accomodate points
# 3. The farthest point is from centroid or any two points in the cluster?it is wrt centroid
# 4. The algo discussed already takes care of ellipsoidal shape?No
# 5. Fuzziness will also be solved in this method, because boundaries will be more compact?no, still smt might come in the border. Random assignment is widely used in K-means
# 6. Even after clustering, we can have points that are not part of any cluster?possible if we have exactly at the boundary
#
# ### 48:00->55:30 Hierarchical clustering
# * Dendrogram, builds tree of clusters
# * Agglomerative - start with individual pts. repeatedly merge on criteria
# * Divisive - Start with one cluster, divide based on criteria
# * Decompose data objects to tree of clusters
# * Clustering obtained by cutting at a desired level
# * Agg Clustering - no. of clusters not defined, computationally expensive
# * Inter Cluster distance
# * Single link: min dist. of centroids
# * Complete link: max distance bt. element in one cluster and an element in another
# * Average: avg. distance bt. element in one cluster and an element of another
# * Centroid: distance bt. centroid of 2 clusters
# * Medoid: dist. bt. 2 medoid
#
# ### 55:30->1:23:30 Agglomerative Clustering
# * Naive algorithm
# * Chose distance bt. two observations
# * Choose a linkage metric
# * Compute distance bt. N clusters
# * find two closest and merge
# * Update distance metrics
# * Repeat until merged to one cluster
# * Branch lenght: min dist. bt 2 cluster/2
# * Example
# 1. How are merging two clusters? min of upper triangular matrix and merge the row and column cluster
# 2. Threshold is minimum distance between clusters?no, it is based on cluster height
# 3. which application we use Heirarchial clustering?this is a method, agnostic towards application. applications where number of clusters are not known
# 4. is this unsupervised? we will also have same problem in supervised
# * Meta learning to choose clustering methods
# 5. we can use NN for clustering?no
# 6. How are we choosing cutoff height?depends on the needs of the application
# 7. How do we define if we have good number of clusters?to be disucsed later under quality of clusters
# * complete, average and centrodi link approach towards clustering
# * Quality of Clusters
# * With labeled-> purity, entropy
# * Ground truth-> Rand Index
# * No Info-> dia, radisu, dun index, sil. score
#
# ### 1:23:30->1:32:00 Quality of Clusters
# * Purity-> no. of correctly assigned data points by N
# * 1-> perfect clustering, 0-> bad clustering
# 1. how do we identify correctly assigned? we use labelled data based on truth availability
# * Entropy->Probability of a class belonging to a cluster
# * Entropy of ith cluste is sum(pijlogpij)
# * total entropy is given by weighted sum
# 2. what is Ni? no. of points in a cluster
#
# ### 1:32:00-> Post Class queries
# 1. Upto which topic for midsem? upto clustering
# 2. type of question?MCQ, MSQ, Num type
# 3. Entropy is cross entropy?no
# 4. Possibility of multiple knee points?typical no
# * To write hand written assignment
# * Expect rough sketch only

# %% [markdown]
# ##Week 5 Lecture 1 on 2nd Feb 2026

# %% [markdown]
# ### Detailed Notes:
# ###16:00->18:00 PCA algo explanation
# * 5Data pts
# * x1-x5 3x1 dimension
# * Center data set-> Calc dim mean and subtract each data pt. with dim mean, result matrix is Xc
# * Calculate Co variance matrix C=(1/n-1)Xc^TXc
# * Solve det(C-lamI)=0
# * lam1,2,3 and find equivalent eigen vectors
# * eigen vectors of max variance is PC
#
# ###18:00->27:00 Practice gap
#
# ###27:00->33:00 Question Error clarification
# 1. middle mean is 6.4? yes ,error in notes
# 2. C should 3x3 or 5x5? formula incorrect on notes, will be corrected
# 3. Why n-1? Because it is computed based on sample statistics
#
# ###33:00->57:30 Practice gap
#
# ###57:30->1:20:00 Diagonalization concept
# * Used in power calc, data science (PCA), Rotates coord to align with PA
# * Steps, Decompose A to J+I, Check AM=GM, Find Basis of null space, Orthonormaliz using Gram-Schmidt
# * Matrix is diagonalizable if AM=GM
# * AM how many times EV is repeated
# * GM is dim of null space dim(ker(A-lamI)
# * Example problem
# 1. What to do after getting Eigne value of J3? Find EV of I and then add together for EV of A
# 2. Is decomposition to I matrix mandatory?It depends on the matrix, we can apply decomposition to familt of matrix split into J+kI
# * Find eigen values of A
# * For each eigen value verify AM=GM
# * find eigen vectors
# * In example two eigen vectors of eigen value 1 are not orthonormal, we use GS method to get second vector
# * arrange all orthonorla eigne vectors in matrix form to form Q orthogonal matrix

# %% [markdown]
# ## Week 4 Lecture 2 on 28th Jan 2026

# %% [markdown]
# ### Detailed Notes:
# ### 04:00->40:00 Cluster Analysis
# * Cluster analysis is an Unsupervised learning method
# * Start with unlabelled data
# * Identify clusters and study characteristics
# * Done by using mean
# * Procedure-> preprocess(remove outlier, numerosity edcution), look at similarity, partition into subset(similarity within subset(Intra-cluster) is high and across cluster(Inter-cluster) should be low)
# * Used for better understanding data, visualization Eg: customer category in sales, predictive purpose, decision making
# * Applications - Marketing, Documents, Image Processing, Manufacturing, Security
# 1. Can all outliers end up in a single cluster? no, cluster analysis are done after removing outliers
# 2. How do we find an outlier?one aspect is distribution, outlier will make the analysis drastically different
# * Definitions of Centroid(mean of data pts.), Radius of cluster(max dist. bt centroid and pt.), diameters of a cluster(largest distance bt. two pts. in a cluster)
# 3. Here there is no relation bt. radius and diameter?no, cluster is not a perfect circle
# 4. Why are we taking square cant we take mod?not differentiable, does not penalize large outliers?
# 5. Should it be a sqaure root in the formula of distance?reasons similar to mod
# 6. Clusters are circle by definition?no, it can take any shape
# 7. In higher dimension it is difficult to visualize?yes
#
# ###40:00->45:00 Clustering approaches
# * Partitiona methods-kmeans, kmedoids, PAM, CLARANS
# * Hierarchial mehtods(Form a tree)-AGNES, DIANA, BIRCH
# * Density based(connectivity and reachability)-DBScan, OPTICS
# * Graph based - Spectral theory
#
# ### 45:00->57:30 K-means
# * Simple to understand and resonably fast, gets complicated for big data
# * Used as a first method
# * Visual Illustrations of K-means
# * Start with arbitrary centers-Assign points closest cnetroid-Recompute centroids-iterate till convergence-reassign ponits to closest centroid
# 1. What is the criteria for convergence?u1^k=u1^k-1
# 2. Will there be a situation where we might miss?no, as we are looking at all possible combinations
# 3. Is mu1 random? no, only initiala guess is random
# 4. Is the algo depend on how good/badly we choose arbitrary center?yes
# 5. What should be local solution mean in this case?we can find better clsuters than at convergence
# 6. We are still not exploring the best case?in a way yes, all possible ways will have high combinations for global optimization, solution
#
# ###57:30-> K-means algorithm
# * Chosse k centers for k cluters(random)
# * Assign instances to clusters
# * Compute centroids of cluster
# * Make cnetroids of cluster centers, go to step 2 till convergence
# * Problems and notations, N-objects, K-means
# * Distance d=(xi-mi)^2
# * Find K-means that minimize
# * K-means cluster-pseudo code-Llyod's heuristic
# 1. What are methods to estimate K? there are heuristics, depending on knowledge or mathematics. To be assumed basesd on application
# * K-means cant find outliers
# 2. we are ideally trying to find min no. of clusters?yes
# 3. What kind of optimization we can use?we can use GD but question is on effceincy
# 3. Lyods Heuristics what does R rerpesent?different way of writing closest mean
# 4. How we will decide the number of clusters? it is heuristics
# 5. Is there any advantage of using PCA?for large dim K means becmes a problem so we use PCA to reduce dimensions
# 6. Projections on the vector is why we do PCA, we take top k vectors those projection done give much info?it gives information about where the data lies
# * Food for thought - bonus questions
# * Prove that k-means yields clusters are convex sets, Hint: any two points we can join using a line that stays inside the cluster
# * k-means is effeciently solvable when all datapoints lie on real line(to use concept of DSA)
# 7. How do we determine convexity of the clusters?to be covered in tutorial
# * Examples runs, k=2,k=4( 2 close clusters), k=4(3 close clusters)
# * Analysis of alogrithm
# * Are mean(centroids) the best pt. to represent cluster centers for a given partition
# * Does algo converge for any dataset
# * Does the algo globally minimize sum of square distance?
# 8. Hypothesis testing, are we supposed to go through that?Only topics needed are covered, will be used in coming topics
# * To share the book from where slides are taken
# 9. Smooth surfaces are properties of all clustering algos?no, to be covered in coming lectures
# 10. Should the additional questions in class be part of assignment?no

# %% [markdown]
# ## Week 4 Lecture 1 on 27th Jan 2026

# %% [markdown]
# ###Detailed Notes
# ### 04:00->25:00 Assignment Q1 Attempt
# * Due Date 2nd Feb 2026
# 1. Reference book for understanding problem solving?Mathematics for Machine Learning book with solved examples, Pattern Recognition by Bishop, Murphy
# 2. Do we have to submit the attempted answer?we should submit for assignment
# 3. Should we do hand written scans or Latex?handwrittten or Latex either should be fine
# 4. Guidance for solving problem?1. take log of likelihood function, take derviative set to 0 thn we will get alpha, 2. Find E(x), we will equate with X-
# 5. Should we take derivate wrt x only? wrt to alpha
# 6. What is meant by estimating function at each point?Likelihood function L(alppha)=pi(i=1,n)f(xi)
# 7. How do we calculate E(X) for large domain range?
# 8. alpha comes in term of x? yes
# 9. MoM is big integration? Use gamma integral
# 10. Why derivative of alpha is taken?we want to find estimate of alpha
# 11. If such formula comes, it will be given in exam? to check with faculty
# 12. Which order of moments in MoM?first order, E(X)
# 13. Why gradient descent is not used? it is used for maxima, minima.
# 14. Is MLE always defined as product of terms, how is it for continuois function? it is defined for intreval 0, inf, we are picking sample so we are taking discrete
# 15. Explain Method of Moments?We have to find E(X) after that we equate with X- and solve for alphan
#
# ### 25:00->33:30 Assignment Q1 Explanation
# * formulate likelihood function for n sample
# * take log of L
# * Diff wrt alpha and set=0
# * Solve for alpha
# * MoM, E(X) equate to x- and solve for alpha
# * Use gamma integral for solving integral
# 1. Both estimate for MLE and MoM came same by chance or always same? by chance, it may not be same
# 2. In practice MLE is better estimator? yes
# 3. Are all distribution applicable for MLE and MoM? yes, description will be given in exam if discussed
#
# ### 33:30->43:30 Assignment Q2 Attempt
# * Estimator is unbiased if E(X)=mu
# 1. Do we have to use any esimtator, or we will be informed what to use? go with the problem question
# 2. Is estimation isbiased, then problem is over and we dont have to chekc variance?yes
# * Find E(thetaMr) and E(thetaMrs)
# 3. We take samples of sampling mean and then we consider estimator as true estimator of population mean, it will not be applicable for samples directly?E(theta) is called sampling mean
#
#
# ### 43:30->54:30 Assignment Q2 answer
# * Check unbiasedness
# * If both are unbiased estimator, we chose one with lower variance
# * unbiased estimator hits true value on average
# * smaller variance->more stable estimates
# * by finding E, both are unbiased. We go for test of variance
# 1. Here covariance is zero as these are independent?yes
# * Computing variance we get theta Mr is less, so it is the better estimator
# 2. How to calculate MSE?Ref to Lecture notes, in this we do not calculate MSE
# 3. What to do when biased?if biased it is not a good estimator
# 4. We checkd for variance becuase both came as unbiased?yes
# 5. Ig both are biased which is better?both are not better
# 6. Can we take variance and compare in the previous case?yes
# 7. In Var we have E(x), then Var comes same for both?to check and come back
#
# ### 54:30->1:04:00 Assignmet Q6 attempt and soln
# 1. Is this not Q3? no it is Q6
# 2. are there any bounds on a? a is from 0->1
# 3. Since C1 and C2 bar, will summation follow distribution proerpty? yes
# 4. E(C1 and C2) is mu? yes
# 5. we should calculate only for mu?yes
# 6. Will we have PCA tutorial?not known, to be done by next week
# * Answer comes to be unbiased
#
# ### 1:04:00-> Assignment Q9 attempt
# * for one variable we take diff wrt x and equal to 0 and maxima minima told by double derivative
# * In this example we have to use partial derivative
# * Solve fx, fy=0
# * Calculate Hessain Determinant fxxfyy-(fxy)^2
# * D< 0 -> saddle point
# * D>0 and fxx>0-> minima, fxx< 0-> maxima
# 1. Should we find eigen value?no, we are finding determinant
# 2. Are we checking convex or not?
# 3. D is evaluated for positive or negative definite?D is the determinant
# 4. What are x,y the stationary point? (0,0),(3,3),(-3,-3)
# 5. are we sloving the equation from gradient?yes
# 6. 3,3 and -3,-3 will be minima and 0,0 be stationary point?yes
# 7. 0,0 is saddle and not stationary?yes
# 8. How to find if a saddle point?find D if < 0 its saddle pt.
# 9. D< 0 it should be maxima for saddle point? no
# 10. What is D?It is Hessian determinant
# 11. How can we comment with D, if eigen values reverse in sign?concept should have  been discussed
# 12. shouldn't d=0 considered the saddle point?no it is indeterminate
# 13. 0,0, D< 0, it is saddle point?yes
# 14. if one value is +ve and other -ve, it is called a saddle point?yes
# 15. Should we describe nature of function?described in terms of maxima, minima
# 16. Q3 link is not needed?yes, but question is omitted
# 17. Do we have to use programming? yes
# 18. Whether we will have prog question in midsem?mainly derivate based
# 19. Will we have more tutorials? no, there will be regular class

# %% [markdown]
# ## Week 3 Lecture 2 on 21th Jan 2026

# %% [markdown]
# ### Detailed Notes
# ### 01:00->05:30 Reacap - constructing set of ortonormal eigen vectors
# * Sum of geometric multiplicities adding to n
# * Any two eigen vectors are orthonormal
#
# ###05:30->24:30 Optimization Problem
# * ||x||=1 and ||Ax||^2 is max
# * Expanding ||Ax||^2 as (Ax)^TAx
# * ||Ax||^2=c1^2sig1^2+..cn^2sign^2
# * Largest eigen value islambda1 and largest singular value is sigma1x
# * ||Ax||^2<=c1^2sig1^2+..cn^2sig1^2 as sig 1 is largest
# * taking sig1^2 outside we get ||Ax||^2<=sig1^2
# 1. Why are limiting to 1-D?That is the solution to the problme, if x=v1 then sig1^2 is the solution
# 2. Can we take x=v2 as the solution? if we take the subspace formed by basis {v2,..vn}
#
# ### 24:30->33:00 Data Matrix
# * X is data matrix, columns are features(p), rows are samples(n)
# * Centring Matrix ->H=In-1/n(1n1n^T)
# * Centred Data Matrix -> Xc=HX
# * Example for Cented Data Matrix
# 1. Is this similar to removing the intercept term for OLS equation? depedns on whether we want to remove the intercept term in the linear regression
# 2. If we consider we want intecept term, can we do the centering of the data?this is done for PCA
# * PCA is equivalent to Total least square regeeression where all measurement are noisy
# * Each column sum is 0,
# 3. What is the operation x^?it is the sum of the rows of the Centered data matrix, called as sample mean of the centered data matrix
#
# ### 33:00->42:30 Projection of vector onto another vector
# * proj(v on u)=(v.u/u.u) u
# * Signed magnitutde of project=v.u assuming ||u||=1
# * Scatter plot of the data centered around the origin
# * which is the direction that preserves the maximum variance when I project these data points onto this direction, then the variance will be maximum which is the first pricipal component
# * The second princple component will have a lower variance
# * PCA is an algorithm that preserves the variance as much as possible
# * If the projection of a point on the principal axis, then the variance of these points will be maximum
# 1. Are there 2 principal axis X1 and X2? Yes, as this is 2-D data, for higher dim data there will be as many principal components as Ax^Tx
# 2. Variance will be maximum on X1? No, projection of the data points on the principal axis will give the maxmimum variance
# 3. How do we determine the solid lines? to be covered
# 4. Is there a comparison bt. the variance of the projection onto PC1 and 2? Yes to be covered later
#
# ### 42:30->58:00Variable Transofrmation
# Xc centered matrix is multiplied with unit vector u
# 1. Is Xc multiplied with u or X? Xc the centered matrix is multiplied
# 2. Why is x.u multiplied?this is only for illustration, not relevant to data matrix
# 3. Is u principal axis? no its an arbitrary vector
# 4. In variable transformation, are we taking projection on u? yes
# 5. The signed magnitude projection, why is mod u added?to make representation as v.u where mod(u)=1 for unit vector
# 6. Should we have dimension=no of features? yes, otherwise matrix vector multiplixaiton will not work
# * Mean of transformed variable y=0
# * Variance of transformed variable y=u^TSu
# * S-> Sample variance-covariance matrix
#
# ### 58:00->1:16:00 PCA Objectives
# * Maximize variance of projection of all samples on u
# 1. What is the 2 mod? it is the 2-norm
# 2. Why we want to maxximize variance?Principle axis is a linear combination of the features, maximum variance relatest to relevant data
# 3. Is it a kind of dimension reduction?Yes
# * Principle axis is the eigen veactor of the covaraince of the matrix
# 4. When say var=lambda is there any proof?Already proved
# * maximum possible value is lambda1
# 5. What is arg?solution to the objective function u^TSu is arg max
# * Second principle component uTu1=0
# * uk will be orthogonal to other uj
# 6. Restrict in the sense are we considering that vector?we are restricting such that the subspace is orthogonal to u1 for u2, both u2,u1 for u3
# 7. Taking orthogonal to u1 how does that restrict that space?plane spanned by only u2 orthogonal to u1
# 8. Is this followed by Grah-Schmit? this is preceeded by Graham smith
#
# ### 1:16:00->1:28:30 Eigen values/vectors of S matrix
# 1. Is Centering a crucial step?yes, otherwise sample covariance cannot become 0
# 2. In actual data variance is not in the orthogonal direction, how will it affect the PCA?if eigen values are distinct all eigen vectors are orthogonal, there is no possibility of non orthogonal , data matrix is not a symmetric data matrix, but covariance matrix is symmetric.
# 3. the number of possible PA is eqaul to total number of eatures?yes
# 4. we will apply only when data points are more than the number of features?no, this will reduce the number of features. Samples are usually large. reducing features by retaining max variance
# 5. PCA related to SVD?SVD to find the eigen vectors
# 6. we can do dimensionality reduction with PCA and SVD? with SVD there is another way of reduction
# 7. What is SVD? Singular Value Decomposition
# 8. Why do we need to center the data? in SVD it is not needed, PCA is to find the eigen values of covariance matrix. We need to center the data to find the covariance matrix
# 9. Xc, SVD and PCA will differ by a factor of 1/N-1?yes
# 10. Is this a reversible process?yes if we have all the principal components, PCA is rotation of data.
# * If data for PCA var is high it is a good apprx of original data
# 11. If we project PCA towards k dimensions, can we get back original data?no, as we truncate
# 12. PCA to tackle multi colinear regerssion models, the interpreation gets lost? yes, PCA is not a feature and cannot be intrepreted as one. It is a linear combination of features
#
# ### 1:28:30->1:38:00Objective Function Value
# * Max value is lambda1 of S
# * Variance explained by ith component is lamdba1 of S
# * Total variance is tr(S)
# * Fractional variance lambdai ofS/total variance
# 1. Should we be more intrested towards the v1, v2 component?v1,v2 is the direction, eigen values gives the variance of data captured. Both eigen values and eigen vectors are important
# 2. lambda1S=lambda1/N-1?yes
#
# ###1:38:00->1:50:00 PCA Scores Matrix
# * U=[u1 u2 .. uk] first k principle components
# * T=XcU is Scores matrix
# * T is projection of samples onto Xc
# * U^TU=I as eigen vectors are orthonormal
# 1. Will we look at probabilistics PCA? No
# 2. What is a scores matrix, where is this used?length of each data point on the principal axis. We will unerstand usage better in lab
# 3. Will in-class quizzes be conducted for PCA? Not by Dr. TS

# %% [markdown]
# ## Week 3 Lecture 1 on 20th Jan 2026

# %% [markdown]
# ### Detailed Notes
# ### 02:00->07:00 Homogenous Linear Equations
# * If an only if works both ways
# * Ax=0 has non-trivial solution if columns are linearly dependent
# * non-trivial solution is non zero solution
# * Ax is a linear combination of the columns of A
# * If linearly independent x=0
# * A need not be square matrix
#
# ###07:00->14:00 Detemrinants
# * Exchange two rows, value changes sign
# * Add row to another row, no effect
# * multiply row by scalar, value multiplies with constant
# * If we do row operation,det value zero to non zero and vice versa cannot happend
# * Det of I matrix is 1
#
# 1. Most of the ML problem, the matrices will not be square why do we study square matrix? Co variance matrix is square
#
# ###14:00->16:30 Homogeneous Linart Eqns. - Square Matrices
# * cols are linearly independent det is non zero, zero if dependednt
# * Ax=0 has non trivial soln if det(A)=0
#
# ###16:30->18:00 Rank Nullity Theorem
# * Nullity - dimension of its null space, how many basis vectors required to spane the space
#
# ###18:00->29:00 Eigen Values and Eigen Vectors
# * x=0 is not a valid eigen vector, as lambda can take any value
# * If lambda =0, x belongs to null space
# * A has to be square
# * Eigen values are roots of the characteristics equation
# * Geometric multiplicity
# * Algebric multiplicity - repeated eigen roots, 1 if all are distinct
# 2. Where do we use geometric and algebraic multiplicity? to construct a set of orthonormal vectors
# * Dimensionality of eigen space for lambda=0 is dimension of null space
# * For each eigen value geometric multiplicity is the dimensionality of the eigen space
# * Geometric multiplicty<=Algebraic multiplicty
#
# ###29:00->54:00 Symmteric matrices
# * A=A^T
# * Symmetric matrix should be square
# * All Eigen values of real symmetric matric is real
# * All eigen vectors of distinct eigen values are orthogonal
# * theorems:
# * A belongs F nxn said to be diagonizable is there exists invertible matrix P belongs to Fnxn auch that A=PDP^-1
# * Columns of P are the eigen vectors and D is the diagonal of the eigen values
# * P is orthogonal iff P^T=P^-1
# 1. Is P orthogonal or orthonormal? rows and columns are orthonormal vectors, matrix is orthogonal
# 2. For a sqaure matrix left and right inverse will be same, can we say PP^-1=I, PP^T=I
# 3. When we say orthogonal, we say d product is zero, how it works now? off diagonal elements are zero so orthogonal
# * Spectral Theorem - A real symmetric matrix is orthogonally diagonizable
# * Square matrix is diagonizable iff geo x = alg x
# 46:30->48:30 - Interrupt
# 4. What is algebraic multiplicity? number of times a root gets repeated
# 5. Why is alg x and geo x same for a symmetric system?It is a theorem and can be proved
# 6. Will these concepts be used for PCA?Yes
#
# ###54:00->1:21:30  Constructions of Orthonormal eigen vectors for a nxn symmetric matrix A
# * CReate a set of basis vectors that is the eigen vectors of the matrix
# 1. why do we need orthonormal? Because for optimization we restrict to unit circle as we cannot compare vectors of different length
# 2. how does unit circle help? it helps in comparing
# 3. In case of ML we will have both numverical and categrorical featuve, how will it help here?to be taken later
# * For each eigen space, we can construct a set of orthonormal vectors
# 4. if eigen vectors are v1,v2 and they are not orthogonal, in 2-D plane we take any 2 vectord that are othongonal are they eigen vectors?Yes
# 5. If we had to choose orthonormal baasis, why do we choose from eigen spaces? becauses we will need eigen values of A^TA
# * Positive Semi Definite matrix-> for any vector x x^TAx>=0
# * Eigen values are non-negative
#
# ###1:21:30->1:33:00 Singular values
# * rt(lambda) is the singular value of A, lamdba is eigen vector of A^TA
# 1. What is x=c1v1+c2v2+..cnvn? representation of x as the combination of orthonormal basis
# 2. Eigen vectors are the basis for the eigen space, how does that spans Rn? Beacuse eigen vector of distinct eigen values are orthogonal
# 3. Why x^Tx=1? Because its a constraint that is considered
#
# ### 1:33:00->1:43:30 Post Class Summary
# * PCA to be covered
# * Construct a set of orthonormal eigen vectors for a symmetric matrix is used for PCA
# 1. We are intrested in symmetric matrix because it appears as a Hessian in optimization? becuase we are intrested in the co variance matrix

# %% [markdown]
# ## Week 2 Lecture 2 on 14th Jan 2026

# %% [markdown]
# ### Detailed Notes:
# ### Work in Progress
# ### 02:00->05:00 Recap
# * Parameter estimation, Std. error, variance, bias
# * Mean square error (MSE) E[(theta^-theta true)^2]
#
# ### 05:00->11:00 Bias Variance Trade-off
# * MSE=Var+Bias^2
# * Comparing two estimators -> realtive effeciecny of estimators
# MSE(theta1)/MSE(theta2)
# * value should be < 1, theta 1 is taken as most effecient
# * Is this sepcficially for cross validation?to find MSE we need theta true and if two parameters are known we are done. However in ML problems, estimates are derived from data Eg: a1, a2 if its a model, if its a distribution, we estimate the paramere eg: mu and sigma of gaussian. If we get a better estimator how can it be characterized without theta true and one of the way is to use relative effeciency
#
# ### 11:00->24:30 Method of Moment
# * Not popularly used in ML
# * Kth moment is E[(x^k)] if k=1->mean
# * Set of random samples from certain dsitributions and unkonw parameters
# 1.  Is moment expected value? Kth moment is E[(x^k)]
# * equate populatin moment with sample moment
# * Data x1,x2,..xn is from an exp function , lambda is unknown
# * Estimation lambda using MoM lambda=1/E[x]
# * One of the methods of parameter estimation
# 2. Why is 1/lambda=mean? that is the theoretical definition of mean for a exponential distribution. Given a sample data, compute mean using sample mean formula and equate to theoretical mean to find parameter estimates
# 3. by doing this are we getting unbiased moment estimators?typically properties of moment, it will lead to unbiased estimates under certain assumptions, most of them are asymptotic properties(requires a larger dataset)
# 4. Will finite data points provide biased estimates?yes
#
# ### 24:30->1:11:30 Maximum Likelihood Estimation
# * Observations X1,X2..Xn belonging to f(x,theta).
# * Construct a likelihood function L(theta)=L(theta/x1,x2,..xn)=f(x1,the)f(x2,the)..f(xn,the)
# * L(the) likelihood function
# * f(x/the)=f(the/x)f(x)/f(the)=likelihood*prior/normalizing factor
# * max(the) L(the)-> Maximum likehood estimator
# * =max(the) pif(xi,the)
# * f,xi-> known, the-> unknown
# * Example for MLE xi~Bernoulli. PMF f(x,p)=p^x(1-p)^(1-x) x=0,1
# * MLE max L(the)=f(x1,the).f(x2,the)..f(xn,the)
# * =p^sum(x)(1-p)^(n-sum(x))
# * find first order derivative wrt p which is same as first order derivative of lnp and equal to 0
# * from p values verify second derivative is < 0 for maximum
# * In Gaussian we look at max mu, sigma, we diff wrt to mu and sigma^2
# 1. If we have distribution known, MLE will be ebst option to find parametrs or depends on the data? there are multiple estimator mostly its MLE, it is easier to show that particular method leads to MLe estimate then all estimates from MLE are valid. MLE does not require dist. of theta
# * Example of D{xn,yn} and applying MLE
# * Properties: for large n it leads to ubiased estimates
# * Var of the^ is as small as any other estimator
# * Least square objective function is one of the widely used objective functions
# 2. Can we say MLE is MVUE for large n?not always as MVUE doesn't speak about large n
# * Estimator is a function of data
# * Invariance property
# the1,the2,..thep->h(the1,the2,..thep)
# then MLE also implies
# the1^,the2^...thep^->h(the1^,the2^...thep^)
#
# ### 1:11:30->1:40:00 Bootstrap estimation
# * Non-parametric approach of estimation
# * No need of assumption of underlying distribution
# * Use sampling with replacement strategies
# * compute sample means and aggregate
# * Example: 1- Data set and B bootstraps and n data points, comput B measure of statistics(Eg: Mean) and find the global bootstrap mean values
# * Why better than MLE? distribution is not known
# * When you have small data set, bootstrap works very well
# * Also helps in lower varaiability of each of the parameter we have estimated without worrying about underlying distribution
# 1. For each bootstrap how many data points? same as observation, collect data points after reaplacement
# * For large n Bootstrap can be computationally intensive, unless the underlying distributions are known
# 2. If 100 observations, have many observations to select? 100 itself but sampled after replacement
# 3. will this be unbiased estimator?difficult to prove for bootstrap, not all the time. For large number of samples and bootstrap it maybe but due to replacmeent, it might cuase bias
# 4. problem with bootstrap is non-deterministic? all approaches are stochaistic and is not sepcific to bootstrap, detemrinistic is established via distributions
# 5. for MLE we run multiple times we get same but not for bootstrap?since MLE solves some optimization, it can lead to local minima. Bootstrap is another optimizer used under certain conditions. MLE looks at data point only in one way and Bootstraps can look at different views of data
# 6. When bootstrap results in lesser variance what are we comparing with?by using anothe estimator, bootstrap is a better way to get less variability in estimated parameters.
# 7. When we create samples and fit a model again we will be using MLE?If model is known, MLE is safer route but if MLE cannot be constructed, we have to look at alternatives
# 8. compared to MLE and MoM, bootstrap computation will be higher?Yes
# 9. We wont be using fitting algorithms in Bootstrap, so that computation will be saved in using bootstrpping? depedns on how you are stimateing, in general bootstrping will have relatively more computation which may not be the case in MLE, MoM
# 10. Since we dont understand the undelying distribution, does bootstrap follow CLT and this gives a gaussian distribution? No, all these are sampling properties
# 11. For variance why is 1/B-1 is used?DOF correction, we are using X- is computed from data and this data has 1 DOF less so we subtract also signifying Bessel's correction
# HW: Compare MLE estimate of variance with bootstrap method computation
# 12. Are we considering sample as population? No

# %% [markdown]
# ## Week 2 Lecture 1 on 13th Jan 2026

# %% [markdown]
# ### Detailed notes
# ### 03:00->05:00 Recall
# * GD and KKT
# * Stochositic and mini batch GD
#
# ### 05:00->34:00 Probability
# * Introduction
# * Experiments, Variability, Random Phenomenon, Random Experiment
# * Sample space and events, Concept of Counting(Permutation and Combination)
# * Exclusive and Independent events
# * Indepenent events is the cornerstone for analysis, feature assumptions etc.
# * Different types of events-Union, Intersection, Null, Difference, Complement
# * Probability measure
# * Aximos P(S)=1, 0<=P(A)<=1, P(AnB)=P(A)+P(B) (mutually ex. events)
# * Conditional probability-> xi: features yi:labels
# P(yi/xi)
# * Bayes' formula
# * Used for estimation and computing conditional probability
# * Indepenedent events, joint distibution, random variables
# 1. are proabaility measure and random variables the same?RV maps samples space to R for event A, P(A) gives probability. RV maps values -Inf to Inf, P(A) take values from 0 to 1
# * Probabiltiy density function-> probability defines as area under the curve bt. two points
# * Cumulative distribution function P(X<=a), Expected value, spread, variance and standard deviation, co-variance
# * co-variance of independent events is zero
#
# ### 34:00->48:00 Distributions
# * Distributions - Binomial, Poission and Normal, Chi-square
# * Mean, Variance of sample
# * n->Inf sample->population mean
# * Central Limit Theorem
# * distribution with finite mu and Inf sigma - Cauchy cenral limit theorem cannot be directly applied there is a separate Central limit theorem
# * Cauchy has both mean and variance undefined
# 1. Where do we use Cauchy distribution?spectroscopic and communication
# 2. Is it used in machine learning? Not much, maybe in Deep learning
# * CLT is for dist. for finite mu and sigma. RV should be independelty and finitely distributed
# * with large enough samples, summation of RVs tends to normal distribution
# * Sample statistics - mean,median and mode
# * Spread - sample variance and data
# * Examples to calculate
# * Sample correlation coeffecient (spearman's coeffecient)
# * Percentile, quartile
#
# ### 48:00->56:30 Safari
#
# ### 56:30->1:07:00 Parameter Estimation
# * reasonable value/range of certain quantities
# * Modeling ML/AI-> parameter values for predictions
# * How good parameters estimates are
# * Estimate parameters of distribtuin and parameters of models of data
# * Goodness of fit for parameters is important otherwise model performs poorly
# * Central idea of estimation parameter is to come up with closest of estimation
# * process of estimation is called estimator
# * done using mathematical map
# * i/p data + objective/loss function, constraints -> values of parameters of the model (theta^)
# * How far estimate is from the true parameter
# * Types ->point estimator(majority), interval estimator, others(non-parametric, parametric and semi parmaetric)
# * Xi feature is a random variable and independent events
# * Random sample should represent the population and should be Bias free
# * Statistics-> function of observation in random sample
#
# ### 1:07:00->1:22:00 Point Estimator
# * Random sample X1,X2...Xn. f(x,theta)->density function
# * theta-> unknown parameter in column vector form
# * Normal dist. -> theta=[mu;sigma^2]
# * Estimator-> i/p Objective function, data, f(x,theta), o/p mu, sigma^2
# * Properties of estimator-> Accuracy, Precision
# * How does n affect value of estimate?
# * Unbiased estimator for theta if E(theta^)=theta true
# * Bias of an estimator b=E(theta^)-theta true
# 1. If point estimator of theta^ follows the same distribution of theta, then is it unbiased?No
# 2. When we dunno the true value how do we calculate the bias?we will not, Used for theoretical study to see if a process leads to bias. Unbiased estimator is considered a true value
# 3. Are there cases where biased estimators will be used for any reason?yes there are, if cost of unbiased estimator is very high then trading off variance we go for biased estimator
# * Variance of a point estimator-> for two estimator with diff variance choose one with minimum variance
# * for a point estimate we prefer minimal varinace unbiased estimator
# * MVUE - Minimum variance Unbiased estimator->esitmator with minimum variance given a set of estimators
# * Next class - Bias variance tradeoff
#
# ### 1:22:00->1:31:00 Post class discussion
# * Lecture Notes sharing
# 1. Can the final exam weightage be distributed? No
# 2. Will the portions be cumulative or incremental? Mostly incremental but related question can occur from previous modules

# %% [markdown]
# ## Week 1 Lecture 1 on 7th Jan 2026

# %% [markdown]
# ### Detailed Notes:
# ### 0:00->11:00 Course Introduction
# * Learning Objectives and Prerequistes
# * Practical Applications will be studied in DAL
# * 12 Credit course
# * Credits, Lectures and Grading policy
# * Assignments top 8 scores out of 10
# * No extension of assignment/quic deadline
# * No step marking in any part of course
# * Effort deosn't carry weightage, results do
#
#
# ### 11:00->35:00 Course Syllabus
# * Module 1: Unsupervised learning
# * methods to perform point estimation.
# * ML invovles estimation based on data
# * Module 2: Supervised learning
# * Learning based on Labelled data
# * Problem 1: function appx-> classification.regression
# * Problem 2: Non linear regression
# * Module 3: Binary Classification
# * Challenges wrt complex models that is decision Trees, CART
# * Bias-Variance tradeoff helps in reducing overfitting, used for small models, doesn't matter ofr DL or large models
# * If we know the truth how far we can be optimal - Bayesian Decision theory
# * Generative vs Discriminative, cases when they are equivalent
# * Module 4: Advanced Methods for Classification
# * Module 5: Sequential Decision Making(if time permits)
#
# Text books:
# e-copies available for both
#
# * Can notes be available before class?
# 1. Provide ref. material for each topic and provide notes.
# 2. Look out for typos(intentional/non-intentional). Provide ref. against topic.
# 3. Week wise division of topic to be provided
# * Will we be informed in advance for quiz? in class, best 8 out 10 taken to consider absence, overwhelming quizzes will be asked as assignments
# * Consideration for International students attending outside IST hours?Expected to attend the classes regularly, if someone issue write separately
# * Can it be intimated at the start of lecture?To be decided on how to address. Expected to assume everday is quiz day. Quiz can be attempted from phone
# * How will the in class quiz be facilitated?Learning Mgmt system is not yet decided. More like MCQ. If notes are required then submission will be provided till night. normally 5-6 mins for quiz
# * Whether any link will be provided for quiz? yes
#
# ### 35:00->41:00 Class setup
#
# ### 41:00->48:00 Overview Optimization Methods
# * Unconstrained vs Constrained
# * Linear programming(LP)
# * Quadratic programming(QP)
# * Non-Linear programming(NLP)
# * Numerical Optimization Techniques
# * Optimization elements
# 1. Linear function-> follows superposition
# f(ax1+bx2)=af(x1)+bf(x2)
# 2. Convex function
# f(ax1+(1-a)x2)=af(x1)+(1-a)x2, a~[0,1]
# 3. Non linear functions
# Eg. f(x)=xTQx is quadratic and non linear
# * f(x)=y=mx+c doesn't statisfy linear property 1
# * c=0 -> linear function c!=0 -> Affine linear function
# * Is any convex function affine? no
# * affine can be transformed into a linear one
#
# ###48:00->1:02:00 Optimization
# * ML or DL are formulated as mathematical optimization
# * Select best option from available set
# * ML always min of loss function f(x)
# * dual of max and converted using sign changes
# * constraints Ax<=b-> linear, g(x)<=0-> non linear, x>=0
# * x-> parametrs of model, distributions or joint/conditional distributions, decision variables
# * g(x) can be linear? defined to be non linear, categorized for convenience. To give a more general formulation
# * f(x)-> cost/loss/objective function
# * can there be equal to 0 constraints?yes
# * can g(x) be >0? yes, but we will write std. form by negating and make it less than. Done to perform optimization seamlessly
# * Types->Linear, quadratic, non linear programming
#
# ### 1:02:00->1:04:00 Unconstrained optimization
# * max f(x) for x
# * f(x) be continuously differentiable
# * 1st(=0) and 2nd(<=0) order necessary consdition
# * is the static optimization same as unconstrained optimization? Yes
# * In case of several variables we have to go for KKT
#
# ### 1:04:00->1:20:30 Constrained optimization
# * Equality constraints and Lagrangian function
# * KKT
# * first order necessary, grad(Lagrangian)
# * second order necessary
# * Lagrangian must be PSD in a tangent space
# * KKT applies to equality and inequality ocnstraints
# * for equality and inequality constraints,need to worry about all inequality sontraints but the constriants which are active ie. gj(x)=0 at any pt. x
# * A set of all active constraints at x A(x)
# * A(x) should satisfy LICQ-Linear independence constraint qualification
# gradhj and gradgj for all j in A(x) are linearly independent
# * for ineq, if g(x) is active then mu is 0 and vice versa(complementary condition)
# * When we practically solve ML problem are all formulated as KKT?Data and problem exists which should be formulated accordingly. Mostly solved by prexisting libraries with situations where librarires hasve to be developed
# * Should x* come for mu as it is not a function?it should not come, but shown to be muj at x*
#
# ### 1:20:30->1:34:00 Optimization in ML and DL
# * Max or Min Objective function
# * DL-> tweak the wieghts and improve performance
# * Gradient descsent grad < 0 increment w, >0 decremnt w, optimum grad=0
# learning rate
# * too big->osciallation diverges
# * too small->long time to convergence
# * small rate when near the min, large rate when far away from min
#
# * How will we know we are near the minimum?examine loss function by doing learning rate x grad then decide learning rate (eta scheduling)
# * When the methods of geometry and statistics fail we use gradient descent? yes
# * Does gradient decent always move towards the minima?by definition yes, but realistic objectove functions can be complex
# * Types of GD
# * Batch, Stochoistic, Mini-Batch(use for NN and DL, typical size of 50 or 256 are used)
#
# ### 1:34:00->1:47:00 Post Class queries
# * Shouldn't Stochaistic GD take a long time as we use only one data point over all samples?certain applications like streaming will give data one by one while normal GD will lead to high memory use when considered many at a time
# * what are the convergence speed across the three? Stochaistic can give a poor performance, usually normal GD converges faster
# * Is Stochoistic GD considered computationaly effecient? yes as only one point of the set is used at a time, it is a tradeoff bt. computation and convergence
# * What is DL? Deep Learning
# * ML is used when features are defined and DL is used when features are not defined? No, Features are always known. ML requires feature engineering, DL does that on its own.
# * Is there are any spillover bt. ML and DL? No spillover, both will be different.conceptually same but techinques are different
# * is there any provision of hybrid approach for GD?eta scheduling is separate consideration, Mini-batch is the hybrid approach
# * For Batch GD, we are using all the dataset, will it guarantee always global minima?Not necessarily, it is not guaranteed

# %% [markdown]
# ###Mid-Sem Notes
# Clustering Definitions:
# 1. Centroid
# 2. Raduis of Cluster
# 3. Diameter of Cluster
#
# Clustering Approaches:
# 1. Partitional Methods
# * K-means
# * K-medoids
# * PAM (Partition around medoids)
# * CLARANS (Clustering Large Applications based upon RANdomized Search)
# 2. Hierarchical Methods
# * AGNES (AGglomerative NESting hierarchical clustering algorithm)
# * DIANA (DIvisive ANAlysis clustering algorithm)
# * BIRCH (Balanced Iterative Reducing and Clustering Using Hierarchy)
# 3. Density-based methods
# * DBScan (Debsity-Based Spatial Clustering of Applications with Noise)
# * OPTICS (Ordering Points To Identify the Clustering Structure)
# 4. Graph Based
# * Spectral theory
#
# K-means Algorithm
# 1. Choose k cluster centers
# 2. Assign instance to clusters
# 3. Recompute Centroids
# 4. make centroid as cluster center and go to step 2 until convergence
#
# K-means critique
# 1. Local optima
# 2. Works only for numeric data
# 3. Does not scale well to large datasets
# 4. Pre-specify number of clusters
#
# Knee method
#
# K-means pitfalls
# * pts that lie on the boundary (think fuzzy)
# * ellipsoidal clusters to better accomodate width and breadth of cluster
#
# Inter Cluster Distance definition
# 1. Single Link - smallest distance bt. pt in one cluster and pt. in another cluster
# 2. Conplete Link - largest distance bt. pt in one cluster and pt. in another cluster
# 3. Average - average distance bt. pt in one cluster and pt. in another cluster
# 4. Centroid - distance between centroids of 2 clusters
# 5. Medoid - distance bt. medoids of 2 clusters
#
# Quality of Clusters
# 1. Purity
# 2. Entropy
# 3. Rand index
# 4. Silhouette score
# 5. Dunn Index
