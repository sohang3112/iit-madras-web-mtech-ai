# %% [markdown]
# ### Question 5 -- WIP

# %%
import numpy as np
data = np.array([
    [144 ,0.6 ,10],
    [89 ,1.0 ,10],
    [59 ,1.4 ,10],
    [278 ,0.6 ,20],
    [167 ,1.0 ,20],
    [141 ,1.0 ,20],
    [164 ,1.0 ,20],
    [129 ,1.4 ,20],
    [259 ,0.6 ,30],
    [245 ,1.0 ,30],
    [214 ,1.4 ,30],
])
X = data[:, 1:]
y = data[:, 0]
Z = (X - np.mean(X, axis=0)) / (np.max(X, axis=0) - np.min(X, axis=0))
Z
# Out:
# array([[-0.5, -0.5],
#        [ 0. , -0.5],
#        [ 0.5, -0.5],
#        [-0.5,  0. ],
#        [ 0. ,  0. ],
#        [ 0. ,  0. ],
#        [ 0. ,  0. ],
#        [ 0.5,  0. ],
#        [-0.5,  0.5],
#        [ 0. ,  0.5],
#        [ 0.5,  0.5]])
