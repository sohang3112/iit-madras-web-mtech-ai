# %% [markdown]
# GEMINI SAYS:
#
# In standard DQN, the target network both selects and evaluates the action:
#
#
# $$y_t = r_t + \gamma (1 - d_t) \max_a Q(s_{t+1}, a; \theta^-)$$
#
# In Double DQN (DDQN), the **online network** selects the action, while the **target network** evaluates it:
#
#
# $$a^* = \arg\max_a Q(s_{t+1}, a; \theta)$$
#
# $$y_t = r_t + \gamma (1 - d_t) Q(s_{t+1}, a^*; \theta^-)$$

# %%
import gymnasium as gym

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.vec_env import VecMonitor
from gymnasium.spaces import Discrete, MultiDiscrete
import numpy as np
import gymnasium as gym
import torch

from pprint import pprint
from copy import deepcopy
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from industrial_inventory_env import (
    IndustrialInventoryEnv,
    generate_student_config,
    public_config_summary,
)

np.set_printoptions(suppress=True)

# %%
ROLL_NUMBER = "DA25M622"

student_config = generate_student_config(ROLL_NUMBER)
config_summary = public_config_summary(student_config)

print("Assigned configuration generated successfully.")
for key, value in config_summary.items():
    print(f"{key}: {value}")
# Out:
# Assigned configuration generated successfully.
# project_version: IITM-6002W-RL-Inventory-2026-v1
# roll_number: DA25M622
# variant_id: V022
# config_fingerprint: 7d77fc79debf206a
# demand_multiplier_profile: [1.0, 1.1, 0.9]
# initial_inventory_profile: [110, 100, 90]
# lead_time_delay_profile: [0.1, 0.0, 0.05]

# %%
class DoubleDQN(DQN):
    # (almost all) code is copied from https://github.com/DLR-RM/stable-baselines3/blob/master/stable_baselines3/dqn/dqn.py
    # (since DQN doesn't expose training hooks, we need to copy the whole train function)
    # except a small change
    def train(self, gradient_steps: int, batch_size: int = 100) -> None:
        # Switch to train mode (this affects batch norm / dropout)
        self.policy.set_training_mode(True)
        # Update learning rate according to schedule
        self._update_learning_rate(self.policy.optimizer)

        losses = []
        for _ in range(gradient_steps):
            # Sample replay buffer
            replay_data = self.replay_buffer.sample(batch_size, env=self._vec_normalize_env)  # type: ignore[union-attr]
            # For n-step replay, discount factor is gamma**n_steps (when no early termination)
            discounts = replay_data.discounts if replay_data.discounts is not None else self.gamma

            with torch.no_grad():
                ############# ONLY THESE 2 LINES CHANGED FOR DOUBLE DQN #############
                # Online net selects action
                next_actions = self.q_net(replay_data.next_observations).argmax(
                    dim=1, keepdim=True
                )
                # Target net evaluates that action
                next_q_values = self.q_net_target(replay_data.next_observations).gather(
                    1, next_actions
                )
                #######################################################################

                # Avoid potential broadcast issue
                next_q_values = next_q_values.reshape(-1, 1)
                # 1-step TD target
                target_q_values = replay_data.rewards + (1 - replay_data.dones) * discounts * next_q_values

            # Get current Q-values estimates
            current_q_values = self.q_net(replay_data.observations)

            # Retrieve the q-values for the actions from the replay buffer
            current_q_values = torch.gather(current_q_values, dim=1, index=replay_data.actions.long())

            # Compute Huber loss (less sensitive to outliers)
            loss = F.smooth_l1_loss(current_q_values, target_q_values)
            losses.append(loss.item())

            # Optimize the policy
            self.policy.optimizer.zero_grad()
            loss.backward()
            # Clip gradient norm
            torch.nn.utils.clip_grad_norm_(self.policy.parameters(), self.max_grad_norm)
            self.policy.optimizer.step()

        # Increase update counter
        self._n_updates += gradient_steps

        self.logger.record("train/n_updates", self._n_updates, exclude="tensorboard")
        self.logger.record("train/loss", np.mean(losses))

# %%
# copied from dqn_training.ipynb -- only class change: DQN -> DoubleDQN
class FlattenMultiDiscreteActionWrapper(gym.ActionWrapper):
    """Maps a MultiDiscrete action space to a single Discrete space."""

    def __init__(self, env: gym.Env):
        super().__init__(env)
        assert isinstance(
            env.action_space, MultiDiscrete
        ), "Wrapper requires MultiDiscrete action space."
        self.nvec = env.action_space.nvec
        # Total discrete actions = product of all dimensions (11 * 11 * 11 = 1331)
        self.action_space = Discrete(int(np.prod(self.nvec)))

    def action(self, action: int) -> np.ndarray:
        # Decode single integer scalar back into a MultiDiscrete vector
        multi_action = np.unravel_index(action, self.nvec)
        return np.array(multi_action, dtype=self.env.action_space.dtype)


# Wrap your environment creator inside the lambda
env_fn = lambda: FlattenMultiDiscreteActionWrapper(
    IndustrialInventoryEnv(
        student_config=student_config,
        scenario_mode="random",
        domain_randomization=True,
    )
)

# Parallelize across 4 environments
vec_env = make_vec_env(
    env_id=env_fn,
    n_envs=4,
    seed=2026,
)
vec_env = VecMonitor(vec_env)

# NOTE: env defined action space MultiDiscrete([11, 11, 11]) in __init__(), but DQN can't work with it so we map it:
# DQN will now see Discrete(11 * 11 * 11 = 1331) action space instead of MultiDiscrete([11, 11, 11])
# without wrapper, previously got error: AssertionError: The algorithm only supports (<class 'gymnasium.spaces.discrete.Discrete'>,) as action spaces but MultiDiscrete([11 11 11]) was provided
model = DoubleDQN("MultiInputPolicy", vec_env, verbose=1)
model.learn(total_timesteps=25000)
# Out:
# /home/sohang/Projects/iit-madras-web-mtech-ai/trimester3/DA6002W_Online&ReinforcementLearning/ReinforcementLearning/RL_ProjectCompetition/RL_Student_Package_2026/.venv-sb3-torch213/lib/python3.12/site-packages/stable_baselines3/common/vec_env/vec_monitor.py:43: UserWarning: The environment is already wrapped with a `Monitor` wrapperbut you are wrapping it with a `VecMonitor` wrapper, the `Monitor` statistics will beoverwritten by the `VecMonitor` ones.
#   warnings.warn(
# Using cpu device
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.17e+03 |
# |    exploration_rate | 0.924     |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 2584      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 200       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 161       |
# |    n_updates        | 6         |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -7.66e+03 |
# |    exploration_rate | 0.848     |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 2293      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 400       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 125       |
# |    n_updates        | 18        |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | -7.7e+03 |
# |    exploration_rate | 0.772    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 2177     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 600      |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 155      |
# |    n_updates        | 31       |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -7.58e+03 |
# |    exploration_rate | 0.696     |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 2033      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 800       |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 157       |
# |    n_updates        | 43        |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -7.61e+03 |
# |    exploration_rate | 0.62      |
# | time/               |           |
# |    episodes         | 20        |
# |    fps              | 2003      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1000      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 141       |
# |    n_updates        | 56        |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -7.48e+03 |
# |    exploration_rate | 0.544     |
# | time/               |           |
# |    episodes         | 24        |
# |    fps              | 2031      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1200      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 152       |
# |    n_updates        | 68        |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -7.55e+03 |
# |    exploration_rate | 0.468     |
# | time/               |           |
# |    episodes         | 28        |
# |    fps              | 2001      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1400      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 116       |
# |    n_updates        | 81        |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | -7.6e+03 |
# |    exploration_rate | 0.392    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 2011     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 1600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 165      |
# |    n_updates        | 93       |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -7.61e+03 |
# |    exploration_rate | 0.316     |
# | time/               |           |
# |    episodes         | 36        |
# |    fps              | 1995      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1800      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 158       |
# |    n_updates        | 106       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -7.69e+03 |
# |    exploration_rate | 0.24      |
# | time/               |           |
# |    episodes         | 40        |
# |    fps              | 1948      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 2000      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 131       |
# |    n_updates        | 118       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -7.79e+03 |
# |    exploration_rate | 0.164     |
# | time/               |           |
# |    episodes         | 44        |
# |    fps              | 1912      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 2200      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 177       |
# |    n_updates        | 131       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.04e+03 |
# |    exploration_rate | 0.088     |
# | time/               |           |
# |    episodes         | 48        |
# |    fps              | 1895      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 2400      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 142       |
# |    n_updates        | 143       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.12e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 52        |
# |    fps              | 1884      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 2600      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 151       |
# |    n_updates        | 156       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.16e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 56        |
# |    fps              | 1886      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 2800      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 135       |
# |    n_updates        | 168       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.22e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 60        |
# |    fps              | 1843      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 3000      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 155       |
# |    n_updates        | 181       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.26e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 64        |
# |    fps              | 1831      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 3200      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 138       |
# |    n_updates        | 193       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.33e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 68        |
# |    fps              | 1814      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 3400      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 180       |
# |    n_updates        | 206       |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | -8.4e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1811     |
# |    time_elapsed     | 1        |
# |    total_timesteps  | 3600     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 185      |
# |    n_updates        | 218      |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.52e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 76        |
# |    fps              | 1779      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 3800      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 167       |
# |    n_updates        | 231       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.62e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 80        |
# |    fps              | 1782      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 4000      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 157       |
# |    n_updates        | 243       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.59e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 84        |
# |    fps              | 1784      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 4200      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 166       |
# |    n_updates        | 256       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.55e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 88        |
# |    fps              | 1785      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 4400      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 170       |
# |    n_updates        | 268       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.52e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 92        |
# |    fps              | 1786      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 4600      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 200       |
# |    n_updates        | 281       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.48e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 96        |
# |    fps              | 1780      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 4800      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 168       |
# |    n_updates        | 293       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.44e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 100       |
# |    fps              | 1774      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 5000      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 151       |
# |    n_updates        | 306       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.44e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 104       |
# |    fps              | 1779      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 5200      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 162       |
# |    n_updates        | 318       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.44e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 108       |
# |    fps              | 1769      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 5400      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 185       |
# |    n_updates        | 331       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.48e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 112       |
# |    fps              | 1772      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 5600      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 151       |
# |    n_updates        | 343       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.48e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 116       |
# |    fps              | 1772      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 5800      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 183       |
# |    n_updates        | 356       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.43e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 120       |
# |    fps              | 1764      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 6000      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 177       |
# |    n_updates        | 368       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.41e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 124       |
# |    fps              | 1760      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 6200      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 168       |
# |    n_updates        | 381       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.43e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 128       |
# |    fps              | 1760      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 6400      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 144       |
# |    n_updates        | 393       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.38e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 132       |
# |    fps              | 1754      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 6600      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 193       |
# |    n_updates        | 406       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.44e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 136       |
# |    fps              | 1749      |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 6800      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 138       |
# |    n_updates        | 418       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.54e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 140       |
# |    fps              | 1742      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 7000      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 181       |
# |    n_updates        | 431       |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | -8.7e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1749     |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 186      |
# |    n_updates        | 443      |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -8.86e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 148       |
# |    fps              | 1753      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 7400      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 154       |
# |    n_updates        | 456       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.03e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 152       |
# |    fps              | 1750      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 7600      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 155       |
# |    n_updates        | 468       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.27e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 156       |
# |    fps              | 1747      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 7800      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 169       |
# |    n_updates        | 481       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.36e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 160       |
# |    fps              | 1750      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 8000      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 150       |
# |    n_updates        | 493       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.24e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 164       |
# |    fps              | 1745      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 8200      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 201       |
# |    n_updates        | 506       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.24e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 168       |
# |    fps              | 1742      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 8400      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 193       |
# |    n_updates        | 518       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.38e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 172       |
# |    fps              | 1734      |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 8600      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 203       |
# |    n_updates        | 531       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.61e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 176       |
# |    fps              | 1728      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 8800      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 226       |
# |    n_updates        | 543       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.65e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 180       |
# |    fps              | 1728      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 9000      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 224       |
# |    n_updates        | 556       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.47e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 184       |
# |    fps              | 1726      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 9200      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 212       |
# |    n_updates        | 568       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.59e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 188       |
# |    fps              | 1727      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 9400      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 162       |
# |    n_updates        | 581       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.78e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 192       |
# |    fps              | 1710      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 9600      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 194       |
# |    n_updates        | 593       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.78e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 196       |
# |    fps              | 1695      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 9800      |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 168       |
# |    n_updates        | 606       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.83e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 200       |
# |    fps              | 1699      |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 10000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 182       |
# |    n_updates        | 618       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -9.89e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 204       |
# |    fps              | 1699      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 10200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 166       |
# |    n_updates        | 631       |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | -1e+04   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1701     |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 10400    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 170      |
# |    n_updates        | 643      |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.01e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 212       |
# |    fps              | 1703      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 10600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 227       |
# |    n_updates        | 656       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.03e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 216       |
# |    fps              | 1709      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 10800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 207       |
# |    n_updates        | 668       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.08e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 220       |
# |    fps              | 1718      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 11000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 171       |
# |    n_updates        | 681       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.11e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 224       |
# |    fps              | 1724      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 11200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 254       |
# |    n_updates        | 693       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.14e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 228       |
# |    fps              | 1729      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 11400     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 215       |
# |    n_updates        | 706       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.17e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 232       |
# |    fps              | 1705      |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 11600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 180       |
# |    n_updates        | 718       |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | -1.2e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1652     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 11800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 217      |
# |    n_updates        | 731      |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.21e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 240       |
# |    fps              | 1647      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 12000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 160       |
# |    n_updates        | 743       |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | -1.2e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1638     |
# |    time_elapsed     | 7        |
# |    total_timesteps  | 12200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 192      |
# |    n_updates        | 756      |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.16e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 248       |
# |    fps              | 1633      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 12400     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 204       |
# |    n_updates        | 768       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.16e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 252       |
# |    fps              | 1627      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 12600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 238       |
# |    n_updates        | 781       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.14e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 256       |
# |    fps              | 1628      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 12800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 169       |
# |    n_updates        | 793       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.15e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 260       |
# |    fps              | 1630      |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 13000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 179       |
# |    n_updates        | 806       |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | -1.2e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1622     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 13200    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 166      |
# |    n_updates        | 818      |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.22e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 268       |
# |    fps              | 1620      |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 13400     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 185       |
# |    n_updates        | 831       |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | -1.2e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1622     |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 13600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 232      |
# |    n_updates        | 843      |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.17e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 276       |
# |    fps              | 1621      |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 13800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 192       |
# |    n_updates        | 856       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.18e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 280       |
# |    fps              | 1627      |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 14000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 186       |
# |    n_updates        | 868       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.21e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 284       |
# |    fps              | 1612      |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 14200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 172       |
# |    n_updates        | 881       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.24e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 288       |
# |    fps              | 1615      |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 14400     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 188       |
# |    n_updates        | 893       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.25e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 292       |
# |    fps              | 1615      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 14600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 202       |
# |    n_updates        | 906       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.28e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 296       |
# |    fps              | 1612      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 14800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 202       |
# |    n_updates        | 918       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.32e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 300       |
# |    fps              | 1611      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 15000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 196       |
# |    n_updates        | 931       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.33e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 304       |
# |    fps              | 1610      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 15200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 197       |
# |    n_updates        | 943       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.34e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 308       |
# |    fps              | 1611      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 15400     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 199       |
# |    n_updates        | 956       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.35e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 312       |
# |    fps              | 1616      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 15600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 240       |
# |    n_updates        | 968       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.36e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 316       |
# |    fps              | 1614      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 15800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 193       |
# |    n_updates        | 981       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.33e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 320       |
# |    fps              | 1615      |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 16000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 229       |
# |    n_updates        | 993       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.31e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 324       |
# |    fps              | 1613      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 16200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 222       |
# |    n_updates        | 1006      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.31e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 328       |
# |    fps              | 1610      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 16400     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 206       |
# |    n_updates        | 1018      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.31e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 332       |
# |    fps              | 1609      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 16600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 212       |
# |    n_updates        | 1031      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.29e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 336       |
# |    fps              | 1608      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 16800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 290       |
# |    n_updates        | 1043      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.28e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 340       |
# |    fps              | 1608      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 17000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 221       |
# |    n_updates        | 1056      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.26e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 344       |
# |    fps              | 1608      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 17200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 231       |
# |    n_updates        | 1068      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.31e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 348       |
# |    fps              | 1609      |
# |    time_elapsed     | 10        |
# |    total_timesteps  | 17400     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 227       |
# |    n_updates        | 1081      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | -1.3e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1611     |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 17600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 241      |
# |    n_updates        | 1093     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# ...
# | time/               |           |
# |    episodes         | 384       |
# |    fps              | 1607      |
# |    time_elapsed     | 11        |
# |    total_timesteps  | 19200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 248       |
# |    n_updates        | 1193      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.28e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 388       |
# |    fps              | 1606      |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 19400     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 220       |
# |    n_updates        | 1206      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.28e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 392       |
# |    fps              | 1604      |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 19600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 219       |
# |    n_updates        | 1218      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.25e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 396       |
# |    fps              | 1603      |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 19800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 191       |
# |    n_updates        | 1231      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.23e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 400       |
# |    fps              | 1599      |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 20000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 164       |
# |    n_updates        | 1243      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.22e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 404       |
# |    fps              | 1596      |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 20200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 202       |
# |    n_updates        | 1256      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.22e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 408       |
# |    fps              | 1594      |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 20400     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 216       |
# |    n_updates        | 1268      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.22e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 412       |
# |    fps              | 1590      |
# |    time_elapsed     | 12        |
# |    total_timesteps  | 20600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 203       |
# |    n_updates        | 1281      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.21e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 416       |
# |    fps              | 1579      |
# |    time_elapsed     | 13        |
# |    total_timesteps  | 20800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 276       |
# |    n_updates        | 1293      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | -1.2e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 1575     |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 21000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 225      |
# |    n_updates        | 1306     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.21e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 424       |
# |    fps              | 1575      |
# |    time_elapsed     | 13        |
# |    total_timesteps  | 21200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 203       |
# |    n_updates        | 1318      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.21e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 428       |
# |    fps              | 1571      |
# |    time_elapsed     | 13        |
# |    total_timesteps  | 21400     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 233       |
# |    n_updates        | 1331      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.21e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 432       |
# |    fps              | 1553      |
# |    time_elapsed     | 13        |
# |    total_timesteps  | 21600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 206       |
# |    n_updates        | 1343      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 50       |
# |    ep_rew_mean      | -1.2e+04 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 1554     |
# |    time_elapsed     | 14       |
# |    total_timesteps  | 21800    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 228      |
# |    n_updates        | 1356     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.23e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 440       |
# |    fps              | 1552      |
# |    time_elapsed     | 14        |
# |    total_timesteps  | 22000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 190       |
# |    n_updates        | 1368      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.27e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 444       |
# |    fps              | 1548      |
# |    time_elapsed     | 14        |
# |    total_timesteps  | 22200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 234       |
# |    n_updates        | 1381      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.24e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 448       |
# |    fps              | 1547      |
# |    time_elapsed     | 14        |
# |    total_timesteps  | 22400     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 243       |
# |    n_updates        | 1393      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.24e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 452       |
# |    fps              | 1546      |
# |    time_elapsed     | 14        |
# |    total_timesteps  | 22600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 204       |
# |    n_updates        | 1406      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.22e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 456       |
# |    fps              | 1544      |
# |    time_elapsed     | 14        |
# |    total_timesteps  | 22800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 205       |
# |    n_updates        | 1418      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.22e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 460       |
# |    fps              | 1543      |
# |    time_elapsed     | 14        |
# |    total_timesteps  | 23000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 193       |
# |    n_updates        | 1431      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.24e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 464       |
# |    fps              | 1544      |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 23200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 237       |
# |    n_updates        | 1443      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.22e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 468       |
# |    fps              | 1545      |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 23400     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 162       |
# |    n_updates        | 1456      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.22e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 472       |
# |    fps              | 1545      |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 23600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 208       |
# |    n_updates        | 1468      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.22e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 476       |
# |    fps              | 1544      |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 23800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 222       |
# |    n_updates        | 1481      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.21e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 480       |
# |    fps              | 1545      |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 24000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 249       |
# |    n_updates        | 1493      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.21e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 484       |
# |    fps              | 1539      |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 24200     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 230       |
# |    n_updates        | 1506      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.21e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 488       |
# |    fps              | 1535      |
# |    time_elapsed     | 15        |
# |    total_timesteps  | 24400     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 206       |
# |    n_updates        | 1518      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.21e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 492       |
# |    fps              | 1530      |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 24600     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 223       |
# |    n_updates        | 1531      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.23e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 496       |
# |    fps              | 1524      |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 24800     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 222       |
# |    n_updates        | 1543      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 50        |
# |    ep_rew_mean      | -1.22e+04 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 500       |
# |    fps              | 1519      |
# |    time_elapsed     | 16        |
# |    total_timesteps  | 25000     |
# | train/              |           |
# |    learning_rate    | 0.0001    |
# |    loss             | 230       |
# |    n_updates        | 1556      |
# -----------------------------------

# %%
model.save("double_dqn_industrial_inventory.zip")

# %%
loaded_model = DoubleDQN.load("double_dqn_industrial_inventory.zip")

# %%
# manual eval loop for 1 episode, to get the info dict for each step, to get the costs
eval_env = env_fn()
records = []
observation, info = eval_env.reset(seed=2026)
while True:
    # now action is coming single number, not list [int, int, int] as before, because of the wrapper
    action_scalar, _ = loaded_model.predict(observation, deterministic=True)  # MultiDiscrete indices directly
    observation, reward, terminated, truncated, info = eval_env.step(action_scalar)
    records.append({
        "action": eval_env.action(action_scalar),  # convert back to MultiDiscrete indices vector for logging [int, int, int]
        "reward": reward,
        "truncated": truncated,
        "info": info,
        'day': info['day'],
        **info['costs']
    })
    if terminated or truncated:
        break

df = pd.DataFrame(records)
df
# Out:
#         action   reward  truncated  \
# 0    [1, 1, 0]  -27.425      False
# 1    [1, 1, 0]  -19.050      False
# 2    [1, 1, 0]  -10.800      False
# 3    [1, 1, 0]  -86.500      False
# 4    [1, 1, 0] -153.800      False
# 5   [2, 8, 10] -198.000      False
# 6    [1, 1, 0] -230.800      False
# 7    [5, 8, 3] -114.550      False
# 8    [1, 1, 0]  -47.400      False
# 9    [1, 1, 0] -157.550      False
# 10   [1, 1, 0]  -19.325      False
# 11   [1, 1, 0]  -81.850      False
# 12   [8, 9, 1] -164.700      False
# 13   [2, 7, 1]  -89.850      False
# 14   [9, 9, 9]  -94.650      False
# 15   [2, 7, 1]  -36.000      False
# 16   [1, 1, 0]  -42.675      False
# 17   [1, 1, 0] -212.625      False
# 18   [1, 1, 0] -122.000      False
# 19   [1, 1, 0] -120.950      False
# 20   [1, 1, 0]  -97.000      False
# 21   [1, 1, 0] -185.150      False
# 22   [1, 1, 0] -252.750      False
# 23   [1, 1, 0] -131.500      False
# 24   [1, 1, 0] -203.150      False
# 25   [1, 1, 0] -203.450      False
# 26   [1, 1, 0] -175.650      False
# 27   [1, 1, 0] -224.950      False
# 28   [2, 7, 1] -177.050      False
# 29   [2, 7, 1] -198.250      False
# 30   [1, 1, 0] -198.650      False
# 31   [1, 1, 0] -142.650      False
# 32   [1, 1, 0] -177.250      False
# 33   [4, 9, 9] -191.100      False
# 34   [1, 1, 0] -121.700      False
# 35   [1, 1, 0]  -96.825      False
# 36   [1, 1, 0]  -44.150      False
# 37   [1, 1, 0] -182.700      False
# 38   [1, 1, 0] -243.000      False
# 39   [2, 6, 7] -127.050      False
# 40   [1, 1, 0] -104.825      False
# 41   [1, 1, 0]  -54.250      False
# 42   [6, 1, 7] -107.900      False
# 43   [1, 5, 5] -140.300      False
# 44   [9, 9, 9] -153.300      False
# 45   [1, 1, 0]  -22.800      False
# 46   [1, 1, 0]  -32.775      False
# 47   [1, 1, 0]  -26.000      False
# 48   [2, 0, 1]  -33.250      False
# 49   [2, 1, 2]  -57.400       True
#
#                                                  info  day  holding  stockout  \
# 0   {'day': 0, 'demand': [34, 21, 21], 'fulfilled_...    0   2462.5       0.0
# 1   {'day': 1, 'demand': [29, 23, 27], 'fulfilled_...    1   1625.0       0.0
# 2   {'day': 2, 'demand': [27, 33, 28], 'fulfilled_...    2    800.0       0.0
# 3   {'day': 3, 'demand': [42, 25, 25], 'fulfilled_...    3    270.0    8100.0
# 4   {'day': 4, 'demand': [26, 28, 29], 'fulfilled_...    4      0.0   15100.0
# 5   {'day': 5, 'demand': [22, 23, 27], 'fulfilled_...    5      0.0   19400.0
# 6   {'day': 6, 'demand': [28, 25, 27], 'fulfilled_...    6      0.0   22800.0
# 7   {'day': 7, 'demand': [34, 21, 24], 'fulfilled_...    7   1455.0    9600.0
# 8   {'day': 8, 'demand': [28, 24, 28], 'fulfilled_...    8   1260.0    3200.0
# 9   {'day': 9, 'demand': [44, 24, 30], 'fulfilled_...    9   1875.0   13600.0
# 10  {'day': 10, 'demand': [22, 28, 31], 'fulfilled...   10   1652.5       0.0
# 11  {'day': 11, 'demand': [35, 28, 40], 'fulfilled...   11   1005.0    6900.0
# 12  {'day': 12, 'demand': [30, 17, 28], 'fulfilled...   12    870.0   15200.0
# 13  {'day': 13, 'demand': [18, 29, 26], 'fulfilled...   13    585.0    8000.0
# 14  {'day': 14, 'demand': [27, 18, 12], 'fulfilled...   14   1665.0    7400.0
# 15  {'day': 15, 'demand': [33, 27, 34], 'fulfilled...   15   3200.0       0.0
# 16  {'day': 16, 'demand': [29, 20, 33], 'fulfilled...   16   3987.5       0.0
# 17  {'day': 17, 'demand': [35, 35, 32], 'fulfilled...   17   3882.5       0.0
# 18  {'day': 18, 'demand': [37, 29, 30], 'fulfilled...   18   3220.0    8700.0
# 19  {'day': 19, 'demand': [27, 19, 29], 'fulfilled...   19   3115.0    8700.0
# 20  {'day': 20, 'demand': [26, 19, 22], 'fulfilled...   20   2820.0    6600.0
# 21  {'day': 21, 'demand': [29, 29, 27], 'fulfilled...   21   2535.0   15700.0
# 22  {'day': 22, 'demand': [38, 26, 25], 'fulfilled...   22   2295.0   22700.0
# 23  {'day': 23, 'demand': [23, 25, 32], 'fulfilled...   23   2070.0   10800.0
# 24  {'day': 24, 'demand': [35, 19, 27], 'fulfilled...   24   1935.0   18100.0
# 25  {'day': 25, 'demand': [32, 28, 32], 'fulfilled...   25   1665.0   18400.0
# 26  {'day': 26, 'demand': [24, 22, 34], 'fulfilled...   26   1485.0   15800.0
# 27  {'day': 27, 'demand': [34, 28, 38], 'fulfilled...   27   1215.0   21000.0
# 28  {'day': 28, 'demand': [32, 24, 25], 'fulfilled...   28   1005.0   16300.0
# 29  {'day': 29, 'demand': [43, 22, 28], 'fulfilled...   29    825.0   18600.0
# 30  {'day': 30, 'demand': [35, 26, 37], 'fulfilled...   30   1485.0   18100.0
# 31  {'day': 31, 'demand': [28, 30, 29], 'fulfilled...   31   2085.0   11900.0
# 32  {'day': 32, 'demand': [35, 26, 32], 'fulfilled...   32   1845.0   15600.0
# 33  {'day': 33, 'demand': [21, 19, 42], 'fulfilled...   33   1710.0   17000.0
# 34  {'day': 34, 'demand': [35, 25, 36], 'fulfilled...   34   1890.0   10000.0
# 35  {'day': 35, 'demand': [27, 26, 33], 'fulfilled...   35   2602.5    6800.0
# 36  {'day': 36, 'demand': [36, 20, 27], 'fulfilled...   36   2335.0    1800.0
# 37  {'day': 37, 'demand': [28, 37, 35], 'fulfilled...   37   1890.0   16100.0
# 38  {'day': 38, 'demand': [32, 28, 32], 'fulfilled...   38   1620.0   22400.0
# 39  {'day': 39, 'demand': [25, 31, 30], 'fulfilled...   39   1305.0   11000.0
# 40  {'day': 40, 'demand': [32, 23, 31], 'fulfilled...   40   1402.5    8800.0
# 41  {'day': 41, 'demand': [19, 31, 39], 'fulfilled...   41   1545.0    3600.0
# 42  {'day': 42, 'demand': [27, 27, 21], 'fulfilled...   42   1290.0    9100.0
# 43  {'day': 43, 'demand': [41, 32, 34], 'fulfilled...   43   1230.0   12400.0
# 44  {'day': 44, 'demand': [35, 36, 38], 'fulfilled...   44    930.0   14000.0
# 45  {'day': 45, 'demand': [38, 29, 32], 'fulfilled...   45   2000.0       0.0
# 46  {'day': 46, 'demand': [44, 37, 37], 'fulfilled...   46   2197.5     800.0
# 47  {'day': 47, 'demand': [32, 21, 39], 'fulfilled...   47   2320.0       0.0
# 48  {'day': 48, 'demand': [36, 24, 35], 'fulfilled...   48   1625.0    1500.0
# 49  {'day': 49, 'demand': [33, 27, 24], 'fulfilled...   49   1140.0    4200.0
#
#     ordering  discarding  daily_total  episode_total
# 0      280.0         0.0       2742.5         2742.5
# 1      280.0         0.0       1905.0         4647.5
# 2      280.0         0.0       1080.0         5727.5
# 3      280.0         0.0       8650.0        14377.5
# 4      280.0         0.0      15380.0        29757.5
# 5      400.0         0.0      19800.0        49557.5
# 6      280.0         0.0      23080.0        72637.5
# 7      400.0         0.0      11455.0        84092.5
# 8      280.0         0.0       4740.0        88832.5
# 9      280.0         0.0      15755.0       104587.5
# 10     280.0         0.0       1932.5       106520.0
# 11     280.0         0.0       8185.0       114705.0
# 12     400.0         0.0      16470.0       131175.0
# 13     400.0         0.0       8985.0       140160.0
# 14     400.0         0.0       9465.0       149625.0
# 15     400.0         0.0       3600.0       153225.0
# 16     280.0         0.0       4267.5       157492.5
# 17     280.0     17100.0      21262.5       178755.0
# 18     280.0         0.0      12200.0       190955.0
# 19     280.0         0.0      12095.0       203050.0
# 20     280.0         0.0       9700.0       212750.0
# 21     280.0         0.0      18515.0       231265.0
# 22     280.0         0.0      25275.0       256540.0
# 23     280.0         0.0      13150.0       269690.0
# 24     280.0         0.0      20315.0       290005.0
# 25     280.0         0.0      20345.0       310350.0
# 26     280.0         0.0      17565.0       327915.0
# 27     280.0         0.0      22495.0       350410.0
# 28     400.0         0.0      17705.0       368115.0
# 29     400.0         0.0      19825.0       387940.0
# 30     280.0         0.0      19865.0       407805.0
# 31     280.0         0.0      14265.0       422070.0
# 32     280.0         0.0      17725.0       439795.0
# 33     400.0         0.0      19110.0       458905.0
# 34     280.0         0.0      12170.0       471075.0
# 35     280.0         0.0       9682.5       480757.5
# 36     280.0         0.0       4415.0       485172.5
# 37     280.0         0.0      18270.0       503442.5
# 38     280.0         0.0      24300.0       527742.5
# 39     400.0         0.0      12705.0       540447.5
# 40     280.0         0.0      10482.5       550930.0
# 41     280.0         0.0       5425.0       556355.0
# 42     400.0         0.0      10790.0       567145.0
# 43     400.0         0.0      14030.0       581175.0
# 44     400.0         0.0      15330.0       596505.0
# 45     280.0         0.0       2280.0       598785.0
# 46     280.0         0.0       3277.5       602062.5
# 47     280.0         0.0       2600.0       604662.5
# 48     200.0         0.0       3325.0       607987.5
# 49     400.0         0.0       5740.0       613727.5

# %%
df[['holding', 'ordering', 'discarding', 'stockout', 'daily_total']].plot()      # , 'episode_total'
# Out:
# <Axes: >
