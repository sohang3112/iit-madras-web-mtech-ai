# %% [markdown]
# # Practice Assignment - LLM Inference with vLLM
#
# ### Experiments
# 1. Observe prefill and decode through TTFT and generation time.
# 2. Explore the throughput and latency trade-off when requests arrive concurrently.
# 3. Measure what automatic prefix caching saves.
#
# The notebook includes the server, streaming, and concurrency plumbing. The experiment code is left incomplete and must be finished by you.

# %% [markdown]
# ## Before you start
#
# Use **Runtime > Change runtime type > GPU**.
#
# For every experiment:
#
# - Predict before running the measurement.
# - Change only the variable named in the task.
# - Use repeated measurements rather than one request.
# - Compare results from your own Colab runtime. Different students may receive different GPUs.
#
# If a TODO is difficult, open Hint 1 first. Use Hint 2 only if you still need help.

# %% [markdown]
# ## Setup
#
# The next cells are **plumbing code**. Run them as-is. You are not expected to write server startup code, HTTP streaming code, or concurrency code.

# %%
# Run this before importing torch or vllm.
# !pip -q install -U uv
# !uv pip install --system -U \
    "https://github.com/vllm-project/vllm/releases/download/v0.23.0/vllm-0.23.0+cu129-cp38-abi3-manylinux_2_28_x86_64.whl" \
    "numpy==2.0.2" \
    --torch-backend=cu129 \
    --extra-index-url https://download.pytorch.org/whl/cu129 \
    --index-strategy unsafe-best-match
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.3/22.3 MB 87.3 MB/s eta 0:00:00
# Using Python 3.12.13 environment at: /usr
# Resolved 194 packages in 8.58s
# Prepared 133 packages in 2m 04s
# Uninstalled 64 packages in 2.09s
# Installed 133 packages in 1.86s
#  - aiohttp==3.14.1
#  + aiohttp==3.14.3
#  - annotated-doc==0.0.4
#  + annotated-doc==0.0.5
#  - annotated-types==0.7.0
#  + annotated-types==0.8.0
#  + anthropic==0.121.0
#  + apache-tvm-ffi==0.1.9
#  + astor==0.8.1
#  + blake3==1.0.9
#  - cachetools==6.2.6
#  + cachetools==7.1.7
#  + cbor2==6.1.4
#  - certifi==2026.6.17
#  + certifi==2026.7.22
#  - cffi==2.1.0
#  + cffi==2.1.1
#  - charset-normalizer==3.4.9
#  + charset-normalizer==3.5.0
#  + compressed-tensors==0.17.0
#  - cryptography==49.0.0
#  + cryptography==50.0.0
#  - cuda-pathfinder==1.5.6
#  + cuda-pathfinder==1.6.0
#  + cuda-tile==1.3.0
#  - cuda-toolkit==12.8.1
#  + cuda-toolkit==12.9.1
#  + depyf==0.20.0
#  + detect-installer==0.1.0
#  - dill==0.3.8
#  + dill==0.4.1
#  + diskcache==5.6.3
#  + dnspython==2.8.0
#  + email-validator==2.3.0
#  - fastapi==0.139.0
#  + fastapi==0.141.1
#  + fastapi-cli==0.0.32
#  + fastapi-cloud-cli==0.23.0
#  + fastar==0.11.0
#  + fastsafetensors==0.3.3
#  - filelock==3.29.7
#  + filelock==3.32.2
#  + flashinfer-cubin==0.6.12
#  + flashinfer-python==0.6.12
#  - fsspec==2025.3.0
#  + fsspec==2026.7.0
#  + gguf==0.19.0
#  - googleapis-common-protos==1.75.0
#  + googleapis-common-protos==1.75.1
#  - grpcio==1.82.1
#  + grpcio==1.83.0
#  - hf-xet==1.5.1
#  + hf-xet==1.6.0
#  - httpcore2==2.5.0
#  + httpcore2==2.10.0
#  - httpx2==2.5.0
#  + httpx2==2.10.0
#  - huggingface-hub==1.23.0
#  + huggingface-hub==1.27.0
#  + humming-kernels==0.1.4
#  + ijson==3.5.1
#  + interegular==0.3.3
#  + jmespath==1.1.0
#  - lark==1.3.1
#  + lark==1.2.2
#  + llguidance==1.7.6
#  - llvmlite==0.43.0
#  + llvmlite==0.47.0
#  + lm-format-enforcer==0.11.3
#  + loguru==0.7.3
#  + mcp==2.0.0
#  + mcp-types==2.0.0
#  + mistral-common==1.11.7
#  + model-hosting-container-standards==0.1.16
#  + msgspec==0.21.1
#  + ninja==1.13.0
#  - numba==0.60.0
#  + numba==0.65.0
#  - nvidia-cublas-cu12==12.8.4.1
#  + nvidia-cublas-cu12==12.9.1.4
#  + nvidia-cuda-crt==13.3.73
#  - nvidia-cuda-cupti-cu12==12.8.90
#  + nvidia-cuda-cupti-cu12==12.9.79
#  + nvidia-cuda-nvcc==13.2.86
#  - nvidia-cuda-nvcc-cu12==12.8.93
#  + nvidia-cuda-nvcc-cu12==12.9.86
#  - nvidia-cuda-nvrtc-cu12==12.8.93
#  + nvidia-cuda-nvrtc-cu12==12.9.86
#  + nvidia-cuda-runtime==13.3.29
#  - nvidia-cuda-runtime-cu12==12.8.90
#  + nvidia-cuda-runtime-cu12==12.9.79
#  + nvidia-cuda-tileiras==13.2.86
#  - nvidia-cudnn-cu12==9.19.0.56
#  + nvidia-cudnn-cu12==9.17.1.4
#  + nvidia-cudnn-frontend==1.27.0
#  - nvidia-cufft-cu12==11.3.3.83
#  + nvidia-cufft-cu12==11.4.1.4
#  - nvidia-cufile-cu12==1.13.1.3
#  + nvidia-cufile-cu12==1.14.1.1
#  - nvidia-curand-cu12==10.3.9.90
#  + nvidia-curand-cu12==10.3.10.19
#  - nvidia-cusolver-cu12==11.7.3.90
#  + nvidia-cusolver-cu12==11.7.5.82
#  - nvidia-cusparse-cu12==12.5.8.93
#  + nvidia-cusparse-cu12==12.5.10.65
#  + nvidia-cutlass-dsl==4.5.2
#  + nvidia-cutlass-dsl-libs-base==4.5.2
#  + nvidia-nvjitlink==13.3.33
#  - nvidia-nvjitlink-cu12==12.8.93
#  + nvidia-nvjitlink-cu12==12.9.86
#  - nvidia-nvtx-cu12==12.8.90
#  + nvidia-nvtx-cu12==12.9.79
#  + nvidia-nvvm==13.2.86
#  - openai==2.45.0
#  + openai==3.0.0
#  + openai-harmony==0.0.8
#  - opentelemetry-api==1.42.1
#  + opentelemetry-api==1.44.0
#  + opentelemetry-exporter-otlp==1.44.0
#  + opentelemetry-exporter-otlp-proto-common==1.44.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.44.0
#  + opentelemetry-exporter-otlp-proto-http==1.44.0
#  + opentelemetry-proto==1.44.0
#  - opentelemetry-sdk==1.42.1
#  + opentelemetry-sdk==1.44.0
#  - opentelemetry-semantic-conventions==0.63b1
#  + opentelemetry-semantic-conventions==0.65b0
#  + opentelemetry-semantic-conventions-ai==0.5.1
#  + outlines-core==0.2.14
#  - packaging==26.2
#  + packaging==26.3
#  + partial-json-parser==0.2.1.1.post7
#  - pillow==11.3.0
#  + pillow==12.3.0
#  - prometheus-client==0.25.0
#  + prometheus-client==0.26.0
#  + prometheus-fastapi-instrumentator==8.1.0
#  - protobuf==5.29.6
#  + protobuf==7.35.1
#  - psutil==5.9.5
#  + psutil==7.2.2
#  + pybase64==1.5.0
#  + pycountry==26.2.16
#  + pydantic-extra-types==2.11.1
#  + pydantic-settings==2.15.0
#  + pyelftools==0.33
#  - pyzmq==26.2.1
#  + pyzmq==27.1.0
#  + quack-kernels==0.5.0
#  - regex==2025.11.3
#  + regex==2026.7.19
#  - requests==2.32.4
#  + requests==2.34.2
#  - rich==13.9.4
#  + rich==15.0.0
#  + rich-toolkit==0.20.3
#  + rignore==0.8.1
#  - sentry-sdk==2.65.0
#  + sentry-sdk==2.67.1
#  + setproctitle==1.3.7
#  - setuptools==75.2.0
#  + setuptools==80.10.2
#  + sse-starlette==3.4.8
#  - starlette==1.3.1
#  + starlette==1.6.0
#  + supervisor==4.3.0
#  - tabulate==0.9.0
#  + tabulate==0.10.0
#  + tilelang==0.1.9
#  + tokenspeed-mla==0.1.2
#  + tokenspeed-triton==3.8.10.post20260721
#  - torch==2.11.0+cu128
#  + torch==2.11.0+cu129
#  + torch-c-dlpack-ext==0.1.5
#  - torchaudio==2.11.0+cu128
#  + torchaudio==2.11.0+cu129
#  - torchvision==0.26.0+cu128
#  + torchvision==0.26.0+cu129
#  - tqdm==4.67.3
#  + tqdm==4.70.0
#  - transformers==5.13.1
#  + transformers==5.15.0
#  - typer==0.26.8
#  + typer==0.27.1
#  - typing-inspection==0.4.2
#  + typing-inspection==0.4.4
#  - urllib3==2.5.0
#  + urllib3==2.7.0
#  - uvicorn==0.51.0
#  + uvicorn==0.52.1
#  + vllm==0.23.0+cu129 (from https://github.com/vllm-project/vllm/releases/download/v0.23.0/vllm-0.23.0+cu129-cp38-abi3-manylinux_2_28_x86_64.whl)
#  - websockets==15.0.1
#  + websockets==17.0.1
#  + xgrammar==0.2.3
#  - yarl==1.24.2
#  + yarl==1.24.5
#  + z3-solver==4.15.4.0

# %%
import os
import gc
import json
import math
import statistics
import subprocess
import sys
import time
from concurrent.futures import ThreadPoolExecutor, as_completed
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt
import requests
import torch
from transformers import AutoTokenizer

if not torch.cuda.is_available():
    raise RuntimeError("Select a GPU runtime and run the notebook again")

import vllm

print("Python", sys.version.split()[0])
print("PyTorch", torch.__version__)
print("vLLM", vllm.__version__)
print("GPU", torch.cuda.get_device_name(0))
print("CUDA", torch.version.cuda)
# Out:
# Python 3.12.13
# PyTorch 2.11.0+cu129
# vLLM 0.23.0
# GPU Tesla T4
# CUDA 12.9

# %%
MODEL = "Qwen/Qwen2.5-0.5B-Instruct"
PORT = 8000
MAX_MODEL_LEN = 4096
GPU_MEMORY_UTILIZATION = 0.78

RESULTS_DIR = Path("/content/vllm_lab_results")
RESULTS_DIR.mkdir(parents=True, exist_ok=True)

tokenizer = AutoTokenizer.from_pretrained(MODEL)
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/7.30k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]

# %% [markdown]
# ### Provided server and measurement utilities
#
# `stream_completion` returns a dictionary with the following metrics:
#
# - `ttft_ms`: client-observed time to first streamed text token (milliseconds)
# - `e2e_ms`: total request time (milliseconds)
# - `approx_tpot_ms`: approximate time per output token after the first token (milliseconds)
# - `output_tokens`: approximate generated token count
#
# `run_concurrent_requests` handles the threading needed to submit requests concurrently. You will design the experiment around it.

# %%
SERVER_PROC = None
SERVER_LOG_HANDLE = None


def _kill_stale_vllm():
    """Remove an orphaned vLLM server from an earlier notebook run."""
    # First try to kill whatever owns the notebook's server port.
    try:
        subprocess.run(
            ["fuser", "-k", f"{PORT}/tcp"],
            stdout=subprocess.DEVNULL,
            stderr=subprocess.DEVNULL,
            check=False,
        )
    except FileNotFoundError:
        pass

    # Fallback for Colab environments where fuser is unavailable.
    try:
        subprocess.run(
            ["pkill", "-f", rf"vllm.*serve.*--port.*{PORT}"],
            stdout=subprocess.DEVNULL,
            stderr=subprocess.DEVNULL,
            check=False,
        )
    except FileNotFoundError:
        pass

    time.sleep(2)


def stop_server():
    global SERVER_PROC, SERVER_LOG_HANDLE

    if SERVER_PROC is not None and SERVER_PROC.poll() is None:
        SERVER_PROC.terminate()
        try:
            SERVER_PROC.wait(timeout=20)
        except subprocess.TimeoutExpired:
            SERVER_PROC.kill()
            SERVER_PROC.wait(timeout=10)

    SERVER_PROC = None

    if SERVER_LOG_HANDLE is not None:
        SERVER_LOG_HANDLE.close()
        SERVER_LOG_HANDLE = None

    # Important in notebooks: rerunning the setup cell can lose SERVER_PROC
    # while the old vLLM process is still alive.
    _kill_stale_vllm()

    gc.collect()
    torch.cuda.empty_cache()
    time.sleep(2)


def show_server_log_tail(lines=50):
    log_path = RESULTS_DIR / "vllm_server.log"

    if SERVER_LOG_HANDLE is not None:
        try:
            SERVER_LOG_HANDLE.flush()
        except Exception:
            pass

    if log_path.exists():
        text = log_path.read_text(errors="replace")
        print("\n".join(text.splitlines()[-lines:]))


def start_server(prefix_caching=False, timeout_s=600):
    global SERVER_PROC, SERVER_LOG_HANDLE

    stop_server()

    log_path = RESULTS_DIR / "vllm_server.log"
    SERVER_LOG_HANDLE = open(log_path, "w", buffering=1)

    cmd = [
        sys.executable,
        "-m",
        "vllm.entrypoints.cli.main",
        "serve",
        MODEL,
        "--host",
        "127.0.0.1",
        "--port",
        str(PORT),
        "--dtype",
        "float16",
        "--gpu-memory-utilization",
        str(GPU_MEMORY_UTILIZATION),
        "--max-model-len",
        str(MAX_MODEL_LEN),
    ]

    if prefix_caching:
        cmd.append("--enable-prefix-caching")
    else:
        cmd.append("--no-enable-prefix-caching")

    print("=" * 80)
    print("Starting vLLM server")
    print("=" * 80)
    print("Model:", MODEL)
    print("Port:", PORT)
    print("Prefix caching:", prefix_caching)
    print("GPU memory utilization:", GPU_MEMORY_UTILIZATION)
    print("Max model length:", MAX_MODEL_LEN)
    print()
    print("Command:")
    print(" ".join(cmd))
    print()
    print("-" * 80)
    print("vLLM LOG")
    print("-" * 80)

    # Capture stdout so we can both display it live and save it.
    SERVER_PROC = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,
        env={
            **os.environ,
            "PYTHONUNBUFFERED": "1",

            # Avoid FlashInfer JIT compilation during startup.
            "VLLM_USE_FLASHINFER_SAMPLER": "0",
        },
    )

    # Read vLLM's stdout continuously in a separate thread.
    import threading

    def stream_logs():
        try:
            for line in iter(SERVER_PROC.stdout.readline, ""):
                if not line:
                    break

                # Show it immediately in the notebook.
                print(line, end="", flush=True)

                # Also preserve it in the log file.
                try:
                    SERVER_LOG_HANDLE.write(line)
                    SERVER_LOG_HANDLE.flush()
                except (ValueError, OSError):
                    pass
        finally:
            try:
                SERVER_PROC.stdout.close()
            except Exception:
                pass

    log_thread = threading.Thread(
        target=stream_logs,
        daemon=True,
    )
    log_thread.start()

    health_url = f"http://127.0.0.1:{PORT}/v1/models"
    deadline = time.time() + timeout_s

    while time.time() < deadline:
        return_code = SERVER_PROC.poll()

        if return_code is not None:
            # Give the logging thread a moment to print the final lines.
            log_thread.join(timeout=2)

            print()
            print("-" * 80)
            print(f"vLLM exited with code {return_code}")
            print(f"Full log: {log_path}")
            print("-" * 80)

            raise RuntimeError(
                f"vLLM exited early with code {return_code}. "
                f"See {log_path}"
            )

        try:
            response = requests.get(
                health_url,
                timeout=2,
            )

            if response.ok:
                print()
                print("=" * 80)
                print("vLLM SERVER READY")
                print("=" * 80)
                print(f"Endpoint: http://127.0.0.1:{PORT}")
                print(f"Logs: {log_path}")
                print()

                return

        except requests.RequestException:
            # Normal while vLLM is still initializing.
            pass

        time.sleep(2)

    print()
    print("=" * 80)
    print(f"STARTUP TIMEOUT after {timeout_s} seconds")
    print("=" * 80)

    stop_server()

    raise TimeoutError(
        f"vLLM did not become ready within {timeout_s} seconds. "
        f"See {log_path}"
    )

# %%
def stream_completion(prompt, max_tokens=16):
    url = f"http://127.0.0.1:{PORT}/v1/completions"
    payload = {
        "model": MODEL,
        "prompt": prompt,
        "max_tokens": max_tokens,
        "temperature": 0.0,
        "ignore_eos": True,
        "stream": True,
    }

    start = time.perf_counter()
    first_text_time = None
    pieces = []

    with requests.post(url, json=payload, stream=True, timeout=180) as response:
        response.raise_for_status()
        for raw in response.iter_lines():
            if not raw or not raw.startswith(b"data: "):
                continue
            data = raw[len(b"data: ") :]
            if data == b"[DONE]":
                break
            obj = json.loads(data)
            text = obj["choices"][0].get("text", "")
            if text:
                if first_text_time is None:
                    first_text_time = time.perf_counter()
                pieces.append(text)

    end = time.perf_counter()
    generated_text = "".join(pieces)
    output_tokens = len(tokenizer.encode(generated_text, add_special_tokens=False))
    ttft_s = first_text_time - start if first_text_time is not None else float("nan")
    e2e_s = end - start
    tpot_s = (e2e_s - ttft_s) / max(output_tokens - 1, 1)

    return {
        "ttft_ms": 1000 * ttft_s,
        "e2e_ms": 1000 * e2e_s,
        "approx_tpot_ms": 1000 * tpot_s,
        "output_tokens": output_tokens,
        "text": generated_text,
    }


def repeat_request(prompt, max_tokens, repeats=3):
    values = [stream_completion(prompt, max_tokens=max_tokens) for _ in range(repeats)]
    return {
        "median_ttft_ms": statistics.median(v["ttft_ms"] for v in values),
        "median_e2e_ms": statistics.median(v["e2e_ms"] for v in values),
        "median_tpot_ms": statistics.median(v["approx_tpot_ms"] for v in values),
        "median_output_tokens": statistics.median(v["output_tokens"] for v in values),
    }


def run_concurrent_requests(prompts, concurrency, max_tokens=32):
    start = time.perf_counter()
    results = []
    with ThreadPoolExecutor(max_workers=concurrency) as pool:
        futures = [pool.submit(stream_completion, p, max_tokens) for p in prompts]
        for future in as_completed(futures):
            results.append(future.result())
    wall_s = time.perf_counter() - start
    return results, wall_s

# %% [markdown]
# ### Start the shared server
#
# We begin with prefix caching disabled. Experiments 1 and 2 use this same server so setup time does not dominate the lab.

# %%
start_server(prefix_caching=False)
_ = stream_completion("Warm up the inference server", max_tokens=8)
print("READY")
# Out:
# ================================================================================
# Starting vLLM server
# ================================================================================
# Model: Qwen/Qwen2.5-0.5B-Instruct
# Port: 8000
# Prefix caching: False
# GPU memory utilization: 0.78
# Max model length: 4096
#
# Command:
# /usr/bin/python3 -m vllm.entrypoints.cli.main serve Qwen/Qwen2.5-0.5B-Instruct --host 127.0.0.1 --port 8000 --dtype float16 --gpu-memory-utilization 0.78 --max-model-len 4096 --no-enable-prefix-caching
#
# --------------------------------------------------------------------------------
# vLLM LOG
# --------------------------------------------------------------------------------
# (APIServer pid=2848) INFO 08-13 05:00:43 [api_utils.py:339]
# (APIServer pid=2848) INFO 08-13 05:00:43 [api_utils.py:339]        █     █     █▄   ▄█
# (APIServer pid=2848) INFO 08-13 05:00:43 [api_utils.py:339]  ▄▄ ▄█ █     █     █ ▀▄▀ █  version 0.23.0
# (APIServer pid=2848) INFO 08-13 05:00:43 [api_utils.py:339]   █▄█▀ █     █     █     █  model   Qwen/Qwen2.5-0.5B-Instruct
# (APIServer pid=2848) INFO 08-13 05:00:43 [api_utils.py:339]    ▀▀  ▀▀▀▀▀ ▀▀▀▀▀ ▀     ▀
# (APIServer pid=2848) INFO 08-13 05:00:43 [api_utils.py:339]
# (APIServer pid=2848) INFO 08-13 05:00:43 [api_utils.py:273] non-default args: {'model_tag': 'Qwen/Qwen2.5-0.5B-Instruct', 'host': '127.0.0.1', 'model': 'Qwen/Qwen2.5-0.5B-Instruct', 'dtype': 'float16', 'max_model_len': 4096, 'gpu_memory_utilization': 0.78, 'enable_prefix_caching': False}
# (APIServer pid=2848) Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# (APIServer pid=2848) INFO 08-13 05:01:06 [model.py:611] Resolved architecture: Qwen2ForCausalLM
# (APIServer pid=2848) WARNING 08-13 05:01:06 [model.py:2083] Casting torch.bfloat16 to torch.float16.
# (APIServer pid=2848) INFO 08-13 05:01:06 [model.py:1745] Using max model len 4096
# (APIServer pid=2848) INFO 08-13 05:01:06 [vllm.py:999] Asynchronous scheduling is enabled.
# (APIServer pid=2848) INFO 08-13 05:01:06 [kernel.py:270] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native'])
# (EngineCore pid=3192) INFO 08-13 05:01:28 [core.py:113] Initializing a V1 LLM engine (v0.23.0) with config: model='Qwen/Qwen2.5-0.5B-Instruct', speculative_config=None, tokenizer='Qwen/Qwen2.5-0.5B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=4096, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, decode_context_parallel_size=1, dcp_comm_backend=ag_rs, disable_custom_all_reduce=False, quantization=None, quantization_config=None, enforce_eager=False, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=Qwen/Qwen2.5-0.5B-Instruct, enable_prefix_caching=False, enable_chunked_prefill=True, pooler_config=None, compilation_config={'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'ir_enable_torch_wrap': True, 'splitting_ops': ['vllm::unified_attention_with_output', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::plamo2_mamba_mixer', 'vllm::qwen_gdn_attention_core', 'vllm::gdn_attention_core_xpu', 'vllm::olmo_hybrid_gdn_full_forward', 'vllm::kda_attention', 'vllm::sparse_attn_indexer', 'vllm::rocm_aiter_sparse_attn_indexer', 'vllm::deepseek_v4_attention', 'vllm::unified_kv_cache_update', 'vllm::unified_mla_kv_cache_update'], 'compile_mm_encoder': False, 'cudagraph_mm_encoder': False, 'encoder_cudagraph_token_budgets': [], 'encoder_cudagraph_max_vision_items_per_batch': 0, 'encoder_cudagraph_max_frames_per_batch': None, 'compile_sizes': [], 'compile_ranges_endpoints': [2048], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'size_asserts': False, 'alignment_asserts': False, 'scalar_asserts': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.FULL_AND_PIECEWISE: (2, 1)>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False, 'fuse_rope_kvcache_cat_mla': False, 'fuse_act_padding': False}, 'max_cudagraph_capture_size': 512, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': False, 'static_all_moe_layers': []}, kernel_config=KernelConfig(ir_op_priority=IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native']), enable_flashinfer_autotune=True, moe_backend='auto', linear_backend='auto')
# (EngineCore pid=3192) INFO 08-13 05:01:29 [parallel_state.py:1568] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.28.0.12:56725 backend=nccl
# (EngineCore pid=3192) INFO 08-13 05:01:29 [parallel_state.py:1903] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (EngineCore pid=3192) INFO 08-13 05:01:30 [topk_topp_sampler.py:39] FlashInfer top-p/top-k sampling disabled via VLLM_USE_FLASHINFER_SAMPLER=0.
# (EngineCore pid=3192) INFO 08-13 05:01:30 [gpu_model_runner.py:5092] Starting to load model Qwen/Qwen2.5-0.5B-Instruct...
# (EngineCore pid=3192) ERROR 08-13 05:01:31 [fa_utils.py:171] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# (EngineCore pid=3192) INFO 08-13 05:01:35 [cuda.py:378] Using FLASHINFER attention backend out of potential backends: ['FLASHINFER', 'TRITON_ATTN', 'FLEX_ATTENTION'].
# (EngineCore pid=3192) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# (EngineCore pid=3192) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.nvrtc module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.nvrtc module instead.
# (EngineCore pid=3192) INFO 08-13 05:01:50 [weight_utils.py:603] Time spent downloading weights for Qwen/Qwen2.5-0.5B-Instruct: 10.469684 seconds
# (EngineCore pid=3192) Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# (EngineCore pid=3192) INFO 08-13 05:01:50 [weight_utils.py:647] No model.safetensors.index.json found in remote.
# (EngineCore pid=3192) INFO 08-13 05:01:50 [weight_utils.py:922] Filesystem type for checkpoints: OVERLAY. Checkpoint size: 0.92 GiB. Available RAM: 7.27 GiB.
# (EngineCore pid=3192) INFO 08-13 05:01:50 [weight_utils.py:945] Auto-prefetch is disabled because the filesystem (OVERLAY) is not a recognized network FS (NFS/Lustre). If you want to force prefetching, start vLLM with --safetensors-load-strategy=prefetch.
# (EngineCore pid=3192)
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# (EngineCore pid=3192)
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:01<00:00,  1.40s/it]
# (EngineCore pid=3192)
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:01<00:00,  1.40s/it]
# (EngineCore pid=3192)
# (EngineCore pid=3192) INFO 08-13 05:01:51 [default_loader.py:397] Loading weights took 1.44 seconds
# (EngineCore pid=3192) INFO 08-13 05:01:52 [gpu_model_runner.py:5187] Model loading took 0.93 GiB memory and 20.944988 seconds
# (EngineCore pid=3192) INFO 08-13 05:02:01 [backends.py:1089] Using cache directory: /root/.cache/vllm/torch_compile_cache/9c1dad01d5/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore pid=3192) INFO 08-13 05:02:01 [backends.py:1148] Dynamo bytecode transform time: 8.31 s
# (EngineCore pid=3192) INFO 08-13 05:02:08 [backends.py:378] Cache the graph of compile range (1, 2048) for later use
# (EngineCore pid=3192) [rank0]:W0813 05:02:09.433000 3192 torch/_inductor/utils.py:1731] Not enough SMs to use max_autotune_gemm mode
# (EngineCore pid=3192) INFO 08-13 05:02:15 [backends.py:393] Compiling a graph for compile range (1, 2048) takes 13.23 s
# (EngineCore pid=3192) INFO 08-13 05:02:24 [decorators.py:708] saved AOT compiled function to /root/.cache/vllm/torch_compile_cache/torch_aot_compile/5f338c9a46ef4c841be038d081ba0c7cc5acd88386f0b654b421c3e6b686f023/rank_0_0/model
# (EngineCore pid=3192) INFO 08-13 05:02:24 [monitor.py:53] torch.compile took 31.43 s in total
# (EngineCore pid=3192) INFO 08-13 05:02:25 [monitor.py:81] Initial profiling/warmup run took 0.58 s
# (EngineCore pid=3192) INFO 08-13 05:02:37 [gpu_model_runner.py:6412] Profiling CUDA graph memory: PIECEWISE=51 (largest=512), FULL=35 (largest=256)
# (EngineCore pid=3192) INFO 08-13 05:05:25 [gpu_model_runner.py:6517] Estimated CUDA graph memory: 1.22 GiB total
# (EngineCore pid=3192) INFO 08-13 05:05:26 [gpu_worker.py:480] Available KV cache memory: 8.62 GiB
# (EngineCore pid=3192) INFO 08-13 05:05:26 [gpu_worker.py:495] CUDA graph memory profiling is enabled (default since v0.21.0). The current --gpu-memory-utilization=0.7800 is equivalent to --gpu-memory-utilization=0.6964 without CUDA graph memory profiling. To maintain the same effective KV cache size as before, increase --gpu-memory-utilization to 0.8636. To disable, set VLLM_MEMORY_PROFILER_ESTIMATE_CUDAGRAPHS=0.
# (EngineCore pid=3192) INFO 08-13 05:05:26 [kv_cache_utils.py:1744] GPU KV cache size: 752,848 tokens
# (EngineCore pid=3192) INFO 08-13 05:05:26 [kv_cache_utils.py:1745] Maximum concurrency for 4,096 tokens per request: 183.80x
# (EngineCore pid=3192) INFO 08-13 05:05:26 [kernel_warmup.py:97] Warming up FlashInfer attention.
# (EngineCore pid=3192)
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):   0%|          | 0/51 [00:00<?, ?it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):   4%|▍         | 2/51 [00:00<00:02, 18.95it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):   8%|▊         | 4/51 [00:00<00:02, 19.36it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  14%|█▎        | 7/51 [00:00<00:02, 19.91it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  20%|█▉        | 10/51 [00:00<00:01, 20.93it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  25%|██▌       | 13/51 [00:00<00:01, 22.62it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  31%|███▏      | 16/51 [00:00<00:01, 23.62it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  37%|███▋      | 19/51 [00:00<00:01, 24.99it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  43%|████▎     | 22/51 [00:00<00:01, 25.47it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  49%|████▉     | 25/51 [00:01<00:00, 26.33it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  55%|█████▍    | 28/51 [00:01<00:00, 26.42it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  61%|██████    | 31/51 [00:01<00:00, 26.63it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  67%|██████▋   | 34/51 [00:01<00:00, 22.71it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  73%|███████▎  | 37/51 [00:01<00:00, 23.45it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  78%|███████▊  | 40/51 [00:01<00:00, 24.67it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  84%|████████▍ | 43/51 [00:01<00:00, 25.23it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  90%|█████████ | 46/51 [00:01<00:00, 24.85it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  96%|█████████▌| 49/51 [00:02<00:00, 25.20it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 51/51 [00:02<00:00, 22.52it/s]
# (EngineCore pid=3192)
# Capturing CUDA graphs (decode, FULL):   0%|          | 0/35 [00:00<?, ?it/s]
# Capturing CUDA graphs (decode, FULL):   9%|▊         | 3/35 [00:00<00:01, 22.70it/s]
# Capturing CUDA graphs (decode, FULL):  17%|█▋        | 6/35 [00:00<00:01, 21.54it/s]
# Capturing CUDA graphs (decode, FULL):  26%|██▌       | 9/35 [00:00<00:01, 22.63it/s]
# Capturing CUDA graphs (decode, FULL):  34%|███▍      | 12/35 [00:00<00:00, 23.14it/s]
# Capturing CUDA graphs (decode, FULL):  43%|████▎     | 15/35 [00:00<00:00, 23.48it/s]
# Capturing CUDA graphs (decode, FULL):  51%|█████▏    | 18/35 [00:00<00:00, 23.94it/s]
# Capturing CUDA graphs (decode, FULL):  60%|██████    | 21/35 [00:01<00:00, 17.86it/s]
# Capturing CUDA graphs (decode, FULL):  69%|██████▊   | 24/35 [00:01<00:00, 19.38it/s]
# Capturing CUDA graphs (decode, FULL):  77%|███████▋  | 27/35 [00:01<00:00, 20.40it/s]
# Capturing CUDA graphs (decode, FULL):  86%|████████▌ | 30/35 [00:01<00:00, 21.90it/s]
# Capturing CUDA graphs (decode, FULL):  94%|█████████▍| 33/35 [00:01<00:00, 23.14it/s]
# Capturing CUDA graphs (decode, FULL): 100%|██████████| 35/35 [00:01<00:00, 20.85it/s]
# (EngineCore pid=3192) INFO 08-13 05:05:31 [gpu_model_runner.py:6585] Graph capturing finished in 5 secs, took 0.65 GiB
# (EngineCore pid=3192) INFO 08-13 05:05:31 [gpu_worker.py:639] CUDA graph pool memory: 0.65 GiB (actual), 1.22 GiB (estimated), difference: 0.57 GiB (87.7%).
# (EngineCore pid=3192) INFO 08-13 05:05:31 [jit_monitor.py:54] Kernel JIT monitor activated — Triton JIT compilations during inference will be logged as warnings.
# (EngineCore pid=3192) INFO 08-13 05:05:32 [core.py:306] init engine (profile, create kv cache, warmup model) took 219.38 s (compilation: 31.43 s)
# (EngineCore pid=3192) INFO 08-13 05:05:33 [vllm.py:999] Asynchronous scheduling is enabled.
# (EngineCore pid=3192) INFO 08-13 05:05:33 [kernel.py:270] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native'])
# (APIServer pid=2848) INFO 08-13 05:05:33 [api_server.py:579] Supported tasks: ['generate']
# (APIServer pid=2848) WARNING 08-13 05:05:34 [model.py:1502] Default vLLM sampling parameters have been overridden by the model's `generation_config.json`: `{'repetition_penalty': 1.1, 'temperature': 0.7, 'top_k': 20, 'top_p': 0.8}`. If this is not intended, please relaunch vLLM instance with `--generation-config vllm`.
# (APIServer pid=2848) INFO 08-13 05:05:35 [hf.py:548] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# (APIServer pid=2848) INFO 08-13 05:05:35 [api_server.py:583] Starting vLLM server on http://127.0.0.1:8000
# (APIServer pid=2848) INFO 08-13 05:05:35 [launcher.py:37] Available routes are:
# (APIServer pid=2848) INFO 08-13 05:05:35 [launcher.py:46] Route: /openapi.json, Methods: HEAD, GET
# (APIServer pid=2848) INFO 08-13 05:05:35 [launcher.py:46] Route: /docs, Methods: HEAD, GET
# (APIServer pid=2848) INFO 08-13 05:05:35 [launcher.py:46] Route: /docs/oauth2-redirect, Methods: HEAD, GET
# (APIServer pid=2848) INFO 08-13 05:05:35 [launcher.py:46] Route: /redoc, Methods: HEAD, GET
# (APIServer pid=2848) INFO 08-13 05:05:35 [launcher.py:46] Route: /metrics, Methods: GET
# (APIServer pid=2848) INFO:     Started server process [2848]
# (APIServer pid=2848) INFO:     Waiting for application startup.
# (APIServer pid=2848) INFO:     Application startup complete.
# (APIServer pid=2848) INFO:     127.0.0.1:51636 - "GET /v1/models HTTP/1.1" 200 OK
#
# ================================================================================
# vLLM SERVER READY
# ================================================================================
# Endpoint: http://127.0.0.1:8000
# Logs: /content/vllm_lab_results/vllm_server.log
#
# (APIServer pid=2848) INFO:     127.0.0.1:51644 - "POST /v1/completions HTTP/1.1" 200 OK
# (EngineCore pid=3192) WARNING 08-13 05:05:37 [jit_monitor.py:103] Triton kernel JIT compilation during inference: _compute_slot_mapping_kernel. This causes a latency spike; consider extending warmup to cover this shape/config.
# READY

# %% [markdown]
# # Experiment 1 - Can you observe prefill and decode?
#
# **Concept recap:** Prefill processes the input prompt and produces the first output token. Decode then generates later tokens sequentially. Time to first token (TTFT) is therefore strongly connected to prefill, while time per output token is connected to decode.
#
# You will run two controlled experiments:
#
# - Change prompt length while keeping output length short.
# - Change output length while keeping the prompt fixed.
#
# ### Your Prediction
# Before coding, which measurement should react most clearly to a much longer prompt? Which measurement should react most clearly to a much longer generated output?

# %% [markdown]
# > **Your response**
# >
# > A much longer prompt should affect **TTFT** most clearly because more prompt tokens must be processed during prefill before the first output token can be returned. A much longer generated output should affect **end-to-end latency** most clearly because decode must produce more tokens sequentially. TPOT is a per-token decode metric, so it may stay roughly similar even when total generation time grows.

# %% [markdown]
# ### Task 1A - Vary prompt length
#
# Complete the cell. Create four prompts of increasing length, request exactly 8 output tokens, and store the prompt token count and median measurements in `prefill_rows`.

# %%
prompt_repeats = [4, 16, 48, 96]
prefill_rows = []

for repeats in prompt_repeats:
    # TODO 1: Create a prompt by repeating the sentence below `repeats` times.
    # Add a short final instruction so the request still looks natural.
    base_sentence = "Efficient LLM inference has a prefill phase and a decode phase. "
    prompt = base_sentence * repeats + "Summarize the main idea in one sentence."

    # TODO 2: Use repeat_request with max_tokens=8.
    measurement = repeat_request(prompt, max_tokens=8)

    # TODO 3: Append a dictionary with these fields:
    # prompt_tokens, median_ttft_ms, median_e2e_ms, median_tpot_ms
    # Replace the pass statement with your code.
    prefill_rows.append(
        {
            "prompt_tokens": len(
                tokenizer.encode(prompt, add_special_tokens=False)
            ),
            "median_ttft_ms": measurement["median_ttft_ms"],
            "median_e2e_ms": measurement["median_e2e_ms"],
            "median_tpot_ms": measurement["median_tpot_ms"],
        }
    )

prefill_df = pd.DataFrame(prefill_rows)
display(prefill_df)
# Out:
# (APIServer pid=2848) INFO:     127.0.0.1:51660 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51672 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51678 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51692 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51700 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51716 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51730 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51734 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51744 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51756 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51772 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51780 - "POST /v1/completions HTTP/1.1" 200 OK
#    prompt_tokens  median_ttft_ms  median_e2e_ms  median_tpot_ms
# 0             67       24.400547      75.790155        7.419659
# 1            235       28.566977      65.607160        5.426561
# 2            683       43.535671      82.042257        5.631500
# 3           1355       64.715348     107.479814        5.953158

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# Only prompt length should change. The output length must stay at 8 for every row. Use `tokenizer.encode(..., add_special_tokens=False)` to count prompt tokens.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# Pseudocode:
#
#     for each repeat count
#         make prompt
#         measurement = repeat_request(prompt, 8)
#         append prompt token count and measurement values
#
# </details>

# %%
required = {"prompt_tokens", "median_ttft_ms", "median_e2e_ms", "median_tpot_ms"}
if (
    isinstance(prefill_df, pd.DataFrame)
    and len(prefill_df) == 4
    and required.issubset(prefill_df.columns)
):
    if prefill_df["prompt_tokens"].is_monotonic_increasing:
        print("PASS")
    else:
        print("CHECK AGAIN")
else:
    print("CHECK AGAIN")
# Out:
# PASS

# %% [markdown]
# ### Task 1B - Vary output length
#
# Now keep the prompt fixed and vary `max_tokens` across 4, 16, 32, and 64. Store your results in `decode_rows` and create `decode_df`.

# %%
fixed_prompt = (
    "A language model first processes the prompt and then generates tokens one at a time. "
    "Explain why these phases have different performance characteristics."
)
output_lengths = [4, 16, 32, 64]
decode_rows = []

# TODO: Write the loop. Store max_tokens, median_ttft_ms,
# median_e2e_ms, and median_tpot_ms for each output length.
for max_tokens in output_lengths:
    measurement = repeat_request(fixed_prompt, max_tokens=max_tokens)
    decode_rows.append(
        {
            "max_tokens": max_tokens,
            "median_ttft_ms": measurement["median_ttft_ms"],
            "median_e2e_ms": measurement["median_e2e_ms"],
            "median_tpot_ms": measurement["median_tpot_ms"],
        }
    )


decode_df = pd.DataFrame(decode_rows)
display(decode_df)
# Out:
# (APIServer pid=2848) INFO:     127.0.0.1:51788 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51800 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51804 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51806 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51816 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51828 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51830 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51832 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51840 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:51854 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33744 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33754 - "POST /v1/completions HTTP/1.1" 200 OK
#    max_tokens  median_ttft_ms  median_e2e_ms  median_tpot_ms
# 0           4       21.694528      35.996693        4.719177
# 1          16       24.192365     108.650943        5.592966
# 2          32       22.358891     198.698040        5.684514
# 3          64       24.678583     388.533721        5.786270

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# The prompt must be identical on every iteration. The only independent variable is `max_tokens`.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# Pseudocode:
#
#     for each output length
#         measurement = repeat_request(fixed_prompt, output length)
#         append output length and measurement values
#
# </details>

# %%
required = {"max_tokens", "median_ttft_ms", "median_e2e_ms", "median_tpot_ms"}
if (
    isinstance(decode_df, pd.DataFrame)
    and len(decode_df) == 4
    and required.issubset(decode_df.columns)
):
    if sorted(decode_df["max_tokens"].tolist()) == [4, 16, 32, 64]:
        print("PASS")
    else:
        print("CHECK AGAIN")
else:
    print("CHECK AGAIN")
# Out:
# PASS

# %% [markdown]
# ### Explain Experiment 1
#
# 1. What happened to TTFT as prompt length increased?
# 2. What happened to end-to-end latency as output length increased?
# 3. Why can one end-to-end timer hide whether time is being spent in prefill or decode?
# 4. Did your measurements perfectly match your prediction? If not, give one plausible source of noise.

# %% [markdown]
# > **Your response**
# >
# > 1. As `prompt_tokens` increases, `median_ttft_ms` should generally increase because prefill has more input tokens to process. The exact increase is hardware- and runtime-dependent, so use the first and last rows of `prefill_df` for the numerical comparison.
# > 2. As `max_tokens` increases, `median_e2e_ms` should increase clearly because more sequential decode steps are required. TTFT should move much less because the prompt is unchanged.
# > 3. One end-to-end timer combines prefill, queueing/serving overhead, and decode. A larger total therefore does not reveal which phase caused the change. TTFT and TPOT separate the prefill-facing and decode-facing effects more clearly.
# > 4. Measurements may not match the prediction perfectly because of GPU frequency changes, background/runtime activity, request scheduling, HTTP/streaming overhead, allocator effects, or ordinary run-to-run noise. That is why the notebook uses repeated measurements and medians.

# %% [markdown]
# # Experiment 2 - Does more concurrency make inference faster?
#
# **Concept recap:** Inference engines batch and schedule work from multiple requests to use the GPU efficiently. Higher concurrency can increase aggregate throughput, but an individual request may wait longer or compete for resources. Throughput and latency therefore answer different questions.
#
# ### Prediction
# As concurrency increases from 1 to 8, what do you expect to happen to output tokens per second and median TTFT?

# %% [markdown]
# > **Your response**
# >
# > I expect aggregate **output tokens per second to increase at first** as concurrency gives vLLM more requests to batch and schedule efficiently, but the increase should become sublinear or saturate once the GPU is well utilized. I expect **median TTFT to increase overall** at higher concurrency because each request may wait behind or share resources with more work, although small non-monotonic changes are possible at low concurrency.

# %% [markdown]
# ### Task 2 - Design the concurrency experiment
#
# The helper `run_concurrent_requests(prompts, concurrency, max_tokens)` is provided. It returns the completed request dictionaries and total wall time.
#
# For each concurrency level 1, 2, 4, and 8:
#
# - create enough unique prompts to keep workers busy;
# - call the helper;
# - calculate aggregate output tokens per second;
# - calculate median TTFT and median end-to-end latency;
# - append one row to `concurrency_rows`.

# %%
concurrency_levels = [1, 2, 4, 8]
concurrency_rows = []

for concurrency in concurrency_levels:
    total_requests = max(8, 2 * concurrency)
    prompts = [
        f"Unique request {i} at concurrency {concurrency}. Explain one inference metric briefly."
        for i in range(total_requests)
    ]

    # TODO 1: Call run_concurrent_requests with max_tokens=32.
    results, wall_s = run_concurrent_requests(
        prompts, concurrency=concurrency, max_tokens=32
    )

    # TODO 2: Calculate total output tokens / wall_s.
    output_tokens_per_s = sum(r["output_tokens"] for r in results) / wall_s

    # TODO 3: Calculate median TTFT and median E2E from `results`.
    median_ttft_ms = statistics.median(r["ttft_ms"] for r in results)
    median_e2e_ms = statistics.median(r["e2e_ms"] for r in results)

    # TODO 4: Append one dictionary to concurrency_rows.
    concurrency_rows.append(
        {
            "concurrency": concurrency,
            "output_tokens_per_s": output_tokens_per_s,
            "median_ttft_ms": median_ttft_ms,
            "median_e2e_ms": median_e2e_ms,
        }
    )

concurrency_df = pd.DataFrame(concurrency_rows)
display(concurrency_df)
# Out:
# (APIServer pid=2848) INFO:     127.0.0.1:33764 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33778 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33784 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33800 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33814 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33830 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33838 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33850 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33856 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33866 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33880 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33882 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33884 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33894 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33910 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33922 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33946 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33932 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33956 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33958 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33974 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:33988 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34004 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34014 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34028 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34030 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34038 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34042 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34058 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34072 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34080 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34094 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34102 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34112 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34114 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34128 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34136 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34140 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34156 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34164 - "POST /v1/completions HTTP/1.1" 200 OK
#    concurrency  output_tokens_per_s  median_ttft_ms  median_e2e_ms
# 0            1           159.901043       21.610658     199.238819
# 1            2           266.905084       39.242967     209.857516
# 2            4           529.744567       58.362111     239.482387
# 3            8           898.729320       80.145509     277.727585

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# Each element of `results` has the keys `output_tokens`, `ttft_ms`, and `e2e_ms`. Use `sum` for total tokens and `statistics.median` for latency.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# Pseudocode:
#
#     results, wall = run concurrent requests
#     throughput = sum output tokens divided by wall
#     median ttft = median of request ttft values
#     median e2e = median of request e2e values
#     append one summary row
#
# </details>

# %%
required = {"concurrency", "output_tokens_per_s", "median_ttft_ms", "median_e2e_ms"}
if (
    isinstance(concurrency_df, pd.DataFrame)
    and len(concurrency_df) == 4
    and required.issubset(concurrency_df.columns)
):
    if sorted(concurrency_df["concurrency"].tolist()) == [1, 2, 4, 8]:
        print("PASS")
    else:
        print("CHECK AGAIN")
else:
    print("CHECK AGAIN")
# Out:
# PASS

# %% [markdown]
# ### Visualize and explain
#
# Create one plot for throughput versus concurrency and one plot for median TTFT versus concurrency. Choose clear axis labels.

# %%
# TODO: Create two plots from concurrency_df.
# You may use pandas plotting or matplotlib directly.
plt.figure()
plt.plot(
    concurrency_df["concurrency"],
    concurrency_df["output_tokens_per_s"],
    marker="o",
)
plt.xlabel("Concurrency")
plt.ylabel("Output tokens per second")
plt.title("Throughput vs concurrency")
plt.grid(True, alpha=0.3)
plt.show()

plt.figure()
plt.plot(
    concurrency_df["concurrency"],
    concurrency_df["median_ttft_ms"],
    marker="o",
)
plt.xlabel("Concurrency")
plt.ylabel("Median TTFT (ms)")
plt.title("Median TTFT vs concurrency")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ### Explain Experiment 2
#
# 1. Did throughput increase linearly with concurrency?
# 2. What happened to median TTFT?
# 3. Is the concurrency setting with the highest throughput automatically the best setting for an interactive application? Why?

# %% [markdown]
# > **Your response**
# >
# > 1. Throughput will usually increase with concurrency, but not linearly all the way to 8. Batching and better GPU utilization help at first; once a bottleneck is saturated, each additional concurrent request contributes less extra throughput.
# > 2. Median TTFT will usually rise at the higher concurrency settings because requests spend more time waiting or competing for scheduled GPU work. Small deviations from a perfectly monotonic trend are normal.
# > 3. No. The highest-throughput setting is not automatically best for an interactive application. Interactive systems also care about how quickly an individual user sees the first token and the final answer, so a useful operating point balances aggregate throughput against TTFT and end-to-end latency.

# %% [markdown]
# # Experiment 3 - What does prefix caching save?
#
# **Concept recap:** If later requests begin with the same long prefix, vLLM can reuse cached KV state for that prefix instead of repeating all of its prefill computation. This should mainly affect the work done before the first new token is produced.
#
# ### Prediction
# Which metric should show the clearest improvement when a long prefix is reused: TTFT, TPOT, or both equally? Explain why before running the comparison.

# %% [markdown]
# > **Your response**
# >
# > **TTFT should improve most clearly.** Prefix caching reuses KV state for the repeated prompt prefix, so the server can avoid much of the repeated prefill work before generating the first new token. TPOT should change much less because the later decode tokens are still generated sequentially in the usual way. End-to-end latency may also fall, especially here where the output is intentionally short, but the mechanism is primarily a prefill/TTFT optimization.

# %% [markdown]
# ### Task 3A - Build a cacheable workload
#
# Create one long `shared_prefix` and at least four different suffix questions. The combined prompts must all begin with exactly the same `shared_prefix`.

# %%
base_prefix_text = (
    "Course note. Prefill processes prompt tokens in parallel. Decode generates later tokens "
    "sequentially. KV caching stores key and value representations from previous tokens. "
    "Prefix caching can reuse KV state across requests that begin with the same token prefix. "
)

# TODO 1: Build a long shared prefix by repeating base_prefix_text.
# Aim for roughly 800 to 1600 tokens so the effect is visible but fits MAX_MODEL_LEN.
base_prefix_tokens = len(
    tokenizer.encode(base_prefix_text, add_special_tokens=False)
)
prefix_repeats = math.ceil(1200 / base_prefix_tokens)
shared_prefix = base_prefix_text * prefix_repeats

suffixes = [
    "Define TTFT in one sentence.",
    "Which phase is most related to TTFT?",
    "What information is stored in a KV cache?",
    "Why can a shared prefix reduce repeated work?",
]

# TODO 2: Build `prefix_prompts` by combining the identical prefix with each suffix.
prefix_prompts = [shared_prefix + "\n\n" + suffix for suffix in suffixes]

if shared_prefix is not None:
    print(
        "Shared prefix tokens",
        len(tokenizer.encode(shared_prefix, add_special_tokens=False)),
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_985/3252518106.py in <cell line: 0>()
#       8 # Aim for roughly 800 to 1600 tokens so the effect is visible but fits MAX_MODEL_LEN.
#       9 base_prefix_tokens = len(
# ---> 10     tokenizer.encode(base_prefix_text, add_special_tokens=False)
#      11 )
#      12 prefix_repeats = math.ceil(1200 / base_prefix_tokens)
#
# NameError: name 'tokenizer' is not defined

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# The prefix must be byte-for-byte identical before every suffix. Repeating the provided paragraph many times is enough for this lab.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# Pseudocode:
#
#     shared prefix = base text repeated N times
#     prompts = shared prefix plus each suffix
#
# </details>

# %%
if isinstance(shared_prefix, str) and len(prefix_prompts) >= 4:
    token_count = len(tokenizer.encode(shared_prefix, add_special_tokens=False))
    same_prefix = all(p.startswith(shared_prefix) for p in prefix_prompts)
    within_limit = token_count < MAX_MODEL_LEN - 64
    if token_count >= 800 and same_prefix and within_limit:
        print("PASS")
    else:
        print("CHECK AGAIN")
else:
    print("CHECK AGAIN")
# Out:
# PASS

# %% [markdown]
# ### Task 3B - Measure prefix caching OFF
#
# The current server still has prefix caching disabled. Measure the four prompts with a short output of 8 tokens and store the request dictionaries in `prefix_off_results`.

# %%
# TODO: Send each prompt once with max_tokens=8 and store the results.
prefix_off_results = [
    stream_completion(prompt, max_tokens=8) for prompt in prefix_prompts
]

# Optional: display a small table after you have filled the list.
# Out:
# (APIServer pid=2848) INFO:     127.0.0.1:34172 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34180 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34190 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=2848) INFO:     127.0.0.1:34202 - "POST /v1/completions HTTP/1.1" 200 OK

# %%
if (
    isinstance(prefix_off_results, list)
    and len(prefix_off_results) == len(prefix_prompts)
    and len(prefix_off_results) >= 4
):
    if all(isinstance(r, dict) and "ttft_ms" in r for r in prefix_off_results):
        print("PASS")
    else:
        print("CHECK AGAIN")
else:
    print("CHECK AGAIN")
# Out:
# PASS

# %% [markdown]
# ### Switch the server to prefix caching ON
#
# This is provided plumbing code. Run it as-is. After the restart, **you** must prime the cache before measuring.

# %%
start_server(prefix_caching=True)
_ = stream_completion("Unrelated server warm up", max_tokens=8)
print("READY")
# Out:
# (APIServer pid=2848) INFO 08-13 05:05:46 [launcher.py:100] [shutdown] API server: shutdown triggered
# (APIServer pid=2848) INFO 08-13 05:05:46 [launcher.py:116] [shutdown] API server: stopping engine client mode=abort timeout=0s
# (APIServer pid=2848) INFO 08-13 05:05:46 [core_client.py:652] [shutdown] MPClient: start timeout=0s
# (APIServer pid=2848) INFO 08-13 05:05:46 [core_client.py:654] [shutdown] MPClient: stopping engine manager
# (APIServer pid=2848) WARNING 08-13 05:05:46 [utils.py:607] [shutdown] Process manager: force killing remaining processes count=1
# (EngineCore pid=3192) INFO 08-13 05:05:46 [core.py:1178] [shutdown] EngineCore: trigger received signal=SIGTERM
# (APIServer pid=2848) INFO 08-13 05:05:46 [core_client.py:656] [shutdown] MPClient: engine manager stopped
# (APIServer pid=2848) INFO 08-13 05:05:46 [core_client.py:657] [shutdown] MPClient: cleaning up background resources
# (APIServer pid=2848) INFO 08-13 05:05:46 [core_client.py:659] [shutdown] MPClient: complete
# (APIServer pid=2848) INFO 08-13 05:05:46 [launcher.py:125] [shutdown] API server: engine client stopped
# (APIServer pid=2848) INFO 08-13 05:05:46 [launcher.py:128] [shutdown] API server: signalling HTTP server shutdown
# (APIServer pid=2848) INFO 08-13 05:05:46 [launcher.py:149] [shutdown] API server: shutting down FastAPI HTTP server
# (APIServer pid=2848) INFO:     Shutting down
# (APIServer pid=2848) INFO:     Waiting for application shutdown.
# (APIServer pid=2848) INFO:     Application shutdown complete.
# /usr/lib/python3.12/multiprocessing/resource_tracker.py:279: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# ================================================================================
# Starting vLLM server
# ================================================================================
# Model: Qwen/Qwen2.5-0.5B-Instruct
# Port: 8000
# Prefix caching: True
# GPU memory utilization: 0.78
# Max model length: 4096
#
# Command:
# /usr/bin/python3 -m vllm.entrypoints.cli.main serve Qwen/Qwen2.5-0.5B-Instruct --host 127.0.0.1 --port 8000 --dtype float16 --gpu-memory-utilization 0.78 --max-model-len 4096 --enable-prefix-caching
#
# --------------------------------------------------------------------------------
# vLLM LOG
# --------------------------------------------------------------------------------
# (APIServer pid=4821) INFO 08-13 05:06:17 [api_utils.py:339]
# (APIServer pid=4821) INFO 08-13 05:06:17 [api_utils.py:339]        █     █     █▄   ▄█
# (APIServer pid=4821) INFO 08-13 05:06:17 [api_utils.py:339]  ▄▄ ▄█ █     █     █ ▀▄▀ █  version 0.23.0
# (APIServer pid=4821) INFO 08-13 05:06:17 [api_utils.py:339]   █▄█▀ █     █     █     █  model   Qwen/Qwen2.5-0.5B-Instruct
# (APIServer pid=4821) INFO 08-13 05:06:17 [api_utils.py:339]    ▀▀  ▀▀▀▀▀ ▀▀▀▀▀ ▀     ▀
# (APIServer pid=4821) INFO 08-13 05:06:17 [api_utils.py:339]
# (APIServer pid=4821) INFO 08-13 05:06:17 [api_utils.py:273] non-default args: {'model_tag': 'Qwen/Qwen2.5-0.5B-Instruct', 'host': '127.0.0.1', 'model': 'Qwen/Qwen2.5-0.5B-Instruct', 'dtype': 'float16', 'max_model_len': 4096, 'gpu_memory_utilization': 0.78, 'enable_prefix_caching': True}
# (APIServer pid=4821) Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# (APIServer pid=4821) INFO 08-13 05:06:18 [model.py:611] Resolved architecture: Qwen2ForCausalLM
# (APIServer pid=4821) WARNING 08-13 05:06:18 [model.py:2083] Casting torch.bfloat16 to torch.float16.
# (APIServer pid=4821) INFO 08-13 05:06:18 [model.py:1745] Using max model len 4096
# (APIServer pid=4821) INFO 08-13 05:06:18 [vllm.py:999] Asynchronous scheduling is enabled.
# (APIServer pid=4821) INFO 08-13 05:06:18 [kernel.py:270] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native'])
# (EngineCore pid=4965) INFO 08-13 05:06:40 [core.py:113] Initializing a V1 LLM engine (v0.23.0) with config: model='Qwen/Qwen2.5-0.5B-Instruct', speculative_config=None, tokenizer='Qwen/Qwen2.5-0.5B-Instruct', skip_tokenizer_init=False, tokenizer_mode=auto, revision=None, tokenizer_revision=None, trust_remote_code=False, dtype=torch.float16, max_seq_len=4096, download_dir=None, load_format=auto, tensor_parallel_size=1, pipeline_parallel_size=1, data_parallel_size=1, decode_context_parallel_size=1, dcp_comm_backend=ag_rs, disable_custom_all_reduce=False, quantization=None, quantization_config=None, enforce_eager=False, enable_return_routed_experts=False, kv_cache_dtype=auto, device_config=cuda, structured_outputs_config=StructuredOutputsConfig(backend='auto', disable_any_whitespace=False, disable_additional_properties=False, reasoning_parser='', reasoning_parser_plugin='', enable_in_reasoning=False), observability_config=ObservabilityConfig(show_hidden_metrics_for_version=None, otlp_traces_endpoint=None, collect_detailed_traces=None, kv_cache_metrics=False, kv_cache_metrics_sample=0.01, cudagraph_metrics=False, enable_layerwise_nvtx_tracing=False, enable_mfu_metrics=False, enable_mm_processor_stats=False, enable_logging_iteration_details=False), seed=0, served_model_name=Qwen/Qwen2.5-0.5B-Instruct, enable_prefix_caching=True, enable_chunked_prefill=True, pooler_config=None, compilation_config={'mode': <CompilationMode.VLLM_COMPILE: 3>, 'debug_dump_path': None, 'cache_dir': '', 'compile_cache_save_format': 'binary', 'backend': 'inductor', 'custom_ops': ['none'], 'ir_enable_torch_wrap': True, 'splitting_ops': ['vllm::unified_attention_with_output', 'vllm::unified_mla_attention_with_output', 'vllm::mamba_mixer2', 'vllm::mamba_mixer', 'vllm::short_conv', 'vllm::linear_attention', 'vllm::plamo2_mamba_mixer', 'vllm::qwen_gdn_attention_core', 'vllm::gdn_attention_core_xpu', 'vllm::olmo_hybrid_gdn_full_forward', 'vllm::kda_attention', 'vllm::sparse_attn_indexer', 'vllm::rocm_aiter_sparse_attn_indexer', 'vllm::deepseek_v4_attention', 'vllm::unified_kv_cache_update', 'vllm::unified_mla_kv_cache_update'], 'compile_mm_encoder': False, 'cudagraph_mm_encoder': False, 'encoder_cudagraph_token_budgets': [], 'encoder_cudagraph_max_vision_items_per_batch': 0, 'encoder_cudagraph_max_frames_per_batch': None, 'compile_sizes': [], 'compile_ranges_endpoints': [2048], 'inductor_compile_config': {'enable_auto_functionalized_v2': False, 'size_asserts': False, 'alignment_asserts': False, 'scalar_asserts': False, 'combo_kernels': True, 'benchmark_combo_kernel': True}, 'inductor_passes': {}, 'cudagraph_mode': <CUDAGraphMode.FULL_AND_PIECEWISE: (2, 1)>, 'cudagraph_num_of_warmups': 1, 'cudagraph_capture_sizes': [1, 2, 4, 8, 16, 24, 32, 40, 48, 56, 64, 72, 80, 88, 96, 104, 112, 120, 128, 136, 144, 152, 160, 168, 176, 184, 192, 200, 208, 216, 224, 232, 240, 248, 256, 272, 288, 304, 320, 336, 352, 368, 384, 400, 416, 432, 448, 464, 480, 496, 512], 'cudagraph_copy_inputs': False, 'cudagraph_specialize_lora': True, 'use_inductor_graph_partition': False, 'pass_config': {'fuse_norm_quant': False, 'fuse_act_quant': False, 'fuse_attn_quant': False, 'enable_sp': False, 'fuse_gemm_comms': False, 'fuse_allreduce_rms': False, 'fuse_rope_kvcache_cat_mla': False, 'fuse_act_padding': False}, 'max_cudagraph_capture_size': 512, 'dynamic_shapes_config': {'type': <DynamicShapesType.BACKED: 'backed'>, 'evaluate_guards': False, 'assume_32_bit_indexing': False}, 'local_cache_dir': None, 'fast_moe_cold_start': False, 'static_all_moe_layers': []}, kernel_config=KernelConfig(ir_op_priority=IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native']), enable_flashinfer_autotune=True, moe_backend='auto', linear_backend='auto')
# (EngineCore pid=4965) INFO 08-13 05:06:41 [parallel_state.py:1568] world_size=1 rank=0 local_rank=0 distributed_init_method=tcp://172.28.0.12:42813 backend=nccl
# (EngineCore pid=4965) INFO 08-13 05:06:41 [parallel_state.py:1903] rank 0 in world size 1 is assigned as DP rank 0, PP rank 0, PCP rank 0, TP rank 0, EP rank N/A, EPLB rank N/A
# (EngineCore pid=4965) INFO 08-13 05:06:41 [topk_topp_sampler.py:39] FlashInfer top-p/top-k sampling disabled via VLLM_USE_FLASHINFER_SAMPLER=0.
# (EngineCore pid=4965) INFO 08-13 05:06:41 [gpu_model_runner.py:5092] Starting to load model Qwen/Qwen2.5-0.5B-Instruct...
# (EngineCore pid=4965) ERROR 08-13 05:06:42 [fa_utils.py:171] Cannot use FA version 2 is not supported due to FA2 is only supported on devices with compute capability >= 8
# (EngineCore pid=4965) INFO 08-13 05:06:43 [cuda.py:378] Using FLASHINFER attention backend out of potential backends: ['FLASHINFER', 'TRITON_ATTN', 'FLEX_ATTENTION'].
# (EngineCore pid=4965) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.cudart module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.runtime module instead.
# (EngineCore pid=4965) <frozen importlib._bootstrap_external>:1301: FutureWarning: The cuda.nvrtc module is deprecated and will be removed in a future release, please switch to use the cuda.bindings.nvrtc module instead.
# (EngineCore pid=4965) Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# (EngineCore pid=4965) INFO 08-13 05:06:45 [weight_utils.py:647] No model.safetensors.index.json found in remote.
# (EngineCore pid=4965) INFO 08-13 05:06:45 [weight_utils.py:922] Filesystem type for checkpoints: OVERLAY. Checkpoint size: 0.92 GiB. Available RAM: 7.51 GiB.
# (EngineCore pid=4965) INFO 08-13 05:06:45 [weight_utils.py:945] Auto-prefetch is disabled because the filesystem (OVERLAY) is not a recognized network FS (NFS/Lustre). If you want to force prefetching, start vLLM with --safetensors-load-strategy=prefetch.
# (EngineCore pid=4965)
# Loading safetensors checkpoint shards:   0% Completed | 0/1 [00:00<?, ?it/s]
# (EngineCore pid=4965)
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:01<00:00,  1.26s/it]
# (EngineCore pid=4965)
# Loading safetensors checkpoint shards: 100% Completed | 1/1 [00:01<00:00,  1.26s/it]
# (EngineCore pid=4965)
# (EngineCore pid=4965) INFO 08-13 05:06:46 [default_loader.py:397] Loading weights took 1.34 seconds
# (EngineCore pid=4965) INFO 08-13 05:06:47 [gpu_model_runner.py:5187] Model loading took 0.93 GiB memory and 4.173693 seconds
# (EngineCore pid=4965) INFO 08-13 05:06:52 [backends.py:1089] Using cache directory: /root/.cache/vllm/torch_compile_cache/9c1dad01d5/rank_0_0/backbone for vLLM's torch.compile
# (EngineCore pid=4965) INFO 08-13 05:06:52 [backends.py:1148] Dynamo bytecode transform time: 4.79 s
# (EngineCore pid=4965) INFO 08-13 05:06:53 [backends.py:292] Directly load the compiled graph(s) for compile range (1, 2048) from the cache, took 0.968 s
# (EngineCore pid=4965) INFO 08-13 05:06:53 [decorators.py:311] Directly load AOT compilation from path /root/.cache/vllm/torch_compile_cache/torch_aot_compile/5f338c9a46ef4c841be038d081ba0c7cc5acd88386f0b654b421c3e6b686f023/rank_0_0/model
# (EngineCore pid=4965) INFO 08-13 05:06:53 [monitor.py:53] torch.compile took 6.03 s in total
# (EngineCore pid=4965) INFO 08-13 05:06:53 [monitor.py:81] Initial profiling/warmup run took 0.13 s
# (EngineCore pid=4965) INFO 08-13 05:07:04 [gpu_model_runner.py:6412] Profiling CUDA graph memory: PIECEWISE=51 (largest=512), FULL=35 (largest=256)
# (EngineCore pid=4965) INFO 08-13 05:07:06 [gpu_model_runner.py:6517] Estimated CUDA graph memory: 1.22 GiB total
# (EngineCore pid=4965) INFO 08-13 05:07:07 [gpu_worker.py:480] Available KV cache memory: 8.62 GiB
# (EngineCore pid=4965) INFO 08-13 05:07:07 [gpu_worker.py:495] CUDA graph memory profiling is enabled (default since v0.21.0). The current --gpu-memory-utilization=0.7800 is equivalent to --gpu-memory-utilization=0.6964 without CUDA graph memory profiling. To maintain the same effective KV cache size as before, increase --gpu-memory-utilization to 0.8636. To disable, set VLLM_MEMORY_PROFILER_ESTIMATE_CUDAGRAPHS=0.
# (EngineCore pid=4965) INFO 08-13 05:07:07 [kv_cache_utils.py:1744] GPU KV cache size: 752,848 tokens
# (EngineCore pid=4965) INFO 08-13 05:07:07 [kv_cache_utils.py:1745] Maximum concurrency for 4,096 tokens per request: 183.80x
# (EngineCore pid=4965) INFO 08-13 05:07:07 [kernel_warmup.py:97] Warming up FlashInfer attention.
# (EngineCore pid=4965)
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):   0%|          | 0/51 [00:00<?, ?it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):   4%|▍         | 2/51 [00:00<00:02, 19.75it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  10%|▉         | 5/51 [00:00<00:02, 20.17it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  16%|█▌        | 8/51 [00:00<00:02, 21.37it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  22%|██▏       | 11/51 [00:00<00:01, 22.90it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  27%|██▋       | 14/51 [00:00<00:01, 23.42it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  33%|███▎      | 17/51 [00:00<00:01, 24.60it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  39%|███▉      | 20/51 [00:00<00:01, 25.70it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  45%|████▌     | 23/51 [00:00<00:01, 26.61it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  51%|█████     | 26/51 [00:01<00:00, 26.31it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  57%|█████▋    | 29/51 [00:01<00:00, 26.43it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  63%|██████▎   | 32/51 [00:01<00:00, 26.79it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  69%|██████▊   | 35/51 [00:01<00:00, 25.81it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  75%|███████▍  | 38/51 [00:01<00:00, 25.46it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  80%|████████  | 41/51 [00:01<00:00, 24.69it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  86%|████████▋ | 44/51 [00:01<00:00, 24.40it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  92%|█████████▏| 47/51 [00:01<00:00, 25.13it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE):  98%|█████████▊| 50/51 [00:02<00:00, 25.42it/s]
# Capturing CUDA graphs (mixed prefill-decode, PIECEWISE): 100%|██████████| 51/51 [00:02<00:00, 24.48it/s]
# (EngineCore pid=4965)
# Capturing CUDA graphs (decode, FULL):   0%|          | 0/35 [00:00<?, ?it/s]
# Capturing CUDA graphs (decode, FULL):   9%|▊         | 3/35 [00:00<00:01, 24.24it/s]
# Capturing CUDA graphs (decode, FULL):  17%|█▋        | 6/35 [00:00<00:01, 24.38it/s]
# Capturing CUDA graphs (decode, FULL):  26%|██▌       | 9/35 [00:00<00:01, 24.26it/s]
# Capturing CUDA graphs (decode, FULL):  34%|███▍      | 12/35 [00:00<00:00, 24.44it/s]
# Capturing CUDA graphs (decode, FULL):  43%|████▎     | 15/35 [00:00<00:00, 23.14it/s]
# Capturing CUDA graphs (decode, FULL):  51%|█████▏    | 18/35 [00:00<00:00, 23.25it/s]
# Capturing CUDA graphs (decode, FULL):  60%|██████    | 21/35 [00:00<00:00, 22.95it/s]
# Capturing CUDA graphs (decode, FULL):  69%|██████▊   | 24/35 [00:01<00:00, 22.51it/s]
# Capturing CUDA graphs (decode, FULL):  77%|███████▋  | 27/35 [00:01<00:00, 22.75it/s]
# Capturing CUDA graphs (decode, FULL):  86%|████████▌ | 30/35 [00:01<00:00, 22.32it/s]
# Capturing CUDA graphs (decode, FULL):  94%|█████████▍| 33/35 [00:01<00:00, 22.83it/s]
# Capturing CUDA graphs (decode, FULL): 100%|██████████| 35/35 [00:01<00:00, 23.13it/s]
# (EngineCore pid=4965) INFO 08-13 05:07:11 [gpu_model_runner.py:6585] Graph capturing finished in 5 secs, took 0.65 GiB
# (EngineCore pid=4965) INFO 08-13 05:07:11 [gpu_worker.py:639] CUDA graph pool memory: 0.65 GiB (actual), 1.22 GiB (estimated), difference: 0.57 GiB (87.7%).
# (EngineCore pid=4965) INFO 08-13 05:07:11 [jit_monitor.py:54] Kernel JIT monitor activated — Triton JIT compilations during inference will be logged as warnings.
# (EngineCore pid=4965) INFO 08-13 05:07:12 [core.py:306] init engine (profile, create kv cache, warmup model) took 25.11 s (compilation: 6.03 s)
# (EngineCore pid=4965) INFO 08-13 05:07:13 [vllm.py:999] Asynchronous scheduling is enabled.
# (EngineCore pid=4965) INFO 08-13 05:07:13 [kernel.py:270] Final IR op priority after setting platform defaults: IrOpPriorityConfig(rms_norm=['native'], fused_add_rms_norm=['native'])
# (APIServer pid=4821) INFO 08-13 05:07:13 [api_server.py:579] Supported tasks: ['generate']
# (APIServer pid=4821) WARNING 08-13 05:07:14 [model.py:1502] Default vLLM sampling parameters have been overridden by the model's `generation_config.json`: `{'repetition_penalty': 1.1, 'temperature': 0.7, 'top_k': 20, 'top_p': 0.8}`. If this is not intended, please relaunch vLLM instance with `--generation-config vllm`.
# (APIServer pid=4821) INFO 08-13 05:07:15 [hf.py:548] Detected the chat template content format to be 'string'. You can set `--chat-template-content-format` to override this.
# (APIServer pid=4821) INFO 08-13 05:07:16 [api_server.py:583] Starting vLLM server on http://127.0.0.1:8000
# (APIServer pid=4821) INFO 08-13 05:07:16 [launcher.py:37] Available routes are:
# (APIServer pid=4821) INFO 08-13 05:07:16 [launcher.py:46] Route: /openapi.json, Methods: HEAD, GET
# (APIServer pid=4821) INFO 08-13 05:07:16 [launcher.py:46] Route: /docs, Methods: HEAD, GET
# (APIServer pid=4821) INFO 08-13 05:07:16 [launcher.py:46] Route: /docs/oauth2-redirect, Methods: HEAD, GET
# (APIServer pid=4821) INFO 08-13 05:07:16 [launcher.py:46] Route: /redoc, Methods: HEAD, GET
# (APIServer pid=4821) INFO 08-13 05:07:16 [launcher.py:46] Route: /metrics, Methods: GET
# (APIServer pid=4821) INFO:     Started server process [4821]
# (APIServer pid=4821) INFO:     Waiting for application startup.
# (APIServer pid=4821) INFO:     Application startup complete.
# (APIServer pid=4821) INFO:     127.0.0.1:40448 - "GET /v1/models HTTP/1.1" 200 OK
#
# ================================================================================
# vLLM SERVER READY
# ================================================================================
# Endpoint: http://127.0.0.1:8000
# Logs: /content/vllm_lab_results/vllm_server.log
#
# (APIServer pid=4821) INFO:     127.0.0.1:40454 - "POST /v1/completions HTTP/1.1" 200 OK
# (EngineCore pid=4965) WARNING 08-13 05:07:17 [jit_monitor.py:103] Triton kernel JIT compilation during inference: _compute_slot_mapping_kernel. This causes a latency spike; consider extending warmup to cover this shape/config.
# READY

# %% [markdown]
# ### Task 3C - Prime and measure prefix caching ON
#
# First send one request that contains the shared prefix so vLLM has seen that prefix. Do not include this priming request in your measurements. Then measure the same `prefix_prompts` with the same `max_tokens=8` and store the results in `prefix_on_results`.

# %%
# TODO 1: Send one priming request containing shared_prefix.
_ = stream_completion(
    shared_prefix + "\n\nWarm up the shared prefix cache.", max_tokens=8
)

# TODO 2: Measure the same prefix_prompts with max_tokens=8.
prefix_on_results = [
    stream_completion(prompt, max_tokens=8) for prompt in prefix_prompts
]
# Out:
# (APIServer pid=4821) INFO:     127.0.0.1:40458 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=4821) INFO:     127.0.0.1:40474 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=4821) INFO:     127.0.0.1:40482 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=4821) INFO:     127.0.0.1:40484 - "POST /v1/completions HTTP/1.1" 200 OK
# (APIServer pid=4821) INFO:     127.0.0.1:40488 - "POST /v1/completions HTTP/1.1" 200 OK

# %% [markdown]
# <details>
# <summary>Hint 1</summary>
#
# The priming request must begin with `shared_prefix`. Its suffix can be something simple such as a warm-up instruction. The measured prompts must be exactly the same ones used in the OFF condition.
#
# </details>

# %% [markdown]
# <details>
# <summary>Hint 2</summary>
#
# Pseudocode:
#
#     send shared prefix plus one warm up suffix
#     for each measured prompt
#         send prompt with 8 output tokens
#         store returned dictionary
#
# </details>

# %%
if (
    isinstance(prefix_on_results, list)
    and len(prefix_on_results) == len(prefix_prompts)
    and len(prefix_on_results) >= 4
):
    if all(isinstance(r, dict) and "ttft_ms" in r for r in prefix_on_results):
        print("PASS")
    else:
        print("CHECK AGAIN")
else:
    print("CHECK AGAIN")
# Out:
# PASS

# %% [markdown]
# ### Task 3D - Compare the conditions
#
# Create a two-row dataframe called `prefix_summary` with these columns:
#
# - `condition`
# - `median_ttft_ms`
# - `median_e2e_ms`
# - `median_tpot_ms`
#
# Use medians across the measured requests.

# %%
# TODO: Summarize prefix_off_results and prefix_on_results.
prefix_summary = pd.DataFrame(
    [
        {
            "condition": "prefix caching OFF",
            "median_ttft_ms": statistics.median(
                r["ttft_ms"] for r in prefix_off_results
            ),
            "median_e2e_ms": statistics.median(
                r["e2e_ms"] for r in prefix_off_results
            ),
            "median_tpot_ms": statistics.median(
                r["approx_tpot_ms"] for r in prefix_off_results
            ),
        },
        {
            "condition": "prefix caching ON",
            "median_ttft_ms": statistics.median(
                r["ttft_ms"] for r in prefix_on_results
            ),
            "median_e2e_ms": statistics.median(
                r["e2e_ms"] for r in prefix_on_results
            ),
            "median_tpot_ms": statistics.median(
                r["approx_tpot_ms"] for r in prefix_on_results
            ),
        },
    ]
)

display(prefix_summary)
# Out:
#             condition  median_ttft_ms  median_e2e_ms  median_tpot_ms
# 0  prefix caching OFF       66.205306     108.164092        5.985804
# 1   prefix caching ON       33.719568      71.752895        5.565207

# %%
required = {"condition", "median_ttft_ms", "median_e2e_ms", "median_tpot_ms"}
if (
    isinstance(prefix_summary, pd.DataFrame)
    and len(prefix_summary) == 2
    and required.issubset(prefix_summary.columns)
):
    print("PASS")
else:
    print("CHECK AGAIN")
# Out:
# PASS

# %% [markdown]
# ### Explain Experiment 3
#
# 1. Which metric changed most clearly when prefix caching was enabled?
# 2. Why did we deliberately keep the generated output short?
# 3. Why would it be a bad experiment to change GPU memory utilization at the same time as the prefix caching flag?
# 4. If your TTFT improvement is small or noisy, what could you change about the workload without changing the concept being tested?

# %% [markdown]
# > **Your response**
# >
# > 1. The clearest expected change is a lower `median_ttft_ms` with prefix caching ON. End-to-end time may also fall, while `median_tpot_ms` should be much less affected because decoding still performs the later token-generation steps.
# > 2. Keeping the output at 8 tokens prevents a long decode phase from dominating end-to-end latency, making the saved prefill work easier to see.
# > 3. Changing GPU memory utilization at the same time would create a confound. It can change memory pressure, scheduling behavior, and cache capacity, so any latency difference could no longer be attributed cleanly to prefix caching.
# > 4. If the TTFT effect is noisy, make the **shared prefix longer** while keeping it within `MAX_MODEL_LEN`, increase the number of repeated measured requests, and compare medians. Keep the suffixes, output length, server settings, and other variables fixed.

# %% [markdown]
# # vLLM synthesis
#
# Complete the table in your own words.
#
# | What you changed | Main work affected | Metric that should react | What your data showed |
# |---|---|---|---|
# | Longer prompt | More prefill work | TTFT most directly; E2E may also rise | Typical result: TTFT increased as prompt token count increased |
# | Longer output | More sequential decode steps | End-to-end latency most clearly; TPOT is the per-token decode metric | Typical result: E2E increased strongly with `max_tokens`, while TTFT changed much less |
# | Higher concurrency | Scheduling/batching and GPU utilization | Aggregate tokens/s and request latency/TTFT | Typical result: throughput increased then became sublinear/saturated, while TTFT generally increased |
# | Prefix caching ON | Repeated prefill work for the shared prefix | TTFT most clearly | Typical result: cached-prefix TTFT fell; TPOT changed much less |
#
# ### Before moving to the torch.compile notebook
#
# **Why is measuring only total response time not enough to understand an inference optimization?**

# %% [markdown]
# > **Your response**
# >
# > Total response time combines several different effects: prefill, queueing/scheduling, network and serving overhead, and sequential decode. An optimization can improve one phase while another phase dominates the total, so a single end-to-end number can hide the mechanism. Metrics such as TTFT, TPOT, end-to-end latency, and aggregate throughput let us see *where* the optimization helps and whether it improves system efficiency, user-facing latency, or both.

# %% [markdown]
# ## Extra practice if you finish early
#
# Design one additional experiment that changes **only one variable**. Examples include a longer shared prefix, a higher concurrency level, or a different output length. State the hypothesis before running it and identify the metric that should react most strongly.

# %%
# Optional practice experiment workspace

# %% [markdown]
# ## Cleanup before the torch.compile notebook
#
# Run this cell before moving on. It stops the vLLM server and releases its GPU memory.

# %%
stop_server()
print("CLEANED UP")
# Out:
# (APIServer pid=4821) INFO 08-13 05:07:18 [launcher.py:100] [shutdown] API server: shutdown triggered
# (APIServer pid=4821) INFO 08-13 05:07:18 [launcher.py:116] [shutdown] API server: stopping engine client mode=abort timeout=0s
# (APIServer pid=4821) INFO 08-13 05:07:18 [core_client.py:652] [shutdown] MPClient: start timeout=0s
# (APIServer pid=4821) INFO 08-13 05:07:18 [core_client.py:654] [shutdown] MPClient: stopping engine manager
# (APIServer pid=4821) WARNING 08-13 05:07:18 [utils.py:607] [shutdown] Process manager: force killing remaining processes count=1
# (APIServer pid=4821) INFO 08-13 05:07:18 [core_client.py:656] [shutdown] MPClient: engine manager stopped
# (APIServer pid=4821) INFO 08-13 05:07:18 [core_client.py:657] [shutdown] MPClient: cleaning up background resources
# (APIServer pid=4821) INFO 08-13 05:07:18 [core_client.py:659] [shutdown] MPClient: complete
# (APIServer pid=4821) ERROR 08-13 05:07:18 [async_llm.py:704] AsyncLLM output_handler failed.
# (APIServer pid=4821) ERROR 08-13 05:07:18 [async_llm.py:704] Traceback (most recent call last):
# (APIServer pid=4821) ERROR 08-13 05:07:18 [async_llm.py:704]   File "/usr/local/lib/python3.12/dist-packages/vllm/v1/engine/async_llm.py", line 660, in output_handler
# (APIServer pid=4821) ERROR 08-13 05:07:18 [async_llm.py:704]     outputs = await engine_core.get_output_async()
# (APIServer pid=4821) ERROR 08-13 05:07:18 [async_llm.py:704]               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# (APIServer pid=4821) ERROR 08-13 05:07:18 [async_llm.py:704]   File "/usr/local/lib/python3.12/dist-packages/vllm/v1/engine/core_client.py", line 1046, in get_output_async
# (APIServer pid=4821) ERROR 08-13 05:07:18 [async_llm.py:704]     raise self._format_exception(outputs) from None
# (APIServer pid=4821) ERROR 08-13 05:07:18 [async_llm.py:704] vllm.v1.engine.exceptions.EngineDeadError: EngineCore encountered an issue. See stack trace (above) for the root cause.
# (APIServer pid=4821) INFO 08-13 05:07:18 [launcher.py:125] [shutdown] API server: engine client stopped
# (APIServer pid=4821) INFO 08-13 05:07:18 [launcher.py:128] [shutdown] API server: signalling HTTP server shutdown
# (APIServer pid=4821) INFO 08-13 05:07:18 [launcher.py:149] [shutdown] API server: shutting down FastAPI HTTP server
# (APIServer pid=4821) INFO:     Shutting down
# (APIServer pid=4821) INFO:     Waiting for application shutdown.
# (APIServer pid=4821) INFO:     Application shutdown complete.
# /usr/lib/python3.12/multiprocessing/resource_tracker.py:279: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
#   warnings.warn('resource_tracker: There appear to be %d '
# CLEANED UP
