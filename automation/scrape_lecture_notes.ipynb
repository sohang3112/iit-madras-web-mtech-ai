# %%
# %pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
from urllib.parse import urlparse, parse_qs, urlsplit, urlunsplit, urlencode

# %%
url = 'https://seek-ode-prod-auth.firebaseapp.com/__/auth/handler?state=AMbdmDmVXdEFedxFvvAhEP8p9g5fY37zRHSHjB_N3S5GA8jaHZLfjyo7jXCXvtcC9kdEWeqtTx8BHM6JCjDeSoTWjYyaNEcFYpq9xMqdY9zNIkBi07959E9Ke5DQ3zxGkQmZuslT9ZmtwMkT7qnyes2DjyduF_tALoxKF4FWknpTXAqapYzOIr-qX-5v--Yqr_joPQ_ekbf_84nEkV7fTNeuGYI3fP_Jk1EVfNndqd1lOBikJnbPAbENCTaE0EsjpUILhstLulAXAC9XevehWtkGJ7WTZQ-zK9jkWckItuWBcbRAa_uq97xBoZCV6l-mHTrlb7bHONy-a62Ikg&code=4%2F0ASc3gC33xmCaDwWV7Iy0ejvqLe6D3Ju7JxZH7klqKNMGs5eCskpKjntlwF8J67p_Z-L2eQ&scope=email%20profile%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.profile%20openid&authuser=1&hd=smail.iitm.ac.in&prompt=none'
print(urlsplit(url))
parse_qs(urlparse(url).query)
# Out:
# SplitResult(scheme='https', netloc='seek-ode-prod-auth.firebaseapp.com', path='/__/auth/handler', query='state=AMbdmDmVXdEFedxFvvAhEP8p9g5fY37zRHSHjB_N3S5GA8jaHZLfjyo7jXCXvtcC9kdEWeqtTx8BHM6JCjDeSoTWjYyaNEcFYpq9xMqdY9zNIkBi07959E9Ke5DQ3zxGkQmZuslT9ZmtwMkT7qnyes2DjyduF_tALoxKF4FWknpTXAqapYzOIr-qX-5v--Yqr_joPQ_ekbf_84nEkV7fTNeuGYI3fP_Jk1EVfNndqd1lOBikJnbPAbENCTaE0EsjpUILhstLulAXAC9XevehWtkGJ7WTZQ-zK9jkWckItuWBcbRAa_uq97xBoZCV6l-mHTrlb7bHONy-a62Ikg&code=4%2F0ASc3gC33xmCaDwWV7Iy0ejvqLe6D3Ju7JxZH7klqKNMGs5eCskpKjntlwF8J67p_Z-L2eQ&scope=email%20profile%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.profile%20openid&authuser=1&hd=smail.iitm.ac.in&prompt=none', fragment='')
# ...

# %%
headers = {
    # 'sec-ch-ua-platform': '"Linux"',
    # 'Referer': '',
    # 'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.36 Edg/144.0.0.0',
    # 'X-Client-Version': 'Chrome/JsCore/10.14.1/FirebaseCore-web',
    # 'sec-ch-ua': '"Not(A:Brand";v="8", "Chromium";v="144", "Microsoft Edge";v="144"',
    # 'Content-Type': 'application/json',
    # 'sec-ch-ua-mobile': '?0',
}

params = {
    'key': 'AIzaSyCRRLTTiR_BLSWJA1m7Gwcy3aYuEhkRI7Q',
}

payload = {
    'requestUri': 
    'sessionId': 'Jc82_wjaMJE6LiCzbIlvQQ5zswk',
    'returnSecureToken': True,
    'returnIdpCredential': True,
}

response = requests.post(
    'https://identitytoolkit.googleapis.com/v1/accounts:signInWithIdp',
    params=params,
    headers=headers,
    json=payload,
)
response.raise_for_status()
login_info = response.json()
login_info

# %%
headers = {
    'SEEK_ID_TOKEN': 'eyJhbGciOiJSUzI1NiIsImtpZCI6ImY3NThlNTYzYzBiNjRhNzVmN2UzZGFlNDk0ZDM5NTk1YzE0MGVmOTMiLCJ0eXAiOiJKV1QifQ.....Ye4CKdzErpthP3Mvnuffm9fSDS82Vnjg4342Y8K7uUJrJRLdznKvO7PVHDjFaUJJImcoYUzMENlmXzmEZhdul_tBdkQ5uuUSFjqd9cfdVpf6uax8li164ICMYKh02yZ9oON4xvNF-DqtK8bHnhViT5zhkNniYAXE9lgXEShmpgnvISGfwveq1Q4daluRIUDnpIheryn46ZIB8s7T4so0YkHgtEwhH83eOEzSyl6_tObnLvbZeYKDiBtcNb07_7ckUOyBtnXlwHVQrWQ_u-JRdUSY8rmsvLZxbG1YyoNhAFYpm9oaO2VHpoZls-Mvd1-lF9CCrunOf-vw7eQ1ThKyOw',
    'SEEK_NAMESPACE': 'ns_26t1iai_da5400w',
}

graphql_query = """
query lesson($id_: String!, $namespace: String!) {
  lesson(id_: $id_, namespace: $namespace) {
    title
    video
    parentUnitId
    transcriptVttUrl
    objectives
    lessonId
    __typename
  }
}
"""

payload = {
    'operationName': 'lesson',
    'variables': {
        'id_': '8',
        'namespace': 'ns_26t1iai_da5400w',
    },
    'query': graphql_query,
}

response = requests.post('https://open-nptel-nk7eaoz6ha-el.a.run.app/graphql', headers=headers, json=payload)
response.raise_for_status()
info: dict = response.json()
info
# Out:
# {'data': {'lesson': {'title': 'Lecture Note 1',
#    'video': '',
#    'parentUnitId': '7',
#    'transcriptVttUrl': '',
#    'objectives': 'Click here to access - <a href="https://cb-prod.seek.study.iitm.ac.in/26t1iai_da5400w/assets/img/DA5400W_FML.pdf" target="_blank" title="">Lecture Note 1</a>',
#    'lessonId': 8,
#    '__typename': 'Lesson'}}}

# %%
soup = BeautifulSoup(info['data']['lesson']['objectives'])
{link.text: link['href'] for link in soup.find_all('a')}
# Out:
# {'Lecture Note 1': 'https://cb-prod.seek.study.iitm.ac.in/26t1iai_da5400w/assets/img/DA5400W_FML.pdf'}

# %%
lecture_pdf_url = 'https://cb-prod.seek.study.iitm.ac.in/26t1iai_da5400w/assets/img/DA5400W_FML.pdf'
urlretrieve(lecture_pdf_url, 'Lecture Note 1' + '.pdf')   # TODO: instead of current directory, download to specific course lecture directory
# Out:
# ('/tmp/tmp3rjym4to', <http.client.HTTPMessage at 0x7f0327649630>)
