# %% [markdown]
# `networkx` graph (Python) library tutorial: https://networkx.org/documentation/stable/tutorial.html

# %%
import networkx as nx

# graph has nodes (vertices), edges/links (pairs of nodes)
# nodes can be any hashable object, except None
# G = nx.Graph()   # empty graph

G = nx.complete_graph(5)
nx.draw(G)     # draws with matplotlib
